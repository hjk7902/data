# %%
import nltk

# %%
nltk.download(download_dir="C:/nltk_data")
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
nltk.download("treebank", download_dir="C:\\nltk_data")
# Out:
# [nltk_data] Downloading package treebank to C:\nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# True

# %%
from nltk.corpus import treebank

# %%
print(treebank.fileids())
# Out:
# ['wsj_0001.mrg', 'wsj_0002.mrg', 'wsj_0003.mrg', 'wsj_0004.mrg', 'wsj_0005.mrg', 'wsj_0006.mrg', 'wsj_0007.mrg', 'wsj_0008.mrg', 'wsj_0009.mrg', 'wsj_0010.mrg', 'wsj_0011.mrg', 'wsj_0012.mrg', 'wsj_0013.mrg', 'wsj_0014.mrg', 'wsj_0015.mrg', 'wsj_0016.mrg', 'wsj_0017.mrg', 'wsj_0018.mrg', 'wsj_0019.mrg', 'wsj_0020.mrg', 'wsj_0021.mrg', 'wsj_0022.mrg', 'wsj_0023.mrg', 'wsj_0024.mrg', 'wsj_0025.mrg', 'wsj_0026.mrg', 'wsj_0027.mrg', 'wsj_0028.mrg', 'wsj_0029.mrg', 'wsj_0030.mrg', 'wsj_0031.mrg', 'wsj_0032.mrg', 'wsj_0033.mrg', 'wsj_0034.mrg', 'wsj_0035.mrg', 'wsj_0036.mrg', 'wsj_0037.mrg', 'wsj_0038.mrg', 'wsj_0039.mrg', 'wsj_0040.mrg', 'wsj_0041.mrg', 'wsj_0042.mrg', 'wsj_0043.mrg', 'wsj_0044.mrg', 'wsj_0045.mrg', 'wsj_0046.mrg', 'wsj_0047.mrg', 'wsj_0048.mrg', 'wsj_0049.mrg', 'wsj_0050.mrg', 'wsj_0051.mrg', 'wsj_0052.mrg', 'wsj_0053.mrg', 'wsj_0054.mrg', 'wsj_0055.mrg', 'wsj_0056.mrg', 'wsj_0057.mrg', 'wsj_0058.mrg', 'wsj_0059.mrg', 'wsj_0060.mrg', 'wsj_0061.mrg', 'wsj_0062.mrg', 'wsj_0063.mrg', 'wsj_0064.mrg', 'wsj_0065.mrg', 'wsj_0066.mrg', 'wsj_0067.mrg', 'wsj_0068.mrg', 'wsj_0069.mrg', 'wsj_0070.mrg', 'wsj_0071.mrg', 'wsj_0072.mrg', 'wsj_0073.mrg', 'wsj_0074.mrg', 'wsj_0075.mrg', 'wsj_0076.mrg', 'wsj_0077.mrg', 'wsj_0078.mrg', 'wsj_0079.mrg', 'wsj_0080.mrg', 'wsj_0081.mrg', 'wsj_0082.mrg', 'wsj_0083.mrg', 'wsj_0084.mrg', 'wsj_0085.mrg', 'wsj_0086.mrg', 'wsj_0087.mrg', 'wsj_0088.mrg', 'wsj_0089.mrg', 'wsj_0090.mrg', 'wsj_0091.mrg', 'wsj_0092.mrg', 'wsj_0093.mrg', 'wsj_0094.mrg', 'wsj_0095.mrg', 'wsj_0096.mrg', 'wsj_0097.mrg', 'wsj_0098.mrg', 'wsj_0099.mrg', 'wsj_0100.mrg', 'wsj_0101.mrg', 'wsj_0102.mrg', 'wsj_0103.mrg', 'wsj_0104.mrg', 'wsj_0105.mrg', 'wsj_0106.mrg', 'wsj_0107.mrg', 'wsj_0108.mrg', 'wsj_0109.mrg', 'wsj_0110.mrg', 'wsj_0111.mrg', 'wsj_0112.mrg', 'wsj_0113.mrg', 'wsj_0114.mrg', 'wsj_0115.mrg', 'wsj_0116.mrg', 'wsj_0117.mrg', 'wsj_0118.mrg', 'wsj_0119.mrg', 'wsj_0120.mrg', 'wsj_0121.mrg', 'wsj_0122.mrg', 'wsj_0123.mrg', 'wsj_0124.mrg', 'wsj_0125.mrg', 'wsj_0126.mrg', 'wsj_0127.mrg', 'wsj_0128.mrg', 'wsj_0129.mrg', 'wsj_0130.mrg', 'wsj_0131.mrg', 'wsj_0132.mrg', 'wsj_0133.mrg', 'wsj_0134.mrg', 'wsj_0135.mrg', 'wsj_0136.mrg', 'wsj_0137.mrg', 'wsj_0138.mrg', 'wsj_0139.mrg', 'wsj_0140.mrg', 'wsj_0141.mrg', 'wsj_0142.mrg', 'wsj_0143.mrg', 'wsj_0144.mrg', 'wsj_0145.mrg', 'wsj_0146.mrg', 'wsj_0147.mrg', 'wsj_0148.mrg', 'wsj_0149.mrg', 'wsj_0150.mrg', 'wsj_0151.mrg', 'wsj_0152.mrg', 'wsj_0153.mrg', 'wsj_0154.mrg', 'wsj_0155.mrg', 'wsj_0156.mrg', 'wsj_0157.mrg', 'wsj_0158.mrg', 'wsj_0159.mrg', 'wsj_0160.mrg', 'wsj_0161.mrg', 'wsj_0162.mrg', 'wsj_0163.mrg', 'wsj_0164.mrg', 'wsj_0165.mrg', 'wsj_0166.mrg', 'wsj_0167.mrg', 'wsj_0168.mrg', 'wsj_0169.mrg', 'wsj_0170.mrg', 'wsj_0171.mrg', 'wsj_0172.mrg', 'wsj_0173.mrg', 'wsj_0174.mrg', 'wsj_0175.mrg', 'wsj_0176.mrg', 'wsj_0177.mrg', 'wsj_0178.mrg', 'wsj_0179.mrg', 'wsj_0180.mrg', 'wsj_0181.mrg', 'wsj_0182.mrg', 'wsj_0183.mrg', 'wsj_0184.mrg', 'wsj_0185.mrg', 'wsj_0186.mrg', 'wsj_0187.mrg', 'wsj_0188.mrg', 'wsj_0189.mrg', 'wsj_0190.mrg', 'wsj_0191.mrg', 'wsj_0192.mrg', 'wsj_0193.mrg', 'wsj_0194.mrg', 'wsj_0195.mrg', 'wsj_0196.mrg', 'wsj_0197.mrg', 'wsj_0198.mrg', 'wsj_0199.mrg']

# %%
treebank.sents("wsj_0001.mrg")
# Out:
# [['Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov.', '29', '.'], ['Mr.', 'Vinken', 'is', 'chairman', 'of', 'Elsevier', 'N.V.', ',', 'the', 'Dutch', 'publishing', 'group', '.']]

# %%
wsj_0001 = treebank.sents("wsj_0001.mrg")
for line in wsj_0001:
    print(' '.join(line))
# Out:
# Pierre Vinken , 61 years old , will join the board as a nonexecutive director Nov. 29 .
# Mr. Vinken is chairman of Elsevier N.V. , the Dutch publishing group .

# %%
treebank.tagged_words("wsj_0001.mrg")
# Out:
# [('Pierre', 'NNP'), ('Vinken', 'NNP'), (',', ','), ...]

# %%
print(treebank.parsed_sents("wsj_0001.mrg")[0])
# Out:
# (S
#   (NP-SBJ
#     (NP (NNP Pierre) (NNP Vinken))
#     (, ,)
#     (ADJP (NP (CD 61) (NNS years)) (JJ old))
#     (, ,))
#   (VP
#     (MD will)
#     (VP
#       (VB join)
#       (NP (DT the) (NN board))
#       (PP-CLR (IN as) (NP (DT a) (JJ nonexecutive) (NN director)))
#       (NP-TMP (NNP Nov.) (CD 29))))
#   (. .))

# %%
nltk.download("book", download_dir="C:/nltk_data", quiet=True)
# Out:
# True

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
type(text1)
# Out:
# nltk.text.Text

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
emma = nltk.corpus.gutenberg.raw("austen-emma.txt")

# %%
print(emma[:200])
# Out:
# [Emma by Jane Austen 1816]
#
# VOLUME I
#
# CHAPTER I
#
#
# Emma Woodhouse, handsome, clever, and rich, with a comfortable home
# and happy disposition, seemed to unite some of the best blessings
# of existence; an

# %%
from nltk.tokenize import sent_tokenize

# %%
print(sent_tokenize(emma[:1000])[3])
# Out:
# Sixteen years had Miss Taylor been in Mr. Woodhouse's family,
# less as a governess than a friend, very fond of both daughters,
# but particularly of Emma.

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(emma[50:100])
# Out:
# ['Emma',
#  'Woodhouse',
#  ',',
#  'handsome',
#  ',',
#  'clever',
#  ',',
#  'and',
#  'rich',
#  ',',
#  'with',
#  'a']

# %%
from nltk.tokenize import RegexpTokenizer

# %%
ret = RegexpTokenizer("[\w]+")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\KOSA\AppData\Local\Temp\ipykernel_7232\1861743190.py:1: SyntaxWarning: invalid escape sequence '\w'
#   ret = RegexpTokenizer("[\w]+")

# %%
ret.tokenize(emma[50:100])
# Out:
# ['Emma', 'Woodhouse', 'handsome', 'clever', 'and', 'rich', 'with', 'a']

# %%
words = ["sending", "cooking", "flies", "lives", 
         "crying", "dying"]

# %%
from nltk.stem import PorterStemmer

# %%
pst = PorterStemmer()

# %%
pst.stem(words[0])
# Out:
# 'send'

# %%
[pst.stem(w) for w in words]
# Out:
# ['send', 'cook', 'fli', 'live', 'cri', 'die']

# %%
from nltk.stem import LancasterStemmer

# %%
lst = LancasterStemmer()

# %%
[lst.stem(w) for w in words]
# Out:
# ['send', 'cook', 'fli', 'liv', 'cry', 'dying']

# %%
from nltk.stem.regexp import RegexpStemmer

# %%
rest = RegexpStemmer('ing')

# %%
[rest.stem(w) for w in words]
# Out:
# ['send', 'cook', 'flies', 'lives', 'cry', 'dy']

# %%
words2 = ['enviar', 'cocina', 'moscas', 'vidas', 
          'llorar', 'morir']

# %%
from nltk.stem.snowball import SnowballStemmer

# %%
sbst = SnowballStemmer('spanish')

# %%
[sbst.stem(w) for w in words2]
# Out:
# ['envi', 'cocin', 'mosc', 'vid', 'llor', 'mor']

# %%
words3 = ["cooking", "believes"]

# %%
from nltk.stem.wordnet import WordNetLemmatizer

# %%
wl = WordNetLemmatizer()

# %%
[wl.lemmatize(w) for w in words3]
# Out:
# ['cooking', 'belief']

# %%
[wl.lemmatize(w, pos='v') for w in words3]
# Out:
# ['cook', 'believe']

# %%
nltk.help.upenn_tagset('NNP')
# Out:
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...

# %%
nltk.help.upenn_tagset()
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
#     lutihaw alai je jour objets salutaris fille quibusdam pas trop Monte
#     terram fiche oui corporis ...
# IN: preposition or conjunction, subordinating
#     astride among uppon whether out inside pro despite on by throughout
#     below within for towards near behind atop around if like until below
#     next into if beside ...
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...
# JJR: adjective, comparative
#     bleaker braver breezier briefer brighter brisker broader bumper busier
#     calmer cheaper choosier cleaner clearer closer colder commoner costlier
#     cozier creamier crunchier cuter ...
# JJS: adjective, superlative
#     calmest cheapest choicest classiest cleanest clearest closest commonest
#     corniest costliest crassest creepiest crudest cutest darkest deadliest
#     dearest deepest densest dinkiest ...
# LS: list item marker
#     A A. B B. C C. D E F First G H I J K One SP-44001 SP-44002 SP-44005
#     SP-44007 Second Third Three Two * a b c d first five four one six three
#     two
# MD: modal auxiliary
#     can cannot could couldn't dare may might must need ought shall should
#     shouldn't will would
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...
# NNPS: noun, proper, plural
#     Americans Americas Amharas Amityvilles Amusements Anarcho-Syndicalists
#     Andalusians Andes Andruses Angels Animals Anthony Antilles Antiques
#     Apache Apaches Apocrypha ...
# NNS: noun, common, plural
#     undergraduates scotches bric-a-brac products bodyguards facets coasts
#     divestitures storehouses designs clubs fragrances averages
#     subjectivists apprehensions muses factory-jobs ...
# PDT: pre-determiner
#     all both half many quite such sure this
# POS: genitive marker
#     ' 's
# PRP: pronoun, personal
#     hers herself him himself hisself it itself me myself one oneself ours
#     ourselves ownself self she thee theirs them themselves they thou thy us
# PRP$: pronoun, possessive
#     her his mine my our ours their thy your
# RB: adverb
#     occasionally unabatingly maddeningly adventurously professedly
#     stirringly prominently technologically magisterially predominately
#     swiftly fiscally pitilessly ...
# RBR: adverb, comparative
#     further gloomier grander graver greater grimmer harder harsher
#     healthier heavier higher however larger later leaner lengthier less-
#     perfectly lesser lonelier longer louder lower more ...
# RBS: adverb, superlative
#     best biggest bluntest earliest farthest first furthest hardest
#     heartiest highest largest least less most nearest second tightest worst
# RP: particle
#     aboard about across along apart around aside at away back before behind
#     by crop down ever fast for forth from go high i.e. in into just later
#     low more off on open out over per pie raising start teeth that through
#     under unto up up-pp upon whole with you
# SYM: symbol
#     % & ' '' ''. ) ). * + ,. < = > @ A[fj] U.S U.S.S.R * ** ***
# TO: "to" as preposition or infinitive marker
#     to
# UH: interjection
#     Goodbye Goody Gosh Wow Jeepers Jee-sus Hubba Hey Kee-reist Oops amen
#     huh howdy uh dammit whammo shucks heck anyways whodunnit honey golly
#     man baby diddle hush sonuvabitch ...
# VB: verb, base form
#     ask assemble assess assign assume atone attention avoid bake balkanize
#     bank begin behold believe bend benefit bevel beware bless boil bomb
#     boost brace break bring broil brush build ...
# VBD: verb, past tense
#     dipped pleaded swiped regummed soaked tidied convened halted registered
#     cushioned exacted snubbed strode aimed adopted belied figgered
#     speculated wore appreciated contemplated ...
# VBG: verb, present participle or gerund
#     telegraphing stirring focusing angering judging stalling lactating
#     hankerin' alleging veering capping approaching traveling besieging
#     encrypting interrupting erasing wincing ...
# VBN: verb, past participle
#     multihulled dilapidated aerosolized chaired languished panelized used
#     experimented flourished imitated reunifed factored condensed sheared
#     unsettled primed dubbed desired ...
# VBP: verb, present tense, not 3rd person singular
#     predominate wrap resort sue twist spill cure lengthen brush terminate
#     appear tend stray glisten obtain comprise detest tease attract
#     emphasize mold postpone sever return wag ...
# VBZ: verb, present tense, 3rd person singular
#     bases reconstructs marks mixes displeases seals carps weaves snatches
#     slumps stretches authorizes smolders pictures emerges stockpiles
#     seduces fizzes uses bolsters slaps speaks pleads ...
# WDT: WH-determiner
#     that what whatever which whichever
# WP: WH-pronoun
#     that what whatever whatsoever which who whom whosoever
# WP$: WH-pronoun, possessive
#     whose
# WRB: Wh-adverb
#     how however whence whenever where whereby whereever wherein whereof why
# ``: opening quotation mark
#     ` ``

# %%
sentense = emma[50:289]

# %%
print(sentense)
# Out:
# Emma Woodhouse, handsome, clever, and rich, with a comfortable home
# and happy disposition, seemed to unite some of the best blessings
# of existence; and had lived nearly twenty-one years in the world
# with very little to distress or vex her.

# %%
from nltk.tag import pos_tag

# %%
tagged_list = pos_tag(word_tokenize(sentense))

# %%
print(tagged_list)
# Out:
# [('Emma', 'NNP'), ('Woodhouse', 'NNP'), (',', ','), ('handsome', 'NN'), (',', ','), ('clever', 'NN'), (',', ','), ('and', 'CC'), ('rich', 'JJ'), (',', ','), ('with', 'IN'), ('a', 'DT'), ('comfortable', 'JJ'), ('home', 'NN'), ('and', 'CC'), ('happy', 'JJ'), ('disposition', 'NN'), (',', ','), ('seemed', 'VBD'), ('to', 'TO'), ('unite', 'VB'), ('some', 'DT'), ('of', 'IN'), ('the', 'DT'), ('best', 'JJS'), ('blessings', 'NNS'), ('of', 'IN'), ('existence', 'NN'), (';', ':'), ('and', 'CC'), ('had', 'VBD'), ('lived', 'VBN'), ('nearly', 'RB'), ('twenty-one', 'CD'), ('years', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('world', 'NN'), ('with', 'IN'), ('very', 'RB'), ('little', 'JJ'), ('to', 'TO'), ('distress', 'VB'), ('or', 'CC'), ('vex', 'VB'), ('her', 'PRP'), ('.', '.')]

# %%
nouns_list = [ t[0] for t in tagged_list if t[1]=="NN"]

# %%
nouns_list
# Out:
# ['handsome', 'clever', 'home', 'disposition', 'existence', 'world']

# %%
import re

# %%
pattern = re.compile('NN?')

# %%
nouns_list = [t[0] for t in tagged_list 
              if pattern.match(t[1])]

# %%
nouns_list
# Out:
# ['Emma',
#  'Woodhouse',
#  'handsome',
#  'clever',
#  'home',
#  'disposition',
#  'blessings',
#  'existence',
#  'years',
#  'world']

# %%
tagged_list
# Out:
# [('Emma', 'NNP'),
#  ('Woodhouse', 'NNP'),
#  (',', ','),
#  ('handsome', 'NN'),
#  (',', ','),
#  ('clever', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('rich', 'JJ'),
#  (',', ','),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('comfortable', 'JJ'),
#  ('home', 'NN'),
#  ('and', 'CC'),
#  ('happy', 'JJ'),
#  ('disposition', 'NN'),
#  (',', ','),
#  ('seemed', 'VBD'),
#  ('to', 'TO'),
#  ('unite', 'VB'),
#  ('some', 'DT'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('best', 'JJS'),
#  ('blessings', 'NNS'),
#  ('of', 'IN'),
#  ('existence', 'NN'),
#  (';', ':'),
#  ('and', 'CC'),
#  ('had', 'VBD'),
#  ('lived', 'VBN'),
#  ('nearly', 'RB'),
#  ('twenty-one', 'CD'),
#  ('years', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('with', 'IN'),
#  ('very', 'RB'),
#  ('little', 'JJ'),
#  ('to', 'TO'),
#  ('distress', 'VB'),
#  ('or', 'CC'),
#  ('vex', 'VB'),
#  ('her', 'PRP'),
#  ('.', '.')]

# %%
from nltk.tag import untag

# %%
untag(tagged_list)
# Out:
# ['Emma',
#  'Woodhouse',
#  ',',
#  'handsome',
#  ',',
#  'clever',
#  ',',
#  'and',
#  'rich',
#  ',',
#  'with',
#  'a',
#  'comfortable',
#  'home',
#  'and',
#  'happy',
#  'disposition',
#  ',',
#  'seemed',
#  'to',
#  'unite',
#  'some',
#  'of',
#  'the',
#  'best',
#  'blessings',
#  'of',
#  'existence',
#  ';',
#  'and',
#  'had',
#  'lived',
#  'nearly',
#  'twenty-one',
#  'years',
#  'in',
#  'the',
#  'world',
#  'with',
#  'very',
#  'little',
#  'to',
#  'distress',
#  'or',
#  'vex',
#  'her',
#  '.']

# %%
["/".join(p) for p in tagged_list]
# Out:
# ['Emma/NNP',
#  'Woodhouse/NNP',
#  ',/,',
#  'handsome/NN',
#  ',/,',
#  'clever/NN',
#  ',/,',
#  'and/CC',
#  'rich/JJ',
#  ',/,',
#  'with/IN',
#  'a/DT',
#  'comfortable/JJ',
#  'home/NN',
#  'and/CC',
#  'happy/JJ',
#  'disposition/NN',
#  ',/,',
#  'seemed/VBD',
#  'to/TO',
#  'unite/VB',
#  'some/DT',
#  'of/IN',
#  'the/DT',
#  'best/JJS',
#  'blessings/NNS',
#  'of/IN',
#  'existence/NN',
#  ';/:',
#  'and/CC',
#  'had/VBD',
#  'lived/VBN',
#  'nearly/RB',
#  'twenty-one/CD',
#  'years/NNS',
#  'in/IN',
#  'the/DT',
#  'world/NN',
#  'with/IN',
#  'very/RB',
#  'little/JJ',
#  'to/TO',
#  'distress/VB',
#  'or/CC',
#  'vex/VB',
#  'her/PRP',
#  './.']

# %%
ret = RegexpTokenizer("[\w]{2,}")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\KOSA\AppData\Local\Temp\ipykernel_7232\2397832216.py:1: SyntaxWarning: invalid escape sequence '\w'
#   ret = RegexpTokenizer("[\w]{2,}")

# %%
from nltk import Text

# %%
emma_text = Text(ret.tokenize(emma))

# %%
emma_text.plot(20)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
emma_text.concordance('Emma', lines=5)
# Out:
# Displaying 5 of 865 matches:
#                                      Emma by Jane Austen 1816 VOLUME CHAPTER E
# a by Jane Austen 1816 VOLUME CHAPTER Emma Woodhouse handsome clever and rich w
# f both daughters but particularly of Emma Between _them_ it was more the intim
# nd friend very mutually attached and Emma doing just what she liked highly est
#  by her own The real evils indeed of Emma situation were the power of having r

# %%
emma_text.similar("general")
# Out:
# love short it london time fact her which highbury and his own well him
# my hurry return vain person despair

# %%
emma_text.similar("general", 10)
# Out:
# love short it london time fact her which highbury and

# %%
emma_text.common_contexts(["general", "strong"])
# Out:
# was_expectation

# %%
emma_text.dispersion_plot(["Emma", "Knightley", "Frank",
                           "Jane", "Harriet", "Robert"])

# %%
len(emma_text)
# Out:
# 154664

# %%
len(set(emma_text))
# Out:
# 7703

# %%
len(set(emma_text)) / len(emma_text)
# Out:
# 0.04980473801272436

# %%
emma_fd = emma_text.vocab()

# %%
type(emma_fd)
# Out:
# nltk.probability.FreqDist

# %%
from nltk import FreqDist

# %%
stopwords = ["Mr.", "Mrs.", "Miss", "Mr", "Mrs", "Dear"]

# %%
emma_tokens = pos_tag(emma_text)

# %%
names_list = [t[0] for t in emma_tokens
              if t[1]=="NNP" and t[0] not in stopwords]

# %%
emma_fd_names = FreqDist(names_list)

# %%
emma_fd_names
# Out:
# FreqDist({'Emma': 833, 'Harriet': 489, 'Weston': 439, 'Knightley': 389, 'Elton': 385, 'Woodhouse': 305, 'Jane': 298, 'Fairfax': 241, 'Churchill': 223, 'Frank': 208, ...})

# %%
emma_fd_names.most_common(5)
# Out:
# [('Emma', 833),
#  ('Harriet', 489),
#  ('Weston', 439),
#  ('Knightley', 389),
#  ('Elton', 385)]

# %% [markdown]
# ## 유튜브 댓글 분석하기

# %%
import pandas as pd
# 4장에서 수집한 유튜브 댓글 데이터 파일이 있어야 합니다.
comment_df = pd.read_csv("comment.csv", encoding="utf-8-sig")
comment_df.head()
# Out:
#                  user                                  comment
# 0  @achinichamika-e4j   1:19 Rose is confuse ready to sandwich
# 1  @achinichamika-e4j  1:07 Rose has really hungry this moment
# 2  @achinichamika-e4j           1:04 lisa cute dance with kuma
# 3  @achinichamika-e4j         I really missing blackPINK house
# 4  @achinichamika-e4j                         Anyone in 2026??

# %%
from nltk.tokenize import RegexpTokenizer
ret = RegexpTokenizer(r"[\w]{2,}")
comment_df["comment"] = comment_df["comment"].map(str)
comment_tokens = comment_df["comment"].map(ret.tokenize)

# %%
comment_tokens.head()
# Out:
# 0     [19, Rose, is, confuse, ready, to, sandwich]
# 1    [07, Rose, has, really, hungry, this, moment]
# 2              [04, lisa, cute, dance, with, kuma]
# 3              [really, missing, blackPINK, house]
# 4                               [Anyone, in, 2026]
# Name: comment, dtype: object

# %%
from nltk.tag import pos_tag
comment_tags = comment_tokens.map(pos_tag)

# %%
comment_tags.head()
# Out:
# 0    [(19, CD), (Rose, NNP), (is, VBZ), (confuse, J...
# 1    [(07, CD), (Rose, NNP), (has, VBZ), (really, R...
# 2    [(04, CD), (lisa, JJ), (cute, NN), (dance, NN)...
# 3    [(really, RB), (missing, VBG), (blackPINK, NN)...
# 4                 [(Anyone, NN), (in, IN), (2026, CD)]
# Name: comment, dtype: object

# %%
comment_list = comment_tags.values.tolist()

# %%
comment_list
# Out:
# [[('19', 'CD'),
#   ('Rose', 'NNP'),
#   ('is', 'VBZ'),
#   ('confuse', 'JJ'),
#   ('ready', 'JJ'),
#   ('to', 'TO'),
#   ('sandwich', 'VB')],
#  [('07', 'CD'),
#   ('Rose', 'NNP'),
#   ('has', 'VBZ'),
#   ('really', 'RB'),
#   ('hungry', 'JJ'),
#   ('this', 'DT'),
#   ('moment', 'NN')],
#  [('04', 'CD'),
#   ('lisa', 'JJ'),
#   ('cute', 'NN'),
#   ('dance', 'NN'),
#   ('with', 'IN'),
#   ('kuma', 'NN')],
#  [('really', 'RB'), ('missing', 'VBG'), ('blackPINK', 'NN'), ('house', 'NN')],
#  [('Anyone', 'NN'), ('in', 'IN'), ('2026', 'CD')],
#  [('Lv', 'NNP'),
#   ('yu', 'PRP'),
#   ('so', 'RB'),
#   ('much', 'JJ'),
#   ('my', 'PRP$'),
#   ('bp', 'JJ'),
#   ('girls', 'NNS')],
#  [('BlackPINK', 'NNP'), ('in', 'IN'), ('your', 'PRP$'), ('area', 'NN')],
#  [('생각에는', 'JJ'),
#   ('블랙핑크를', 'NNP'),
#   ('인도에서', 'NNP'),
#   ('누가', 'NNP'),
#   ('보고', 'NNP'),
#   ('있을까요', 'NNP'),
#   ('저는', 'NNP'),
#   ('한국에서', 'NNP'),
#   ('보고', 'NNP'),
#   ('있어요', 'NN')],
#  [('Cute', 'NNP'), ('jesso', 'NN')],
#  [('Jisoo', 'NNP'),
#   ('and', 'CC'),
#   ('Jennie', 'NNP'),
#   ('cute', 'JJ'),
#   ('voice', 'NN'),
#   ('melted', 'VBD'),
#   ('me', 'PRP')],
#  [('我好哦哇提出2026', '$'), ('07', 'CD')],
#  [('41', 'CD'), ('jisoo', 'NNS'), ('so', 'RB'), ('cute', 'JJ')],
#  [('Cute', 'NN')],
#  [('Who', 'WP'),
#   ('watch', 'VBP'),
#   ('this', 'DT'),
#   ('in', 'IN'),
#   ('2026', 'CD')],
#  [('rosé', 'NN'),
#   ('being', 'VBG'),
#   ('the', 'DT'),
#   ('foodie', 'NN'),
#   ('since', 'IN'),
#   ('the', 'DT'),
#   ('beginning', 'NN'),
#   ('of', 'IN'),
#   ('this', 'DT'),
#   ('episode', 'NN')],
#  [('watch', 'NN'), ('in', 'IN'), ('2025', 'CD')],
#  [('2026', 'CD'),
#   ('Msih', 'NNP'),
#   ('ada', 'VBD'),
#   ('yg', 'JJ'),
#   ('nonton', 'NN'),
#   ('ga', 'NN'),
#   ('nih', 'NN')],
#  [('장미만', 'NN')],
#  [('Lisa', 'NNP'), ('est', 'JJS'), ('très', 'NN'), ('adorable', 'JJ')],
#  [('Wow', 'NN')],
#  [('Find', 'NNP'),
#   ('someone', 'NN'),
#   ('who', 'WP'),
#   ('looks', 'VBZ'),
#   ('at', 'IN'),
#   ('you', 'PRP'),
#   ('like', 'VBP'),
#   ('Rose', 'JJ'),
#   ('looks', 'NNS'),
#   ('at', 'IN'),
#   ('Toast', 'NNP')],
#  [('LOVE', 'NNP'),
#   ('HOW', 'NNP'),
#   ('CHAEYOUNG', 'NNP'),
#   ('JUST', 'NNP'),
#   ('CASUALLY', 'NNP'),
#   ('SWITCHES', 'NNP'),
#   ('BETWEEN', 'NNP'),
#   ('KOREAN', 'NNP'),
#   ('AND', 'NNP'),
#   ('ENGLISH', 'NNP')],
#  [('Jisoo', 'NNP'),
#   ('look', 'VBP'),
#   ('like', 'IN'),
#   ('baby', 'NN'),
#   ('and', 'CC'),
#   ('cute', 'NN')],
#  [('remember', 'VB'),
#   ('watching', 'VBG'),
#   ('bp', 'JJ'),
#   ('house', 'NN'),
#   ('during', 'IN'),
#   ('late', 'JJ'),
#   ('summer', 'NN'),
#   ('nights', 'NNS'),
#   ('with', 'IN'),
#   ('not', 'RB'),
#   ('care', 'VB'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('world', 'NN'),
#   ('no', 'DT'),
#   ('academic', 'JJ'),
#   ('pressure', 'NN'),
#   ('no', 'DT'),
#   ('stress', 'NN'),
#   ('the', 'DT'),
#   ('whole', 'JJ'),
#   ('house', 'NN'),
#   ('was', 'VBD'),
#   ('asleep', 'RB'),
#   ('was', 'VBD'),
#   ('watching', 'VBG'),
#   ('this', 'DT'),
#   ('It', 'PRP'),
#   ('so', 'RB'),
#   ('nostalgic', 'JJ'),
#   ('and', 'CC'),
#   ('wish', 'NN'),
#   ('could', 'MD'),
#   ('go', 'VB'),
#   ('back', 'RB')],
#  [('00', 'CD'),
#   ('Me', 'NNP'),
#   ('LITERALLY', 'NNP'),
#   ('CANT', 'NNP'),
#   ('GET', 'NNP'),
#   ('OVER', 'NNP'),
#   ('JISOO', 'NNP'),
#   ('CUTE', 'NNP'),
#   ('VOICE', 'NNP')],
#  [('Jisoo', 'NNP'),
#   ('sayin', 'NN'),
#   ('Finally', 'NNP'),
#   ('found', 'VBD'),
#   ('something', 'NN'),
#   ('good', 'JJ'),
#   ('at', 'IN'),
#   ('it', 'PRP'),
#   ('breaks', 'VB'),
#   ('my', 'PRP$'),
#   ('heart', 'NN'),
#   ('Jisooni', 'NNP'),
#   ('you', 'PRP'),
#   ('re', 'VBP'),
#   ('more', 'JJR'),
#   ('than', 'IN'),
#   ('enough', 'IN'),
#   ('We', 'PRP'),
#   ('appreciate', 'VBP'),
#   ('all', 'DT'),
#   ('your', 'PRP$'),
#   ('efforts', 'NNS'),
#   ('Fighting', 'VBG')],
#  [('Jisoo', 'NNP'),
#   ('must', 'MD'),
#   ('be', 'VB'),
#   ('really', 'RB'),
#   ('hate', 'JJ'),
#   ('shopping', 'NN')],
#  [('블랙핑크', 'JJ'),
#   ('너무', 'NNP'),
#   ('귀여워요', 'NNP'),
#   ('여러분', 'NNP'),
#   ('너무', 'NNP'),
#   ('보고', 'NNP'),
#   ('싶어요', 'VBD'),
#   ('2025년에', 'CD'),
#   ('누구세요', 'NN')],
#  [('Jisoo', 'NNP'),
#   ('is', 'VBZ'),
#   ('very', 'RB'),
#   ('cute', 'JJ'),
#   ('Jennie', 'NNP'),
#   ('is', 'VBZ'),
#   ('gentle', 'JJ'),
#   ('Rosé', 'NNP'),
#   ('always', 'RB'),
#   ('gets', 'VBZ'),
#   ('along', 'IN'),
#   ('with', 'IN'),
#   ('people', 'NNS'),
#   ('Lisa', 'NNP'),
#   ('is', 'VBZ'),
#   ('happy', 'JJ')],
#  [('jisoo', 'NN'),
#   ('sounds', 'VBZ'),
#   ('so', 'RB'),
#   ('cute', 'JJ'),
#   ('with', 'IN'),
#   ('helium', 'NN'),
#   ('like', 'IN'),
#   ('cute', 'NN'),
#   ('chipmunk', 'NN')],
#  [('Anyeong', 'NNP'),
#   ('anyeong', 'RB'),
#   ('Jisoo', 'NNP'),
#   ('yah', 'NNP'),
#   ('So', 'NNP'),
#   ('cute', 'NN')],
#  [('when', 'WRB'),
#   ('jisoo', 'NNS'),
#   ('have', 'VBP'),
#   ('bangs', 'NNS'),
#   ('she', 'PRP'),
#   ('look', 'VBD'),
#   ('even', 'RB'),
#   ('more', 'RBR'),
#   ('cute', 'JJ')],
#  [('Coment', 'NNP'),
#   ('ohtres', 'VBZ'),
#   ('99', 'CD'),
#   ('00', 'CD'),
#   ('Jisso', 'NNP'),
#   ('Cute', 'NNP'),
#   ('great', 'JJ'),
#   ('Love', 'NNP'),
#   ('you', 'PRP')],
#  [('Jisoo', 'NNP'),
#   ('and', 'CC'),
#   ('jennie', 'NN'),
#   ('making', 'VBG'),
#   ('cute', 'JJ'),
#   ('voices', 'NNS'),
#   ('lisa', 'VBP'),
#   ('speaking', 'VBG'),
#   ('in', 'IN'),
#   ('english', 'JJ'),
#   ('Rose', 'NNP'),
#   ('adorable', 'JJ'),
#   ('reactions', 'NNS'),
#   ('on', 'IN'),
#   ('her', 'PRP$'),
#   ('toast', 'NN'),
#   ('bread', 'NN'),
#   ('and', 'CC'),
#   ('channie', 'NN'),
#   ('sweet', 'JJ'),
#   ('moments', 'NNS'),
#   ('THERE', 'EX'),
#   ('are', 'VBP'),
#   ('so', 'RB'),
#   ('precious', 'JJ')],
#  [('Who', 'WP'),
#   ('here', 'RB'),
#   ('after', 'IN'),
#   ('hearing', 'VBG'),
#   ('blackpink', 'NN'),
#   ('sing', 'VBG'),
#   ('jisoo', 'JJ'),
#   ('helium', 'NN'),
#   ('song', 'NN'),
#   ('after', 'IN'),
#   ('years', 'NNS')],
#  [('In', 'IN'),
#   ('blackpink', 'NN'),
#   ('debut', 'NN'),
#   ('days', 'NNS'),
#   ('they', 'PRP'),
#   ('are', 'VBP'),
#   ('all', 'DT'),
#   ('so', 'RB'),
#   ('cute', 'JJ')],
#  [('37', 'CD'),
#   ('When', 'WRB'),
#   ('Jisoo', 'NNP'),
#   ('says', 'VBZ'),
#   ('goodbye', 'NN'),
#   ('to', 'TO'),
#   ('the', 'DT'),
#   ('balloon', 'NN')],
#  [('ROSE', 'NNP'),
#   ('BEING', 'NNP'),
#   ('HUNGRY', 'NNP'),
#   ('WAS', 'NNP'),
#   ('THE', 'NNP'),
#   ('CUTEST', 'NNP'),
#   ('THING', 'NNP'),
#   ('VE', 'NNP'),
#   ('EVER', 'NNP'),
#   ('SEEN', 'NNP'),
#   ('UGHH', 'NNP')],
#  [('00', 'CD'),
#   ('stan', 'JJ'),
#   ('year', 'NN'),
#   ('old', 'JJ'),
#   ('kids', 'NNS')],
#  [('2025년', 'CD'),
#   ('1월', 'CD'),
#   ('2일', 'CD'),
#   ('블랙핑크', 'NN'),
#   ('지순', 'NN'),
#   ('팬사랑', 'NN')],
#  [('52', 'CD'), ('aww', 'NNS'), ('so', 'RB'), ('cute', 'JJ')],
#  [('Kuku', 'NNP'),
#   ('is', 'VBZ'),
#   ('santa', 'JJ'),
#   ('clause', 'NN'),
#   ('sooooo', 'VBD'),
#   ('cute', 'JJ'),
#   ('kuku', 'NN')],
#  [('Anyone', 'NN'), ('else', 'RB'), ('in', 'IN'), ('2026', 'CD')],
#  [('swear', 'NN'),
#   ('rose', 'VBD'),
#   ('is', 'VBZ'),
#   ('The', 'DT'),
#   ('Cute', 'NNP'),
#   ('st', 'NN'),
#   ('foodie', 'NN'),
#   ('have', 'VBP'),
#   ('Seen', 'NNP'),
#   ('her', 'PRP$'),
#   ('Love', 'NNP'),
#   ('for', 'IN'),
#   ('Food', 'NNP'),
#   ('Is', 'NNP'),
#   ('just', 'RB'),
#   ('adorable', 'JJ')],
#  [('ilove', 'VB'), ('you', 'PRP'), ('black', 'JJ'), ('pink', 'VB')],
#  [('Rose', 'NNP'), ('is', 'VBZ'), ('so', 'RB'), ('cute', 'JJ')],
#  [('love', 'VB'), ('black', 'JJ'), ('pink', 'NN')],
#  [('Woooooooow', 'NN')],
#  [('rose', 'VBD')],
#  [('am', 'VBP'),
#   ('here', 'RB'),
#   ('to', 'TO'),
#   ('re', 'VB'),
#   ('watch', 'VB'),
#   ('my', 'PRP$'),
#   ('unnies', 'NNS')],
#  [('it', 'PRP'),
#   ('was', 'VBD'),
#   ('an', 'DT'),
#   ('abandoned', 'VBN'),
#   ('house', 'NN'),
#   ('so', 'IN'),
#   ('sad', 'JJ')],
#  [('2026', 'CD'), ('Love', 'NNP'), ('You', 'PRP'), ('Blackpink', 'VBP')],
#  [('59', 'CD'),
#   ('Jisoo', 'NNP'),
#   ('Voice', 'NNP'),
#   ('so', 'RB'),
#   ('sweet', 'JJ')],
#  [('Ohhh', 'NNP'),
#   ('jisoo', 'NN'),
#   ('voice', 'NN'),
#   ('so', 'RB'),
#   ('cute', 'JJ')],
#  [('from', 'IN'),
#   ('Türkiye', 'NNP'),
#   ('but', 'CC'),
#   ('love', 'VBP'),
#   ('you', 'PRP'),
#   ('blackpink', 'VBP')],
#  [('Jisoo', 'NNP'), ('face', 'NN'), ('asleep', 'NN')],
#  [('Rosu', 'NNP'),
#   ('jichu', 'NN'),
#   ('lisuu', 'NN'),
#   ('jennu', 'NN'),
#   ('Black', 'NNP'),
#   ('pink', 'NN')],
#  [('Ay', 'NNP'), ('que', 'NN'), ('tiernaaaas', 'NN')],
#  [('2026', 'CD')],
#  [('Blackpink', 'NNP'), ('Is', 'VBZ'), ('cuteeee', 'JJ')],
#  [('영상이', 'JJ'), ('너무', 'NNP'), ('좋았어요', 'NN')],
#  [('love', 'NN'), ('lisa', 'NN')],
#  [('Myyyyyyy', 'NN')],
#  [('Aniong', 'NNP'),
#   ('aniong', 'RB'),
#   ('naeun', 'RB'),
#   ('jisoo', 'JJ'),
#   ('yaaaa', 'NN'),
#   ('sooo', 'NN'),
#   ('cuteeee', 'NN')],
#  [('Hello', 'NN')],
#  [('Happy', 'JJ'),
#   ('birthday', 'NN'),
#   ('to', 'TO'),
#   ('you', 'PRP'),
#   ('Lisa', 'VB')],
#  [('Rosie', 'NNP'),
#   ('so', 'RB'),
#   ('pretty', 'RB'),
#   ('like', 'IN'),
#   ('angel', 'NN'),
#   ('and', 'CC'),
#   ('Lisa', 'NNP'),
#   ('Jennie', 'NNP'),
#   ('Jisoo', 'NNP')],
#  [('Hi', 'NNP'), ('Lisa', 'NNP')],
#  [('Ekonomine', 'NNP'),
#   ('perbaiki', 'NN'),
#   ('adi', 'NN'),
#   ('dan', 'NN'),
#   ('jiso', 'NN')],
#  [('hola', 'NN'),
#   ('soy', 'NN'),
#   ('Evelin', 'NNP'),
#   ('nueva', 'CC'),
#   ('subcritora', 'JJ'),
#   ('soy', 'NN'),
#   ('la', 'NN'),
#   ('fans', 'NNS'),
#   ('numero', 'VBP'),
#   ('de', 'IN'),
#   ('blacpik', 'FW'),
#   ('me', 'PRP'),
#   ('gusta', 'JJ'),
#   ('su', 'NN'),
#   ('musica', 'NN'),
#   ('mi', 'NN'),
#   ('mayor', 'NN'),
#   ('sueño', 'NN'),
#   ('es', 'NN'),
#   ('ir', 'NN'),
#   ('sus', 'NN'),
#   ('konsi', 'NN'),
#   ('ertos', 'NN')],
#  [('นค', 'JJ'), ('ดถ', 'NNP'), ('งพวกเขา', 'NN')],
#  [('nan', 'NN')],
#  [('2026', 'CD')],
#  [('JISOO', 'NNP'), ('tooooo', 'NN'), ('cuteeee', 'NN')],
#  [('can', 'MD'),
#   ('understand', 'VB'),
#   ('koreanbut', 'VB'),
#   ('seen', 'VBN'),
#   ('with', 'IN'),
#   ('spirit', 'NN')],
#  [('블랙핑크', 'JJ'), ('시애틀', 'NNP'), ('레미', 'NN')],
#  [('love', 'VB'), ('black', 'JJ'), ('pink', 'NN'), ('welcome', 'NN')],
#  [('Jennie', 'NNP'), ('is', 'VBZ'), ('cute', 'JJ')],
#  [('11', 'CD'), ('39', 'CD')],
#  [('Rose', 'NNP'), ('is', 'VBZ'), ('my', 'PRP$'), ('bias', 'NN')],
#  [('Rose', 'VB')],
#  [('In', 'IN'),
#   ('blackpink', 'NN'),
#   ('debut', 'NN'),
#   ('days', 'NNS'),
#   ('they', 'PRP'),
#   ('are', 'VBP'),
#   ('all', 'DT'),
#   ('so', 'RB'),
#   ('cute', 'JJ')],
#  [('BLACKPİNK', 'NNP'), ('İN', 'NNP'), ('YOUR', 'NNP'), ('AREA', 'NNP')],
#  [('저는', 'JJ'), ('블랙핑크를', 'NNP'), ('너무', 'NNP'), ('좋아해요', 'NN')],
#  [('Hi', 'NN')],
#  [('Jisoo', 'NNP'),
#   ('and', 'CC'),
#   ('jennie', 'JJ'),
#   ('voice', 'NN'),
#   ('are', 'VBP'),
#   ('so', 'RB'),
#   ('cute', 'JJ')],
#  [('nan', 'NN')],
#  [('40', 'CD'), ('the', 'DT'), ('jisoo', 'NN'), ('scream', 'NN')],
#  [('nan', 'NN')],
#  [('Lisa', 'NNP'), ('so', 'RB'), ('cuuuuuuuuuuuute', 'JJ')],
#  [('wish', 'NN'), ('could', 'MD'), ('visit', 'VB'), ('them', 'PRP')],
#  [('34', 'CD'), ('36', 'CD')],
#  [('love', 'NN'), ('you', 'PRP'), ('black', 'JJ'), ('pink', 'VB')],
#  [('Please', 'NNP'),
#   ('give', 'VB'),
#   ('me', 'PRP'),
#   ('your', 'PRP$'),
#   ('phone', 'NN'),
#   ('number', 'NN'),
#   ('all', 'DT')],
#  [('am', 'VBP'),
#   ('blink', 'NN'),
#   ('and', 'CC'),
#   ('like', 'IN'),
#   ('BLACKPINK', 'NNP'),
#   ('so', 'RB'),
#   ('much', 'JJ'),
#   ('BLACKPINK', 'NNP'),
#   ('forever', 'NN')],
#  [('00', 'CD'), ('is', 'VBZ'), ('so', 'RB'), ('cute', 'JJ')],
#  [('Hi', 'NNP'),
#   ('am', 'VBP'),
#   ('from', 'IN'),
#   ('India', 'NNP'),
#   ('am', 'VBP'),
#   ('is', 'VBZ'),
#   ('your', 'PRP$'),
#   ('big', 'JJ'),
#   ('fan', 'NN'),
#   ('my', 'PRP$'),
#   ('name', 'NN'),
#   ('is', 'VBZ'),
#   ('debanshi', 'JJ')],
#  [('nan', 'NN')],
#  [('Best', 'NNP'), ('House', 'NNP')],
#  [('هاي', 'NN')],
#  [('blackpink', 'NN')],
#  [('nan', 'NN')],
#  [('انيونغ', 'JJ'),
#   ('انيونغ', 'NNP'),
#   ('نانن', 'NNP'),
#   ('جيسوو', 'NNP'),
#   ('يااب', 'NNP'),
#   ('جاكي', 'NNP'),
#   ('ماني', 'NNP'),
#   ('هاني', 'NNP'),
#   ('كاني', 'NNP'),
#   ('ياااهه', 'NN')],
#  [('تشيتسووو', 'NN')],
#  [('Very', 'RB'), ('nice', 'JJ')],
#  [('blackpink', 'NN'),
#   ('que', 'NN'),
#   ('dieu', 'VBP'),
#   ('vous', 'JJ'),
#   ('accorde', 'NN'),
#   ('une', 'JJ'),
#   ('longue', 'NN'),
#   ('vie', 'NN')],
#  [('2026', 'CD')],
#  [('2026', 'CD')],
#  [('Jisoo', 'NNP'), ('very', 'RB'), ('very', 'RB'), ('cute', 'JJ')],
#  [('Ħàvé', 'JJ'), ('ńíćè', 'NNP'), ('ðáý', 'NN')],
#  [('love', 'NN'),
#   ('you', 'PRP'),
#   ('blackpinki', 'VBP'),
#   ('am', 'VBP'),
#   ('from', 'IN'),
#   ('Bangladesh', 'NNP')],
#  [('who', 'WP'),
#   ('is', 'VBZ'),
#   ('watching', 'VBG'),
#   ('after', 'IN'),
#   ('baemon', 'NN'),
#   ('house', 'NN')],
#  [('Anyone', 'NN'), ('in', 'IN'), ('2026', 'CD')],
#  [('Sooo', 'NNP'), ('cute', 'NN')],
#  [('Im', 'NN'),
#   ('from', 'IN'),
#   ('india', 'JJ'),
#   ('kerala', 'NN'),
#   ('now', 'RB'),
#   ('in', 'IN'),
#   ('uae', 'JJ'),
#   ('ras', 'NNS'),
#   ('al', 'VBP'),
#   ('khaimah', 'NN')],
#  [('Im', 'NNP'),
#   ('fan', 'NN'),
#   ('but', 'CC'),
#   ('im', 'JJ'),
#   ('soo', 'NN'),
#   ('sad', 'JJ'),
#   ('Ant', 'NNP'),
#   ('meet', 'NN'),
#   ('guys', 'NNS')],
#  [('Blackpink', 'NNP'),
#   ('fan', 'NN'),
#   ('but', 'CC'),
#   ('dont', 'NN'),
#   ('have', 'VBP'),
#   ('anything', 'NN')],
#  [('Cute', 'NNP'), ('jisoo', 'NN')],
#  [('Any', 'DT'), ('indians', 'NNS'), ('here', 'RB')],
#  [('nan', 'NN')],
#  [('hello', 'NN'), ('rob', 'NN')],
#  [('they', 'PRP'),
#   ('are', 'VBP'),
#   ('best', 'JJS'),
#   ('in', 'IN'),
#   ('cooking', 'VBG'),
#   ('too', 'RB')],
#  [('다들', 'JJ'), ('너무', 'NNP'), ('귀여워요', 'NN')],
#  [('진짜', 'JJ'), ('너무', 'NNP'), ('너무너무너무', 'NNP'), ('귀여워요', 'NN')],
#  [('Wow', 'NN')],
#  [('Jisoo', 'NNP'), ('is', 'VBZ'), ('very', 'RB'), ('cute', 'JJ')],
#  [('It', 'PRP'), ('mar', 'VBZ'), ('2026', 'CD')],
#  [('am', 'VBP'), ('your', 'PRP$'), ('biggest', 'JJS'), ('fan', 'NN')],
#  [('Like', 'IN'), ('jisoo', 'NN')],
#  [('2026', 'CD'), ('당신은', 'NN'), ('누구입니까', 'NN')],
#  [('LOVE', 'NNP'), ('YOU', 'NN')],
#  [('YEAR', 'NN')],
#  [('2026', 'CD')],
#  [('49', 'CD'),
#   ('kuma', 'NN'),
#   ('was', 'VBD'),
#   ('looking', 'VBG'),
#   ('so', 'RB'),
#   ('cute', 'JJ')],
#  [('are', 'VBP'),
#   ('any', 'DT'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('black', 'JJ'),
#   ('pink', 'NN'),
#   ('members', 'NNS'),
#   ('religious', 'JJ')],
#  [('저는', 'JJ'), ('그들을', 'NNP'), ('너무너무', 'NNP'), ('사랑해요', 'NN')],
#  [('Loveee', 'NNP'), ('babyy', 'NN'), ('Roséee', 'NNP')],
#  [('Jisoo', 'NNP'), ('so', 'RB'), ('cute', 'JJ')],
#  [('So', 'RB'), ('cool', 'JJ'), ('and', 'CC'), ('cute', 'NN')],
#  [('Black', 'NNP'), ('pink', 'NN')],
#  [('light', 'JJ'), ('pink', 'VBP'), ('color', 'NN'), ('anaconda', 'NN')],
#  [('Jennie', 'NNP'),
#   ('voice', 'NN'),
#   ('is', 'VBZ'),
#   ('so', 'RB'),
#   ('cute', 'JJ')],
#  [('Jisoo', 'NNP'),
#   ('is', 'VBZ'),
#   ('sooooo', 'JJ'),
#   ('cute', 'NN'),
#   ('She', 'PRP'),
#   ('so', 'RB'),
#   ('adorable', 'JJ')],
#  [('the', 'DT'),
#   ('way', 'NN'),
#   ('lisa', 'JJ'),
#   ('loves', 'VBZ'),
#   ('kuma', 'NN')],
#  [('OMG', 'NNP'), ('Jisoo', 'NNP')],
#  [('Jisso', 'NNP'), ('song', 'NN')],
#  [('Jisso', 'NNP'), ('song', 'NN')],
#  [('38', 'CD')],
#  [('The', 'DT'),
#   ('kuma', 'NN'),
#   ('dance', 'NN'),
#   ('so', 'IN'),
#   ('cute', 'JJ'),
#   ('and', 'CC'),
#   ('jisoos', 'JJ'),
#   ('voice', 'NN'),
#   ('so', 'RB'),
#   ('cute', 'JJ'),
#   ('eee', 'NN')],
#  [('03', 'CD'), ('04', 'CD')],
#  [('01', 'CD')],
#  [('Time', 'NNP'),
#   ('flies', 'NNS'),
#   ('still', 'RB'),
#   ('remember', 'VB'),
#   ('them', 'PRP'),
#   ('this', 'DT'),
#   ('way', 'NN')],
#  [('La', 'NNP'), ('extraño', 'VBZ'), ('tanto', 'NN')],
#  [('45', 'CD')],
#  [('Blackpink', 'NN')],
#  [('Rose', 'NNP'),
#   ('Rose', 'NNP'),
#   ('Rose', 'NNP'),
#   ('Rose', 'NNP'),
#   ('Rose', 'NNP'),
#   ('Rose', 'NNP'),
#   ('Rose', 'NNP'),
#   ('Rose', 'NNP'),
#   ('Rose', 'NNP'),
#   ('Rose', 'NNP')],
#  [('Jisso', 'NNP'),
#   ('balloon', 'NN'),
#   ('voice', 'NN'),
#   ('cute', 'NN'),
#   ('love', 'NN'),
#   ('you', 'PRP'),
#   ('ji', 'VBP')],
#  [('love', 'VB'),
#   ('jisoo', 'NN'),
#   ('and', 'CC'),
#   ('har', 'JJ'),
#   ('voice', 'NN')],
#  [('We', 'PRP'),
#   ('miss', 'VBP'),
#   ('you', 'PRP'),
#   ('Blackpink', 'VBP'),
#   ('We', 'PRP'),
#   ('re', 'VBP'),
#   ('watching', 'VBG'),
#   ('you', 'PRP'),
#   ('from', 'IN'),
#   ('2026', 'CD')],
#  [('09', 'CD'),
#   ('and', 'CC'),
#   ('Jennie', 'NNP'),
#   ('voice', 'NNP'),
#   ('too', 'RB'),
#   ('sooo', 'JJ'),
#   ('cute', 'NN')],
#  [('00', 'CD'),
#   ('Jisoo', 'NNP'),
#   ('voice', 'NN'),
#   ('is', 'VBZ'),
#   ('soooooo', 'JJ'),
#   ('cute', 'NN')],
#  [('miss', 'VB'),
#   ('the', 'DT'),
#   ('blackpink', 'NN'),
#   ('house', 'NN'),
#   ('too', 'RB'),
#   ('much', 'JJ')],
#  [('2026', 'CD')],
#  [('Blackpink', 'NNP'), ('please', 'VBD'), ('come', 'VB'), ('back', 'RB')],
#  [('Anyone', 'NN'), ('in', 'IN'), ('2026', 'CD')],
#  [('00', 'CD'),
#   ('JİSOO', 'NNP'),
#   ('İS', 'NNP'),
#   ('SO', 'NNP'),
#   ('CUTE', 'NNP')],
#  [('Lisa', 'NNP'),
#   ('has', 'VBZ'),
#   ('come', 'VBN'),
#   ('from', 'IN'),
#   ('different', 'JJ'),
#   ('world', 'NN')],
#  [('Hay', 'NN')],
#  [('안녕하세요', 'NN'), ('from', 'IN'), ('an', 'DT'), ('Indian', 'JJ')],
#  [('Merry', 'NNP'), ('christmas', 'VBZ'), ('xmas', 'NN')],
#  [('2026', 'CD'),
#   ('bye', 'NN'),
#   ('bye', 'NN'),
#   ('2025', 'CD'),
#   ('love', 'NN'),
#   ('Jisoo', 'NNP'),
#   ('Jennie', 'NNP'),
#   ('Lisa', 'NNP'),
#   ('Rose', 'NNP')],
#  [('love', 'NN'), ('you', 'PRP'), ('blackpink', 'VBP')],
#  [('Unnies', 'NNS'),
#   ('are', 'VBP'),
#   ('cooking', 'VBG'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('maknaes', 'NN')],
#  [('06', 'CD'), ('cuteJisoo', 'NN')],
#  [('This', 'DT'),
#   ('is', 'VBZ'),
#   ('my', 'PRP$'),
#   ('21th', 'JJ'),
#   ('time', 'NN'),
#   ('watching', 'VBG'),
#   ('this', 'DT')],
#  [('Las', 'NNP'),
#   ('amo', 'NN'),
#   ('blackpink', 'NN'),
#   ('soy', 'NN'),
#   ('blink', 'VBP'),
#   ('hace', 'NN'),
#   ('años', 'NN')],
#  [('جاية', 'JJ'), ('هنا', 'NNP'), ('أسترجع', 'NNP'), ('الذكريات', 'NN')],
#  [('지수의', 'JJ'), ('목소리는', 'NNP'), ('정말', 'NNP'), ('달콤해요', 'NN')],
#  [('Jisoo', 'NNP'),
#   ('voice', 'NN'),
#   ('is', 'VBZ'),
#   ('very', 'RB'),
#   ('cute', 'JJ')],
#  [('Aww', 'NNP'),
#   ('my', 'PRP$'),
#   ('cuties', 'NNS'),
#   ('love', 'VBP'),
#   ('you', 'PRP'),
#   ('all', 'DT'),
#   ('so', 'RB'),
#   ('much', 'JJ')],
#  [('buleakpinkue', 'NN'), ('love', 'VB'), ('them', 'PRP'), ('alot', 'RP')],
#  [('Jisoo', 'NNP'),
#   ('voice', 'NN'),
#   ('is', 'VBZ'),
#   ('so', 'RB'),
#   ('cute', 'JJ'),
#   ('love', 'NN'),
#   ('it', 'PRP')],
#  [('My', 'PRP$'),
#   ('brother', 'NN'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('second', 'JJ'),
#   ('male', 'NN'),
#   ('to', 'TO'),
#   ('visit', 'VB'),
#   ('the', 'DT'),
#   ('black', 'JJ'),
#   ('pink', 'NN'),
#   ('house', 'NN')],
#  [('My', 'PRP$'),
#   ('seepeg', 'NN'),
#   ('is', 'VBZ'),
#   ('eyes', 'NNS'),
#   ('you', 'PRP')],
#  [('Hi', 'NNP'),
#   ('plisss', 'NN'),
#   ('this', 'DT'),
#   ('show', 'NN'),
#   ('in', 'IN'),
#   ('Panamá', 'NNP'),
#   ('plissss', 'NN'),
#   ('love', 'NN')],
#  [('yg', 'NN'),
#   ('did', 'VBD'),
#   ('give', 'VB'),
#   ('her', 'PRP$'),
#   ('food', 'NN'),
#   ('in', 'IN'),
#   ('refersh', 'NN')],
#  [('Türkler', 'NNP'), ('burdamı', 'NN')],
#  [('love', 'NN'), ('you', 'PRP'), ('Blackpink', 'VBP')],
#  [('BLACK', 'NNP'), ('PINK', 'NNP')],
#  [('38', 'CD'),
#   ('thought', 'JJ'),
#   ('jisoo', 'NN'),
#   ('is', 'VBZ'),
#   ('kid', 'VBN')],
#  [('03', 'CD'), ('jisooooooooooo', 'NN')],
#  [('00', 'CD'), ('jisoo', 'NN'), ('helium', 'NN'), ('song', 'NN')],
#  [('05', 'CD')],
#  [('The', 'DT'),
#   ('bao', 'NN'),
#   ('bun', 'NN'),
#   ('is', 'VBZ'),
#   ('Chinese', 'JJ'),
#   ('thing', 'NN')],
#  [('watching', 'VBG'),
#   ('for', 'IN'),
#   ('the', 'DT'),
#   ('First', 'JJ'),
#   ('time', 'NN')],
#  [('love', 'NN'), ('you', 'PRP'), ('blackpink', 'VBP')],
#  [('People', 'NNS'), ('in', 'IN'), ('2026', 'CD')],
#  [('love', 'NN'), ('you', 'PRP'), ('black', 'JJ'), ('pink', 'VB')],
#  [('Kuku', 'NNP'),
#   ('is', 'VBZ'),
#   ('so', 'RB'),
#   ('cute', 'JJ'),
#   ('with', 'IN'),
#   ('Christmas', 'NNP'),
#   ('outfit', 'NN')],
#  [('The', 'DT'),
#   ('way', 'NN'),
#   ('jisoo', 'NN'),
#   ('singing', 'NN'),
#   ('After', 'IN'),
#   ('some', 'DT'),
#   ('helium', 'NN'),
#   ('become', 'VBP'),
#   ('like', 'IN'),
#   ('this', 'DT'),
#   ('ohh', 'VBZ'),
#   ('the', 'DT'),
#   ('voice', 'NN')],
#  [('Lisa', 'NNP'),
#   ('waking', 'VBG'),
#   ('up', 'RP'),
#   ('jisoo', 'NN'),
#   ('and', 'CC'),
#   ('carrying', 'VBG'),
#   ('her', 'PRP$'),
#   ('Jisoo', 'NNP'),
#   ('eyeliner', 'NN'),
#   ('messed', 'VBD'),
#   ('up', 'RP'),
#   ('brooooo', 'JJ'),
#   ('yohoooo', 'NN'),
#   ('can', 'MD'),
#   ('stop', 'VB'),
#   ('laughing', 'NN')],
#  [('Rosè', 'NNP'),
#   ('enjoying', 'VBG'),
#   ('her', 'PRP$'),
#   ('food', 'NN'),
#   ('is', 'VBZ'),
#   ('always', 'RB'),
#   ('the', 'DT'),
#   ('best', 'JJS')],
#  [('The', 'DT'),
#   ('way', 'NN'),
#   ('Rosè', 'NNP'),
#   ('enjoying', 'VBG'),
#   ('the', 'DT'),
#   ('bread', 'NN'),
#   ('they', 'PRP'),
#   ('are', 'VBP'),
#   ('so', 'RB'),
#   ('simple', 'JJ'),
#   ('and', 'CC'),
#   ('lovely', 'RB'),
#   ('Idk', 'NNP'),
#   ('how', 'WRB'),
#   ('heaters', 'NNS'),
#   ('are', 'VBP'),
#   ('hating', 'VBG'),
#   ('our', 'PRP$'),
#   ('sweeties', 'NNS'),
#   ('ll', 'VBP'),
#   ('always', 'RB'),
#   ('be', 'VB'),
#   ('grateful', 'JJ'),
#   ('for', 'IN'),
#   ('them', 'PRP'),
#   ('for', 'IN'),
#   ('making', 'VBG'),
#   ('my', 'PRP$'),
#   ('life', 'NN'),
#   ('little', 'RB'),
#   ('better', 'RBR')],
#  [('miss', 'NNS'), ('bp', 'NN')],
#  [('nan', 'NN')],
#  [('In', 'IN'),
#   ('this', 'DT'),
#   ('year', 'NN'),
#   ('was', 'VBD'),
#   ('born', 'VBN')],
#  [('nan', 'NN')],
#  [('Lisailove', 'NNP'), ('yuo', 'NN')],
#  [('Jisoo', 'NN')],
#  [('jisoo', 'NN'),
#   ('voice', 'NN'),
#   ('is', 'VBZ'),
#   ('so', 'RB'),
#   ('sweet', 'JJ')],
#  [('love', 'VB'),
#   ('how', 'WRB'),
#   ('jisoos', 'NN'),
#   ('the', 'DT'),
#   ('oldest', 'JJS'),
#   ('but', 'CC'),
#   ('acts', 'VBZ'),
#   ('like', 'IN'),
#   ('the', 'DT'),
#   ('youngest', 'JJS')],
#  [('Alguém', 'NN'), ('2026', 'CD')],
#  [('want', 'NN'), ('to', 'TO'), ('be', 'VB'), ('the', 'DT'), ('dog', 'NN')],
#  [('Dalgom', 'NNP'),
#   ('looks', 'VBZ'),
#   ('so', 'RB'),
#   ('cute', 'JJ'),
#   ('and', 'CC'),
#   ('the', 'DT'),
#   ('dog', 'NN'),
#   ('from', 'IN'),
#   ('Jennie', 'NNP'),
#   ('too', 'RB'),
#   ('forget', 'VBZ'),
#   ('the', 'DT'),
#   ('name', 'NN'),
#   ('of', 'IN'),
#   ('the', 'DT'),
#   ('dog', 'NN'),
#   ('from', 'IN'),
#   ('jennie', 'NN')],
#  [('Lisa', 'NNP'), ('and', 'CC'), ('Rose', 'NNP')],
#  [('Rosè', 'NNP'),
#   ('is', 'VBZ'),
#   ('so', 'RB'),
#   ('cute', 'JJ'),
#   ('she', 'PRP'),
#   ('is', 'VBZ'),
#   ('really', 'RB'),
#   ('cutie', 'JJ'),
#   ('patootie', 'NN')],
#  [('Jisoo', 'NNP'), ('and', 'CC'), ('Lisa', 'NNP')],
#  [('nan', 'NN')],
#  [('How', 'WRB'),
#   ('is', 'VBZ'),
#   ('comes', 'VBZ'),
#   ('in', 'IN'),
#   ('2026', 'CD')],
#  [('nan', 'NN')],
#  [('Who', 'WP'), ('is', 'VBZ'), ('in', 'IN'), ('2026', 'CD')],
#  [('Jennie', 'NNP'),
#   ('and', 'CC'),
#   ('jisoo', 'NNS'),
#   ('make', 'VBP'),
#   ('their', 'PRP$'),
#   ('voices', 'NNS'),
#   ('so', 'RB'),
#   ('cute', 'JJ'),
#   ('00', 'CD')],
#  [('Spick', 'NNP'), ('in', 'IN'), ('english', 'JJ')],
#  [('Jennie', 'NNP'),
#   ('listening', 'VBG'),
#   ('to', 'TO'),
#   ('Dua', 'NNP'),
#   ('Lipa', 'NNP'),
#   ('song', 'VBD'),
#   ('new', 'JJ'),
#   ('rules', 'NNS')],
#  [('Jisoo', 'NNP'),
#   ('wos', 'VBZ'),
#   ('so', 'RB'),
#   ('beautiful', 'JJ'),
#   ('and', 'CC'),
#   ('cute', 'NN')],
#  [('Jisoo', 'NNP'),
#   ('cute', 'JJ'),
#   ('voice', 'NN'),
#   ('melt', 'VBD'),
#   ('my', 'PRP$'),
#   ('heart', 'NN')],
#  [('2026', 'CD')],
#  [('love', 'VB'), ('all', 'DT'), ('blinks', 'NNS')],
#  [('Who', 'WP'), ('is', 'VBZ'), ('on', 'IN'), ('2026', 'CD')],
#  [('2026', 'CD'),
#   ('and', 'CC'),
#   ('am', 'VBP'),
#   ('still', 'RB'),
#   ('here', 'RB')],
#  [('2026년', 'CD'), ('사람', 'NN')],
#  [('42', 'CD'), ('Jisoo', 'NNP')],
#  [('also', 'RB'),
#   ('get', 'VB'),
#   ('jump', 'NN'),
#   ('scare', 'NN'),
#   ('when', 'WRB'),
#   ('trying', 'VBG'),
#   ('to', 'TO'),
#   ('look', 'VB'),
#   ('if', 'IN'),
#   ('the', 'DT'),
#   ('toast', 'NN'),
#   ('is', 'VBZ'),
#   ('done', 'VBN')],
#  [('love', 'NN'), ('you', 'PRP'), ('BLACKPINK', 'VBP')],
#  [('Extraño', 'NNP'), ('estos', 'NN'), ('momentos', 'NN')],
#  [('Alguém', 'NNP'), ('em', 'NN'), ('2026', 'CD'), ('aqui', 'NN')],
#  [('Anyone', 'NN'), ('from', 'IN'), ('2026', 'CD')],
#  [('love', 'NN'),
#   ('you', 'PRP'),
#   ('BLACKPINK', 'VBP'),
#   ('very', 'RB'),
#   ('much', 'JJ')],
#  [('Blinks', 'NNS'), ('2026', 'CD')],
#  [('Alguien', 'NNP'),
#   ('del', 'NN'),
#   ('2026', 'CD'),
#   ('feliz', 'NN'),
#   ('cumpleaños', 'NN'),
#   ('jisoo', 'NN')],
#  [('Who', 'WP'),
#   ('watch', 'VBP'),
#   ('this', 'DT'),
#   ('in', 'IN'),
#   ('2026', 'CD')],
#  [('Happy', 'JJ'), ('birthday', 'NN'), ('jisoo', 'NN')],
#  [('Iiliflim', 'NN')],
#  [('Eww', 'NN'), ('that', 'IN'), ('for', 'IN'), ('kidss', 'NN')],
#  [('Happy', 'JJ'), ('birthday', 'NN'), ('to', 'TO'), ('jisoo', 'VB')],
#  [('love', 'NN'), ('you', 'PRP'), ('blink', 'VBP')],
#  [('jisoo', 'VB'),
#   ('your', 'PRP$'),
#   ('Birthday', 'NNP'),
#   ('and', 'CC'),
#   ('wish', 'VB'),
#   ('you', 'PRP'),
#   ('Happy', 'JJ'),
#   ('Birthday', 'NNP')],
#  [('2026', 'CD')],
#  [('Anyone', 'NN'), ('in', 'IN'), ('2026', 'CD')],
#  [('2026', 'CD')],
#  [('안녕하세요', 'JJ'),
#   ('여러분', 'NNP'),
#   ('새해', 'NNP'),
#   ('많이', 'NNP'),
#   ('받으세요', 'NN'),
#   ('2026', 'CD')],
#  [('저는', 'JJ'), ('블랙핑크를', 'NNP'), ('좋아해요', 'NN')],
#  [('مرحبا', 'NN'), ('Love', 'NNP'), ('Rose', 'NNP'), ('you', 'PRP')],
#  [('love', 'NN'), ('you', 'PRP'), ('blakpink', 'VBP')],
#  [('හන', 'NN')],
#  [('35', 'CD'),
#   ('So', 'RB'),
#   ('rose', 'VBD'),
#   ('called', 'VBN'),
#   ('foddie', 'NN')],
#  [('그래도', 'JJ'),
#   ('셰프랍시고', 'NNP'),
#   ('겨우', 'NNP'),
#   ('샌드위치', 'NNP'),
#   ('하나를', 'NNP'),
#   ('각잡고', 'NNP'),
#   ('가르칠', 'NNP'),
#   ('있을', 'NNP'),
#   ('때가', 'NNP'),
#   ('좋았지', 'NNP'),
#   ('요즘은', 'NNP'),
#   ('감히', 'NNP'),
#   ('셰프', 'NNP'),
#   ('따위가', 'NNP'),
#   ('어딜', 'NNP'),
#   ('한남동', 'NNP'),
#   ('근처에라도', 'NNP'),
#   ('가까이', 'NNP'),
#   ('수가', 'NNP'),
#   ('있나', 'NN')],
#  [('00', 'CD'),
#   ('omg', 'JJ'),
#   ('jisoo', 'NN'),
#   ('voice', 'NN'),
#   ('is', 'VBZ'),
#   ('so', 'RB')],
#  [('Kangen', 'NNP'), ('mereka', 'NN'), ('diera', 'NN'), ('ini', 'NN')],
#  [('마디로', 'NN')],
#  [('00', 'CD'),
#   ('The', 'DT'),
#   ('voice', 'NN'),
#   ('its', 'PRP$'),
#   ('about', 'IN'),
#   ('to', 'TO'),
#   ('start', 'VB'),
#   ('2026', 'CD'),
#   ('and', 'CC'),
#   ('still', 'RB'),
#   ('remember', 'VB'),
#   ('this', 'DT')],
#  [('LOVE', 'NNP'),
#   ('JISOO', 'NNP'),
#   ('PONYTAIL', 'NNP'),
#   ('SHE', 'NNP'),
#   ('IS', 'VBZ'),
#   ('LOOKING', 'NNP'),
#   ('AS', 'NNP'),
#   ('BABY', 'NNP')],
#  [('강아지', 'JJ'), ('너무', 'NNP'), ('귀엽다', 'NN')],
#  [('40', 'CD'),
#   ('jisoo', 'NN'),
#   ('is', 'VBZ'),
#   ('looking', 'VBG'),
#   ('very', 'RB'),
#   ('cute', 'JJ')],
#  [('How', 'WRB'),
#   ('wish', 'JJ'),
#   ('there', 'EX'),
#   ('is', 'VBZ'),
#   ('subtitle', 'JJ'),
#   ('but', 'CC'),
#   ('then', 'RB'),
#   ('again', 'RB'),
#   ('HAPPY', 'NNP'),
#   ('TO', 'NNP'),
#   ('SEE', 'NNP'),
#   ('THEM', 'NNP'),
#   ('SMILING', 'NNP'),
#   ('living', 'NN'),
#   ('in', 'IN'),
#   ('normal', 'JJ'),
#   ('lifeeven', 'JJ'),
#   ('withcam', 'NN')],
#  [('BLCK', 'NNP'), ('PINK', 'NNP')],
#  [],
#  [('MISS', 'NNP'), ('BPHOUSE', 'NNP'), ('SM', 'NNP')],
#  [('It', 'PRP'),
#   ('beautiful', 'JJ'),
#   ('rosé', 'JJ'),
#   ('jisoo', 'NN'),
#   ('lisa', 'NN'),
#   ('jennie', 'NN')],
#  [('أنا', 'JJ'),
#   ('أكبر', 'NNP'),
#   ('معجبا', 'NNP'),
#   ('بكم', 'NNP'),
#   ('أحبكم', 'NNP'),
#   ('يا', 'NNP'),
#   ('بلاك', 'NNP'),
#   ('بينك', 'NN')],
#  [('크리스마스여서', 'NN'), ('와봤엉요', 'NN')],
#  [('혼자', 'JJ'), ('있는', 'NNP'), ('사람', 'NNP'), ('많아', 'NN')],
#  [('احبك', 'NN')],
#  [('yisoo', 'NNS'), ('cute', 'NN')],
#  [('คร', 'JJ'),
#   ('บท', 'NNP'),
#   ('กเป', 'NNP'),
#   ('นภาพท', 'NNP'),
#   ('ความส', 'NNP'),
#   ('ขก', 'NNP'),
#   ('นมาก', 'NNP'),
#   ('าร', 'NNP'),
#   ('กท', 'NNP'),
#   ('กคน', 'NN')],
#  [('Jisoo', 'NNP'), ('cute', 'NN')],
#  [('Who', 'WP'),
#   ('is', 'VBZ'),
#   ('Bridget', 'NNP'),
#   ('get', 'VB'),
#   ('back', 'RB'),
#   ('here', 'RB'),
#   ('Who', 'WP'),
#   ('is', 'VBZ'),
#   ('Bridget', 'NNP')],
#  [('Brown', 'NNP'), ('hair', 'NN'), ('rosé', 'NN')],
#  [('iloveeeeuuuuu', 'NN'), ('girlssss', 'NN')],
#  [('Türkümmmm', 'NN')]]

# %%
from itertools import chain
comment_list = list(chain.from_iterable(comment_list))

# %%
comment_list
# Out:
# [('19', 'CD'),
#  ('Rose', 'NNP'),
#  ('is', 'VBZ'),
#  ('confuse', 'JJ'),
#  ('ready', 'JJ'),
#  ('to', 'TO'),
#  ('sandwich', 'VB'),
#  ('07', 'CD'),
#  ('Rose', 'NNP'),
#  ('has', 'VBZ'),
#  ('really', 'RB'),
#  ('hungry', 'JJ'),
#  ('this', 'DT'),
#  ('moment', 'NN'),
#  ('04', 'CD'),
#  ('lisa', 'JJ'),
#  ('cute', 'NN'),
#  ('dance', 'NN'),
#  ('with', 'IN'),
#  ('kuma', 'NN'),
#  ('really', 'RB'),
#  ('missing', 'VBG'),
#  ('blackPINK', 'NN'),
#  ('house', 'NN'),
#  ('Anyone', 'NN'),
#  ('in', 'IN'),
#  ('2026', 'CD'),
#  ('Lv', 'NNP'),
#  ('yu', 'PRP'),
#  ('so', 'RB'),
#  ('much', 'JJ'),
#  ('my', 'PRP$'),
#  ('bp', 'JJ'),
#  ('girls', 'NNS'),
#  ('BlackPINK', 'NNP'),
#  ('in', 'IN'),
#  ('your', 'PRP$'),
#  ('area', 'NN'),
#  ('생각에는', 'JJ'),
#  ('블랙핑크를', 'NNP'),
#  ('인도에서', 'NNP'),
#  ('누가', 'NNP'),
#  ('보고', 'NNP'),
#  ('있을까요', 'NNP'),
#  ('저는', 'NNP'),
#  ('한국에서', 'NNP'),
#  ('보고', 'NNP'),
#  ('있어요', 'NN'),
#  ('Cute', 'NNP'),
#  ('jesso', 'NN'),
#  ('Jisoo', 'NNP'),
#  ('and', 'CC'),
#  ('Jennie', 'NNP'),
#  ('cute', 'JJ'),
#  ('voice', 'NN'),
#  ('melted', 'VBD'),
#  ('me', 'PRP'),
#  ('我好哦哇提出2026', '$'),
#  ('07', 'CD'),
#  ('41', 'CD'),
#  ('jisoo', 'NNS'),
#  ('so', 'RB'),
#  ('cute', 'JJ'),
#  ('Cute', 'NN'),
#  ('Who', 'WP'),
#  ('watch', 'VBP'),
#  ('this', 'DT'),
#  ('in', 'IN'),
#  ('2026', 'CD'),
#  ('rosé', 'NN'),
#  ('being', 'VBG'),
#  ('the', 'DT'),
#  ('foodie', 'NN'),
#  ('since', 'IN'),
#  ('the', 'DT'),
#  ('beginning', 'NN'),
#  ('of', 'IN'),
#  ('this', 'DT'),
#  ('episode', 'NN'),
#  ('watch', 'NN'),
#  ('in', 'IN'),
#  ('2025', 'CD'),
#  ('2026', 'CD'),
#  ('Msih', 'NNP'),
#  ('ada', 'VBD'),
#  ('yg', 'JJ'),
#  ('nonton', 'NN'),
#  ('ga', 'NN'),
#  ('nih', 'NN'),
#  ('장미만', 'NN'),
#  ('Lisa', 'NNP'),
#  ('est', 'JJS'),
#  ('très', 'NN'),
#  ('adorable', 'JJ'),
#  ('Wow', 'NN'),
#  ('Find', 'NNP'),
#  ('someone', 'NN'),
#  ('who', 'WP'),
#  ('looks', 'VBZ'),
#  ('at', 'IN'),
#  ('you', 'PRP'),
#  ('like', 'VBP'),
#  ('Rose', 'JJ'),
#  ('looks', 'NNS'),
#  ('at', 'IN'),
#  ('Toast', 'NNP'),
#  ('LOVE', 'NNP'),
#  ('HOW', 'NNP'),
#  ('CHAEYOUNG', 'NNP'),
#  ('JUST', 'NNP'),
#  ('CASUALLY', 'NNP'),
#  ('SWITCHES', 'NNP'),
#  ('BETWEEN', 'NNP'),
#  ('KOREAN', 'NNP'),
#  ('AND', 'NNP'),
#  ('ENGLISH', 'NNP'),
#  ('Jisoo', 'NNP'),
#  ('look', 'VBP'),
#  ('like', 'IN'),
#  ('baby', 'NN'),
#  ('and', 'CC'),
#  ('cute', 'NN'),
#  ('remember', 'VB'),
#  ('watching', 'VBG'),
#  ('bp', 'JJ'),
#  ('house', 'NN'),
#  ('during', 'IN'),
#  ('late', 'JJ'),
#  ('summer', 'NN'),
#  ('nights', 'NNS'),
#  ('with', 'IN'),
#  ('not', 'RB'),
#  ('care', 'VB'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('no', 'DT'),
#  ('academic', 'JJ'),
#  ('pressure', 'NN'),
#  ('no', 'DT'),
#  ('stress', 'NN'),
#  ('the', 'DT'),
#  ('whole', 'JJ'),
#  ('house', 'NN'),
#  ('was', 'VBD'),
#  ('asleep', 'RB'),
#  ('was', 'VBD'),
#  ('watching', 'VBG'),
#  ('this', 'DT'),
#  ('It', 'PRP'),
#  ('so', 'RB'),
#  ('nostalgic', 'JJ'),
#  ('and', 'CC'),
#  ('wish', 'NN'),
#  ('could', 'MD'),
#  ('go', 'VB'),
#  ('back', 'RB'),
#  ('00', 'CD'),
#  ('Me', 'NNP'),
#  ('LITERALLY', 'NNP'),
#  ('CANT', 'NNP'),
#  ('GET', 'NNP'),
#  ('OVER', 'NNP'),
#  ('JISOO', 'NNP'),
#  ('CUTE', 'NNP'),
#  ('VOICE', 'NNP'),
#  ('Jisoo', 'NNP'),
#  ('sayin', 'NN'),
#  ('Finally', 'NNP'),
#  ('found', 'VBD'),
#  ('something', 'NN'),
#  ('good', 'JJ'),
#  ('at', 'IN'),
#  ('it', 'PRP'),
#  ('breaks', 'VB'),
#  ('my', 'PRP$'),
#  ('heart', 'NN'),
#  ('Jisooni', 'NNP'),
#  ('you', 'PRP'),
#  ('re', 'VBP'),
#  ('more', 'JJR'),
#  ('than', 'IN'),
#  ('enough', 'IN'),
#  ('We', 'PRP'),
#  ('appreciate', 'VBP'),
#  ('all', 'DT'),
#  ('your', 'PRP$'),
#  ('efforts', 'NNS'),
#  ('Fighting', 'VBG'),
#  ('Jisoo', 'NNP'),
#  ('must', 'MD'),
#  ('be', 'VB'),
#  ('really', 'RB'),
#  ('hate', 'JJ'),
#  ('shopping', 'NN'),
#  ('블랙핑크', 'JJ'),
#  ('너무', 'NNP'),
#  ('귀여워요', 'NNP'),
#  ('여러분', 'NNP'),
#  ('너무', 'NNP'),
#  ('보고', 'NNP'),
#  ('싶어요', 'VBD'),
#  ('2025년에', 'CD'),
#  ('누구세요', 'NN'),
#  ('Jisoo', 'NNP'),
#  ('is', 'VBZ'),
#  ('very', 'RB'),
#  ('cute', 'JJ'),
#  ('Jennie', 'NNP'),
#  ('is', 'VBZ'),
#  ('gentle', 'JJ'),
#  ('Rosé', 'NNP'),
#  ('always', 'RB'),
#  ('gets', 'VBZ'),
#  ('along', 'IN'),
#  ('with', 'IN'),
#  ('people', 'NNS'),
#  ('Lisa', 'NNP'),
#  ('is', 'VBZ'),
#  ('happy', 'JJ'),
#  ('jisoo', 'NN'),
#  ('sounds', 'VBZ'),
#  ('so', 'RB'),
#  ('cute', 'JJ'),
#  ('with', 'IN'),
#  ('helium', 'NN'),
#  ('like', 'IN'),
#  ('cute', 'NN'),
#  ('chipmunk', 'NN'),
#  ('Anyeong', 'NNP'),
#  ('anyeong', 'RB'),
#  ('Jisoo', 'NNP'),
#  ('yah', 'NNP'),
#  ('So', 'NNP'),
#  ('cute', 'NN'),
#  ('when', 'WRB'),
#  ('jisoo', 'NNS'),
#  ('have', 'VBP'),
#  ('bangs', 'NNS'),
#  ('she', 'PRP'),
#  ('look', 'VBD'),
#  ('even', 'RB'),
#  ('more', 'RBR'),
#  ('cute', 'JJ'),
#  ('Coment', 'NNP'),
#  ('ohtres', 'VBZ'),
#  ('99', 'CD'),
#  ('00', 'CD'),
#  ('Jisso', 'NNP'),
#  ('Cute', 'NNP'),
#  ('great', 'JJ'),
#  ('Love', 'NNP'),
#  ('you', 'PRP'),
#  ('Jisoo', 'NNP'),
#  ('and', 'CC'),
#  ('jennie', 'NN'),
#  ('making', 'VBG'),
#  ('cute', 'JJ'),
#  ('voices', 'NNS'),
#  ('lisa', 'VBP'),
#  ('speaking', 'VBG'),
#  ('in', 'IN'),
#  ('english', 'JJ'),
#  ('Rose', 'NNP'),
#  ('adorable', 'JJ'),
#  ('reactions', 'NNS'),
#  ('on', 'IN'),
#  ('her', 'PRP$'),
#  ('toast', 'NN'),
#  ('bread', 'NN'),
#  ('and', 'CC'),
#  ('channie', 'NN'),
#  ('sweet', 'JJ'),
#  ('moments', 'NNS'),
#  ('THERE', 'EX'),
#  ('are', 'VBP'),
#  ('so', 'RB'),
#  ('precious', 'JJ'),
#  ('Who', 'WP'),
#  ('here', 'RB'),
#  ('after', 'IN'),
#  ('hearing', 'VBG'),
#  ('blackpink', 'NN'),
#  ('sing', 'VBG'),
#  ('jisoo', 'JJ'),
#  ('helium', 'NN'),
#  ('song', 'NN'),
#  ('after', 'IN'),
#  ('years', 'NNS'),
#  ('In', 'IN'),
#  ('blackpink', 'NN'),
#  ('debut', 'NN'),
#  ('days', 'NNS'),
#  ('they', 'PRP'),
#  ('are', 'VBP'),
#  ('all', 'DT'),
#  ('so', 'RB'),
#  ('cute', 'JJ'),
#  ('37', 'CD'),
#  ('When', 'WRB'),
#  ('Jisoo', 'NNP'),
#  ('says', 'VBZ'),
#  ('goodbye', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('balloon', 'NN'),
#  ('ROSE', 'NNP'),
#  ('BEING', 'NNP'),
#  ('HUNGRY', 'NNP'),
#  ('WAS', 'NNP'),
#  ('THE', 'NNP'),
#  ('CUTEST', 'NNP'),
#  ('THING', 'NNP'),
#  ('VE', 'NNP'),
#  ('EVER', 'NNP'),
#  ('SEEN', 'NNP'),
#  ('UGHH', 'NNP'),
#  ('00', 'CD'),
#  ('stan', 'JJ'),
#  ('year', 'NN'),
#  ('old', 'JJ'),
#  ('kids', 'NNS'),
#  ('2025년', 'CD'),
#  ('1월', 'CD'),
#  ('2일', 'CD'),
#  ('블랙핑크', 'NN'),
#  ('지순', 'NN'),
#  ('팬사랑', 'NN'),
#  ('52', 'CD'),
#  ('aww', 'NNS'),
#  ('so', 'RB'),
#  ('cute', 'JJ'),
#  ('Kuku', 'NNP'),
#  ('is', 'VBZ'),
#  ('santa', 'JJ'),
#  ('clause', 'NN'),
#  ('sooooo', 'VBD'),
#  ('cute', 'JJ'),
#  ('kuku', 'NN'),
#  ('Anyone', 'NN'),
#  ('else', 'RB'),
#  ('in', 'IN'),
#  ('2026', 'CD'),
#  ('swear', 'NN'),
#  ('rose', 'VBD'),
#  ('is', 'VBZ'),
#  ('The', 'DT'),
#  ('Cute', 'NNP'),
#  ('st', 'NN'),
#  ('foodie', 'NN'),
#  ('have', 'VBP'),
#  ('Seen', 'NNP'),
#  ('her', 'PRP$'),
#  ('Love', 'NNP'),
#  ('for', 'IN'),
#  ('Food', 'NNP'),
#  ('Is', 'NNP'),
#  ('just', 'RB'),
#  ('adorable', 'JJ'),
#  ('ilove', 'VB'),
#  ('you', 'PRP'),
#  ('black', 'JJ'),
#  ('pink', 'VB'),
#  ('Rose', 'NNP'),
#  ('is', 'VBZ'),
#  ('so', 'RB'),
#  ('cute', 'JJ'),
#  ('love', 'VB'),
#  ('black', 'JJ'),
#  ('pink', 'NN'),
#  ('Woooooooow', 'NN'),
#  ('rose', 'VBD'),
#  ('am', 'VBP'),
#  ('here', 'RB'),
#  ('to', 'TO'),
#  ('re', 'VB'),
#  ('watch', 'VB'),
#  ('my', 'PRP$'),
#  ('unnies', 'NNS'),
#  ('it', 'PRP'),
#  ('was', 'VBD'),
#  ('an', 'DT'),
#  ('abandoned', 'VBN'),
#  ('house', 'NN'),
#  ('so', 'IN'),
#  ('sad', 'JJ'),
#  ('2026', 'CD'),
#  ('Love', 'NNP'),
#  ('You', 'PRP'),
#  ('Blackpink', 'VBP'),
#  ('59', 'CD'),
#  ('Jisoo', 'NNP'),
#  ('Voice', 'NNP'),
#  ('so', 'RB'),
#  ('sweet', 'JJ'),
#  ('Ohhh', 'NNP'),
#  ('jisoo', 'NN'),
#  ('voice', 'NN'),
#  ('so', 'RB'),
#  ('cute', 'JJ'),
#  ('from', 'IN'),
#  ('Türkiye', 'NNP'),
#  ('but', 'CC'),
#  ('love', 'VBP'),
#  ('you', 'PRP'),
#  ('blackpink', 'VBP'),
#  ('Jisoo', 'NNP'),
#  ('face', 'NN'),
#  ('asleep', 'NN'),
#  ('Rosu', 'NNP'),
#  ('jichu', 'NN'),
#  ('lisuu', 'NN'),
#  ('jennu', 'NN'),
#  ('Black', 'NNP'),
#  ('pink', 'NN'),
#  ('Ay', 'NNP'),
#  ('que', 'NN'),
#  ('tiernaaaas', 'NN'),
#  ('2026', 'CD'),
#  ('Blackpink', 'NNP'),
#  ('Is', 'VBZ'),
#  ('cuteeee', 'JJ'),
#  ('영상이', 'JJ'),
#  ('너무', 'NNP'),
#  ('좋았어요', 'NN'),
#  ('love', 'NN'),
#  ('lisa', 'NN'),
#  ('Myyyyyyy', 'NN'),
#  ('Aniong', 'NNP'),
#  ('aniong', 'RB'),
#  ('naeun', 'RB'),
#  ('jisoo', 'JJ'),
#  ('yaaaa', 'NN'),
#  ('sooo', 'NN'),
#  ('cuteeee', 'NN'),
#  ('Hello', 'NN'),
#  ('Happy', 'JJ'),
#  ('birthday', 'NN'),
#  ('to', 'TO'),
#  ('you', 'PRP'),
#  ('Lisa', 'VB'),
#  ('Rosie', 'NNP'),
#  ('so', 'RB'),
#  ('pretty', 'RB'),
#  ('like', 'IN'),
#  ('angel', 'NN'),
#  ('and', 'CC'),
#  ('Lisa', 'NNP'),
#  ('Jennie', 'NNP'),
#  ('Jisoo', 'NNP'),
#  ('Hi', 'NNP'),
#  ('Lisa', 'NNP'),
#  ('Ekonomine', 'NNP'),
#  ('perbaiki', 'NN'),
#  ('adi', 'NN'),
#  ('dan', 'NN'),
#  ('jiso', 'NN'),
#  ('hola', 'NN'),
#  ('soy', 'NN'),
#  ('Evelin', 'NNP'),
#  ('nueva', 'CC'),
#  ('subcritora', 'JJ'),
#  ('soy', 'NN'),
#  ('la', 'NN'),
#  ('fans', 'NNS'),
#  ('numero', 'VBP'),
#  ('de', 'IN'),
#  ('blacpik', 'FW'),
#  ('me', 'PRP'),
#  ('gusta', 'JJ'),
#  ('su', 'NN'),
#  ('musica', 'NN'),
#  ('mi', 'NN'),
#  ('mayor', 'NN'),
#  ('sueño', 'NN'),
#  ('es', 'NN'),
#  ('ir', 'NN'),
#  ('sus', 'NN'),
#  ('konsi', 'NN'),
#  ('ertos', 'NN'),
#  ('นค', 'JJ'),
#  ('ดถ', 'NNP'),
#  ('งพวกเขา', 'NN'),
#  ('nan', 'NN'),
#  ('2026', 'CD'),
#  ('JISOO', 'NNP'),
#  ('tooooo', 'NN'),
#  ('cuteeee', 'NN'),
#  ('can', 'MD'),
#  ('understand', 'VB'),
#  ('koreanbut', 'VB'),
#  ('seen', 'VBN'),
#  ('with', 'IN'),
#  ('spirit', 'NN'),
#  ('블랙핑크', 'JJ'),
#  ('시애틀', 'NNP'),
#  ('레미', 'NN'),
#  ('love', 'VB'),
#  ('black', 'JJ'),
#  ('pink', 'NN'),
#  ('welcome', 'NN'),
#  ('Jennie', 'NNP'),
#  ('is', 'VBZ'),
#  ('cute', 'JJ'),
#  ('11', 'CD'),
#  ('39', 'CD'),
#  ('Rose', 'NNP'),
#  ('is', 'VBZ'),
#  ('my', 'PRP$'),
#  ('bias', 'NN'),
#  ('Rose', 'VB'),
#  ('In', 'IN'),
#  ('blackpink', 'NN'),
#  ('debut', 'NN'),
#  ('days', 'NNS'),
#  ('they', 'PRP'),
#  ('are', 'VBP'),
#  ('all', 'DT'),
#  ('so', 'RB'),
#  ('cute', 'JJ'),
#  ('BLACKPİNK', 'NNP'),
#  ('İN', 'NNP'),
#  ('YOUR', 'NNP'),
#  ('AREA', 'NNP'),
#  ('저는', 'JJ'),
#  ('블랙핑크를', 'NNP'),
#  ('너무', 'NNP'),
#  ('좋아해요', 'NN'),
#  ('Hi', 'NN'),
#  ('Jisoo', 'NNP'),
#  ('and', 'CC'),
#  ('jennie', 'JJ'),
#  ('voice', 'NN'),
#  ('are', 'VBP'),
#  ('so', 'RB'),
#  ('cute', 'JJ'),
#  ('nan', 'NN'),
#  ('40', 'CD'),
#  ('the', 'DT'),
#  ('jisoo', 'NN'),
#  ('scream', 'NN'),
#  ('nan', 'NN'),
#  ('Lisa', 'NNP'),
#  ('so', 'RB'),
#  ('cuuuuuuuuuuuute', 'JJ'),
#  ('wish', 'NN'),
#  ('could', 'MD'),
#  ('visit', 'VB'),
#  ('them', 'PRP'),
#  ('34', 'CD'),
#  ('36', 'CD'),
#  ('love', 'NN'),
#  ('you', 'PRP'),
#  ('black', 'JJ'),
#  ('pink', 'VB'),
#  ('Please', 'NNP'),
#  ('give', 'VB'),
#  ('me', 'PRP'),
#  ('your', 'PRP$'),
#  ('phone', 'NN'),
#  ('number', 'NN'),
#  ('all', 'DT'),
#  ('am', 'VBP'),
#  ('blink', 'NN'),
#  ('and', 'CC'),
#  ('like', 'IN'),
#  ('BLACKPINK', 'NNP'),
#  ('so', 'RB'),
#  ('much', 'JJ'),
#  ('BLACKPINK', 'NNP'),
#  ('forever', 'NN'),
#  ('00', 'CD'),
#  ('is', 'VBZ'),
#  ('so', 'RB'),
#  ('cute', 'JJ'),
#  ('Hi', 'NNP'),
#  ('am', 'VBP'),
#  ('from', 'IN'),
#  ('India', 'NNP'),
#  ('am', 'VBP'),
#  ('is', 'VBZ'),
#  ('your', 'PRP$'),
#  ('big', 'JJ'),
#  ('fan', 'NN'),
#  ('my', 'PRP$'),
#  ('name', 'NN'),
#  ('is', 'VBZ'),
#  ('debanshi', 'JJ'),
#  ('nan', 'NN'),
#  ('Best', 'NNP'),
#  ('House', 'NNP'),
#  ('هاي', 'NN'),
#  ('blackpink', 'NN'),
#  ('nan', 'NN'),
#  ('انيونغ', 'JJ'),
#  ('انيونغ', 'NNP'),
#  ('نانن', 'NNP'),
#  ('جيسوو', 'NNP'),
#  ('يااب', 'NNP'),
#  ('جاكي', 'NNP'),
#  ('ماني', 'NNP'),
#  ('هاني', 'NNP'),
#  ('كاني', 'NNP'),
#  ('ياااهه', 'NN'),
#  ('تشيتسووو', 'NN'),
#  ('Very', 'RB'),
#  ('nice', 'JJ'),
#  ('blackpink', 'NN'),
#  ('que', 'NN'),
#  ('dieu', 'VBP'),
#  ('vous', 'JJ'),
#  ('accorde', 'NN'),
#  ('une', 'JJ'),
#  ('longue', 'NN'),
#  ('vie', 'NN'),
#  ('2026', 'CD'),
#  ('2026', 'CD'),
#  ('Jisoo', 'NNP'),
#  ('very', 'RB'),
#  ('very', 'RB'),
#  ('cute', 'JJ'),
#  ('Ħàvé', 'JJ'),
#  ('ńíćè', 'NNP'),
#  ('ðáý', 'NN'),
#  ('love', 'NN'),
#  ('you', 'PRP'),
#  ('blackpinki', 'VBP'),
#  ('am', 'VBP'),
#  ('from', 'IN'),
#  ('Bangladesh', 'NNP'),
#  ('who', 'WP'),
#  ('is', 'VBZ'),
#  ('watching', 'VBG'),
#  ('after', 'IN'),
#  ('baemon', 'NN'),
#  ('house', 'NN'),
#  ('Anyone', 'NN'),
#  ('in', 'IN'),
#  ('2026', 'CD'),
#  ('Sooo', 'NNP'),
#  ('cute', 'NN'),
#  ('Im', 'NN'),
#  ('from', 'IN'),
#  ('india', 'JJ'),
#  ('kerala', 'NN'),
#  ('now', 'RB'),
#  ('in', 'IN'),
#  ('uae', 'JJ'),
#  ('ras', 'NNS'),
#  ('al', 'VBP'),
#  ('khaimah', 'NN'),
#  ('Im', 'NNP'),
#  ('fan', 'NN'),
#  ('but', 'CC'),
#  ('im', 'JJ'),
#  ('soo', 'NN'),
#  ('sad', 'JJ'),
#  ('Ant', 'NNP'),
#  ('meet', 'NN'),
#  ('guys', 'NNS'),
#  ('Blackpink', 'NNP'),
#  ('fan', 'NN'),
#  ('but', 'CC'),
#  ('dont', 'NN'),
#  ('have', 'VBP'),
#  ('anything', 'NN'),
#  ('Cute', 'NNP'),
#  ('jisoo', 'NN'),
#  ('Any', 'DT'),
#  ('indians', 'NNS'),
#  ('here', 'RB'),
#  ('nan', 'NN'),
#  ('hello', 'NN'),
#  ('rob', 'NN'),
#  ('they', 'PRP'),
#  ('are', 'VBP'),
#  ('best', 'JJS'),
#  ('in', 'IN'),
#  ('cooking', 'VBG'),
#  ('too', 'RB'),
#  ('다들', 'JJ'),
#  ('너무', 'NNP'),
#  ('귀여워요', 'NN'),
#  ('진짜', 'JJ'),
#  ('너무', 'NNP'),
#  ('너무너무너무', 'NNP'),
#  ('귀여워요', 'NN'),
#  ('Wow', 'NN'),
#  ('Jisoo', 'NNP'),
#  ('is', 'VBZ'),
#  ('very', 'RB'),
#  ('cute', 'JJ'),
#  ('It', 'PRP'),
#  ('mar', 'VBZ'),
#  ('2026', 'CD'),
#  ('am', 'VBP'),
#  ('your', 'PRP$'),
#  ('biggest', 'JJS'),
#  ('fan', 'NN'),
#  ('Like', 'IN'),
#  ('jisoo', 'NN'),
#  ('2026', 'CD'),
#  ('당신은', 'NN'),
#  ('누구입니까', 'NN'),
#  ('LOVE', 'NNP'),
#  ('YOU', 'NN'),
#  ('YEAR', 'NN'),
#  ('2026', 'CD'),
#  ('49', 'CD'),
#  ('kuma', 'NN'),
#  ('was', 'VBD'),
#  ('looking', 'VBG'),
#  ('so', 'RB'),
#  ('cute', 'JJ'),
#  ('are', 'VBP'),
#  ('any', 'DT'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('black', 'JJ'),
#  ('pink', 'NN'),
#  ('members', 'NNS'),
#  ('religious', 'JJ'),
#  ('저는', 'JJ'),
#  ('그들을', 'NNP'),
#  ('너무너무', 'NNP'),
#  ('사랑해요', 'NN'),
#  ('Loveee', 'NNP'),
#  ('babyy', 'NN'),
#  ('Roséee', 'NNP'),
#  ('Jisoo', 'NNP'),
#  ('so', 'RB'),
#  ('cute', 'JJ'),
#  ('So', 'RB'),
#  ('cool', 'JJ'),
#  ('and', 'CC'),
#  ('cute', 'NN'),
#  ('Black', 'NNP'),
#  ('pink', 'NN'),
#  ('light', 'JJ'),
#  ('pink', 'VBP'),
#  ('color', 'NN'),
#  ('anaconda', 'NN'),
#  ('Jennie', 'NNP'),
#  ('voice', 'NN'),
#  ('is', 'VBZ'),
#  ('so', 'RB'),
#  ('cute', 'JJ'),
#  ('Jisoo', 'NNP'),
#  ('is', 'VBZ'),
#  ('sooooo', 'JJ'),
#  ('cute', 'NN'),
#  ('She', 'PRP'),
#  ('so', 'RB'),
#  ('adorable', 'JJ'),
#  ('the', 'DT'),
#  ('way', 'NN'),
#  ('lisa', 'JJ'),
#  ('loves', 'VBZ'),
#  ('kuma', 'NN'),
#  ('OMG', 'NNP'),
#  ('Jisoo', 'NNP'),
#  ('Jisso', 'NNP'),
#  ('song', 'NN'),
#  ('Jisso', 'NNP'),
#  ('song', 'NN'),
#  ('38', 'CD'),
#  ('The', 'DT'),
#  ('kuma', 'NN'),
#  ('dance', 'NN'),
#  ('so', 'IN'),
#  ('cute', 'JJ'),
#  ('and', 'CC'),
#  ('jisoos', 'JJ'),
#  ('voice', 'NN'),
#  ('so', 'RB'),
#  ('cute', 'JJ'),
#  ('eee', 'NN'),
#  ('03', 'CD'),
#  ('04', 'CD'),
#  ('01', 'CD'),
#  ('Time', 'NNP'),
#  ('flies', 'NNS'),
#  ('still', 'RB'),
#  ('remember', 'VB'),
#  ('them', 'PRP'),
#  ('this', 'DT'),
#  ('way', 'NN'),
#  ('La', 'NNP'),
#  ('extraño', 'VBZ'),
#  ('tanto', 'NN'),
#  ('45', 'CD'),
#  ('Blackpink', 'NN'),
#  ('Rose', 'NNP'),
#  ('Rose', 'NNP'),
#  ('Rose', 'NNP'),
#  ('Rose', 'NNP'),
#  ('Rose', 'NNP'),
#  ('Rose', 'NNP'),
#  ('Rose', 'NNP'),
#  ('Rose', 'NNP'),
#  ('Rose', 'NNP'),
#  ('Rose', 'NNP'),
#  ('Jisso', 'NNP'),
#  ('balloon', 'NN'),
#  ('voice', 'NN'),
#  ('cute', 'NN'),
#  ('love', 'NN'),
#  ('you', 'PRP'),
#  ('ji', 'VBP'),
#  ('love', 'VB'),
#  ('jisoo', 'NN'),
#  ('and', 'CC'),
#  ('har', 'JJ'),
#  ('voice', 'NN'),
#  ('We', 'PRP'),
#  ('miss', 'VBP'),
#  ('you', 'PRP'),
#  ('Blackpink', 'VBP'),
#  ('We', 'PRP'),
#  ('re', 'VBP'),
#  ('watching', 'VBG'),
#  ('you', 'PRP'),
#  ('from', 'IN'),
#  ('2026', 'CD'),
#  ('09', 'CD'),
#  ('and', 'CC'),
#  ('Jennie', 'NNP'),
#  ('voice', 'NNP'),
#  ('too', 'RB'),
#  ('sooo', 'JJ'),
#  ('cute', 'NN'),
#  ('00', 'CD'),
#  ('Jisoo', 'NNP'),
#  ('voice', 'NN'),
#  ('is', 'VBZ'),
#  ('soooooo', 'JJ'),
#  ('cute', 'NN'),
#  ('miss', 'VB'),
#  ('the', 'DT'),
#  ('blackpink', 'NN'),
#  ('house', 'NN'),
#  ('too', 'RB'),
#  ('much', 'JJ'),
#  ('2026', 'CD'),
#  ('Blackpink', 'NNP'),
#  ('please', 'VBD'),
#  ('come', 'VB'),
#  ('back', 'RB'),
#  ('Anyone', 'NN'),
#  ('in', 'IN'),
#  ('2026', 'CD'),
#  ('00', 'CD'),
#  ('JİSOO', 'NNP'),
#  ('İS', 'NNP'),
#  ('SO', 'NNP'),
#  ('CUTE', 'NNP'),
#  ('Lisa', 'NNP'),
#  ('has', 'VBZ'),
#  ('come', 'VBN'),
#  ('from', 'IN'),
#  ('different', 'JJ'),
#  ('world', 'NN'),
#  ('Hay', 'NN'),
#  ('안녕하세요', 'NN'),
#  ('from', 'IN'),
#  ('an', 'DT'),
#  ('Indian', 'JJ'),
#  ('Merry', 'NNP'),
#  ('christmas', 'VBZ'),
#  ('xmas', 'NN'),
#  ('2026', 'CD'),
#  ('bye', 'NN'),
#  ('bye', 'NN'),
#  ('2025', 'CD'),
#  ('love', 'NN'),
#  ('Jisoo', 'NNP'),
#  ('Jennie', 'NNP'),
#  ('Lisa', 'NNP'),
#  ('Rose', 'NNP'),
#  ('love', 'NN'),
#  ('you', 'PRP'),
#  ('blackpink', 'VBP'),
#  ('Unnies', 'NNS'),
#  ('are', 'VBP'),
#  ('cooking', 'VBG'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('maknaes', 'NN'),
#  ('06', 'CD'),
#  ('cuteJisoo', 'NN'),
#  ('This', 'DT'),
#  ('is', 'VBZ'),
#  ('my', 'PRP$'),
#  ('21th', 'JJ'),
#  ('time', 'NN'),
#  ('watching', 'VBG'),
#  ('this', 'DT'),
#  ('Las', 'NNP'),
#  ('amo', 'NN'),
#  ('blackpink', 'NN'),
#  ('soy', 'NN'),
#  ('blink', 'VBP'),
#  ('hace', 'NN'),
#  ('años', 'NN'),
#  ('جاية', 'JJ'),
#  ('هنا', 'NNP'),
#  ('أسترجع', 'NNP'),
#  ('الذكريات', 'NN'),
#  ('지수의', 'JJ'),
#  ('목소리는', 'NNP'),
#  ('정말', 'NNP'),
#  ('달콤해요', 'NN'),
#  ('Jisoo', 'NNP'),
#  ('voice', 'NN'),
#  ('is', 'VBZ'),
#  ('very', 'RB'),
#  ('cute', 'JJ'),
#  ('Aww', 'NNP'),
#  ('my', 'PRP$'),
#  ('cuties', 'NNS'),
#  ('love', 'VBP'),
#  ('you', 'PRP'),
#  ('all', 'DT'),
#  ('so', 'RB'),
#  ('much', 'JJ'),
#  ('buleakpinkue', 'NN'),
#  ('love', 'VB'),
#  ('them', 'PRP'),
#  ('alot', 'RP'),
#  ('Jisoo', 'NNP'),
#  ('voice', 'NN'),
#  ('is', 'VBZ'),
#  ('so', 'RB'),
#  ('cute', 'JJ'),
#  ('love', 'NN'),
#  ('it', 'PRP'),
#  ('My', 'PRP$'),
#  ('brother', 'NN'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('second', 'JJ'),
#  ('male', 'NN'),
#  ('to', 'TO'),
#  ('visit', 'VB'),
#  ('the', 'DT'),
#  ('black', 'JJ'),
#  ('pink', 'NN'),
#  ('house', 'NN'),
#  ('My', 'PRP$'),
#  ('seepeg', 'NN'),
#  ('is', 'VBZ'),
#  ('eyes', 'NNS'),
#  ('you', 'PRP'),
#  ('Hi', 'NNP'),
#  ('plisss', 'NN'),
#  ('this', 'DT'),
#  ('show', 'NN'),
#  ('in', 'IN'),
#  ('Panamá', 'NNP'),
#  ('plissss', 'NN'),
#  ('love', 'NN'),
#  ('yg', 'NN'),
#  ('did', 'VBD'),
#  ('give', 'VB'),
#  ('her', 'PRP$'),
#  ('food', 'NN'),
#  ('in', 'IN'),
#  ('refersh', 'NN'),
#  ('Türkler', 'NNP'),
#  ('burdamı', 'NN'),
#  ('love', 'NN'),
#  ('you', 'PRP'),
#  ('Blackpink', 'VBP'),
#  ('BLACK', 'NNP'),
#  ('PINK', 'NNP'),
#  ('38', 'CD'),
#  ('thought', 'JJ'),
#  ('jisoo', 'NN'),
#  ('is', 'VBZ'),
#  ('kid', 'VBN'),
#  ('03', 'CD'),
#  ('jisooooooooooo', 'NN'),
#  ('00', 'CD'),
#  ('jisoo', 'NN'),
#  ('helium', 'NN'),
#  ('song', 'NN'),
#  ('05', 'CD'),
#  ('The', 'DT'),
#  ('bao', 'NN'),
#  ('bun', 'NN'),
#  ('is', 'VBZ'),
#  ('Chinese', 'JJ'),
#  ('thing', 'NN'),
#  ('watching', 'VBG'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('First', 'JJ'),
#  ('time', 'NN'),
#  ('love', 'NN'),
#  ('you', 'PRP'),
#  ...]

# %%
import re
pattern = re.compile("NN?")
comment_nouns = [ t[0] for t in comment_list if pattern.match(t[1]) ]

# %%
comment_nouns
# Out:
# ['Rose',
#  'Rose',
#  'moment',
#  'cute',
#  'dance',
#  'kuma',
#  'blackPINK',
#  'house',
#  'Anyone',
#  'Lv',
#  'girls',
#  'BlackPINK',
#  'area',
#  '블랙핑크를',
#  '인도에서',
#  '누가',
#  '보고',
#  '있을까요',
#  '저는',
#  '한국에서',
#  '보고',
#  '있어요',
#  'Cute',
#  'jesso',
#  'Jisoo',
#  'Jennie',
#  'voice',
#  'jisoo',
#  'Cute',
#  'rosé',
#  'foodie',
#  'beginning',
#  'episode',
#  'watch',
#  'Msih',
#  'nonton',
#  'ga',
#  'nih',
#  '장미만',
#  'Lisa',
#  'très',
#  'Wow',
#  'Find',
#  'someone',
#  'looks',
#  'Toast',
#  'LOVE',
#  'HOW',
#  'CHAEYOUNG',
#  'JUST',
#  'CASUALLY',
#  'SWITCHES',
#  'BETWEEN',
#  'KOREAN',
#  'AND',
#  'ENGLISH',
#  'Jisoo',
#  'baby',
#  'cute',
#  'house',
#  'summer',
#  'nights',
#  'world',
#  'pressure',
#  'stress',
#  'house',
#  'wish',
#  'Me',
#  'LITERALLY',
#  'CANT',
#  'GET',
#  'OVER',
#  'JISOO',
#  'CUTE',
#  'VOICE',
#  'Jisoo',
#  'sayin',
#  'Finally',
#  'something',
#  'heart',
#  'Jisooni',
#  'efforts',
#  'Jisoo',
#  'shopping',
#  '너무',
#  '귀여워요',
#  '여러분',
#  '너무',
#  '보고',
#  '누구세요',
#  'Jisoo',
#  'Jennie',
#  'Rosé',
#  'people',
#  'Lisa',
#  'jisoo',
#  'helium',
#  'cute',
#  'chipmunk',
#  'Anyeong',
#  'Jisoo',
#  'yah',
#  'So',
#  'cute',
#  'jisoo',
#  'bangs',
#  'Coment',
#  'Jisso',
#  'Cute',
#  'Love',
#  'Jisoo',
#  'jennie',
#  'voices',
#  'Rose',
#  'reactions',
#  'toast',
#  'bread',
#  'channie',
#  'moments',
#  'blackpink',
#  'helium',
#  'song',
#  'years',
#  'blackpink',
#  'debut',
#  'days',
#  'Jisoo',
#  'goodbye',
#  'balloon',
#  'ROSE',
#  'BEING',
#  'HUNGRY',
#  'WAS',
#  'THE',
#  'CUTEST',
#  'THING',
#  'VE',
#  'EVER',
#  'SEEN',
#  'UGHH',
#  'year',
#  'kids',
#  '블랙핑크',
#  '지순',
#  '팬사랑',
#  'aww',
#  'Kuku',
#  'clause',
#  'kuku',
#  'Anyone',
#  'swear',
#  'Cute',
#  'st',
#  'foodie',
#  'Seen',
#  'Love',
#  'Food',
#  'Is',
#  'Rose',
#  'pink',
#  'Woooooooow',
#  'unnies',
#  'house',
#  'Love',
#  'Jisoo',
#  'Voice',
#  'Ohhh',
#  'jisoo',
#  'voice',
#  'Türkiye',
#  'Jisoo',
#  'face',
#  'asleep',
#  'Rosu',
#  'jichu',
#  'lisuu',
#  'jennu',
#  'Black',
#  'pink',
#  'Ay',
#  'que',
#  'tiernaaaas',
#  'Blackpink',
#  '너무',
#  '좋았어요',
#  'love',
#  'lisa',
#  'Myyyyyyy',
#  'Aniong',
#  'yaaaa',
#  'sooo',
#  'cuteeee',
#  'Hello',
#  'birthday',
#  'Rosie',
#  'angel',
#  'Lisa',
#  'Jennie',
#  'Jisoo',
#  'Hi',
#  'Lisa',
#  'Ekonomine',
#  'perbaiki',
#  'adi',
#  'dan',
#  'jiso',
#  'hola',
#  'soy',
#  'Evelin',
#  'soy',
#  'la',
#  'fans',
#  'su',
#  'musica',
#  'mi',
#  'mayor',
#  'sueño',
#  'es',
#  'ir',
#  'sus',
#  'konsi',
#  'ertos',
#  'ดถ',
#  'งพวกเขา',
#  'nan',
#  'JISOO',
#  'tooooo',
#  'cuteeee',
#  'spirit',
#  '시애틀',
#  '레미',
#  'pink',
#  'welcome',
#  'Jennie',
#  'Rose',
#  'bias',
#  'blackpink',
#  'debut',
#  'days',
#  'BLACKPİNK',
#  'İN',
#  'YOUR',
#  'AREA',
#  '블랙핑크를',
#  '너무',
#  '좋아해요',
#  'Hi',
#  'Jisoo',
#  'voice',
#  'nan',
#  'jisoo',
#  'scream',
#  'nan',
#  'Lisa',
#  'wish',
#  'love',
#  'Please',
#  'phone',
#  'number',
#  'blink',
#  'BLACKPINK',
#  'BLACKPINK',
#  'forever',
#  'Hi',
#  'India',
#  'fan',
#  'name',
#  'nan',
#  'Best',
#  'House',
#  'هاي',
#  'blackpink',
#  'nan',
#  'انيونغ',
#  'نانن',
#  'جيسوو',
#  'يااب',
#  'جاكي',
#  'ماني',
#  'هاني',
#  'كاني',
#  'ياااهه',
#  'تشيتسووو',
#  'blackpink',
#  'que',
#  'accorde',
#  'longue',
#  'vie',
#  'Jisoo',
#  'ńíćè',
#  'ðáý',
#  'love',
#  'Bangladesh',
#  'baemon',
#  'house',
#  'Anyone',
#  'Sooo',
#  'cute',
#  'Im',
#  'kerala',
#  'ras',
#  'khaimah',
#  'Im',
#  'fan',
#  'soo',
#  'Ant',
#  'meet',
#  'guys',
#  'Blackpink',
#  'fan',
#  'dont',
#  'anything',
#  'Cute',
#  'jisoo',
#  'indians',
#  'nan',
#  'hello',
#  'rob',
#  '너무',
#  '귀여워요',
#  '너무',
#  '너무너무너무',
#  '귀여워요',
#  'Wow',
#  'Jisoo',
#  'fan',
#  'jisoo',
#  '당신은',
#  '누구입니까',
#  'LOVE',
#  'YOU',
#  'YEAR',
#  'kuma',
#  'pink',
#  'members',
#  '그들을',
#  '너무너무',
#  '사랑해요',
#  'Loveee',
#  'babyy',
#  'Roséee',
#  'Jisoo',
#  'cute',
#  'Black',
#  'pink',
#  'color',
#  'anaconda',
#  'Jennie',
#  'voice',
#  'Jisoo',
#  'cute',
#  'way',
#  'kuma',
#  'OMG',
#  'Jisoo',
#  'Jisso',
#  'song',
#  'Jisso',
#  'song',
#  'kuma',
#  'dance',
#  'voice',
#  'eee',
#  'Time',
#  'flies',
#  'way',
#  'La',
#  'tanto',
#  'Blackpink',
#  'Rose',
#  'Rose',
#  'Rose',
#  'Rose',
#  'Rose',
#  'Rose',
#  'Rose',
#  'Rose',
#  'Rose',
#  'Rose',
#  'Jisso',
#  'balloon',
#  'voice',
#  'cute',
#  'love',
#  'jisoo',
#  'voice',
#  'Jennie',
#  'voice',
#  'cute',
#  'Jisoo',
#  'voice',
#  'cute',
#  'blackpink',
#  'house',
#  'Blackpink',
#  'Anyone',
#  'JİSOO',
#  'İS',
#  'SO',
#  'CUTE',
#  'Lisa',
#  'world',
#  'Hay',
#  '안녕하세요',
#  'Merry',
#  'xmas',
#  'bye',
#  'bye',
#  'love',
#  'Jisoo',
#  'Jennie',
#  'Lisa',
#  'Rose',
#  'love',
#  'Unnies',
#  'maknaes',
#  'cuteJisoo',
#  'time',
#  'Las',
#  'amo',
#  'blackpink',
#  'soy',
#  'hace',
#  'años',
#  'هنا',
#  'أسترجع',
#  'الذكريات',
#  '목소리는',
#  '정말',
#  '달콤해요',
#  'Jisoo',
#  'voice',
#  'Aww',
#  'cuties',
#  'buleakpinkue',
#  'Jisoo',
#  'voice',
#  'love',
#  'brother',
#  'male',
#  'pink',
#  'house',
#  'seepeg',
#  'eyes',
#  'Hi',
#  'plisss',
#  'show',
#  'Panamá',
#  'plissss',
#  'love',
#  'yg',
#  'food',
#  'refersh',
#  'Türkler',
#  'burdamı',
#  'love',
#  'BLACK',
#  'PINK',
#  'jisoo',
#  'jisooooooooooo',
#  'jisoo',
#  'helium',
#  'song',
#  'bao',
#  'bun',
#  'thing',
#  'time',
#  'love',
#  'People',
#  'love',
#  'Kuku',
#  'Christmas',
#  'outfit',
#  'way',
#  'jisoo',
#  'singing',
#  'helium',
#  'voice',
#  'Lisa',
#  'jisoo',
#  'Jisoo',
#  'eyeliner',
#  'yohoooo',
#  'laughing',
#  'Rosè',
#  'food',
#  'way',
#  'Rosè',
#  'bread',
#  'Idk',
#  'heaters',
#  'sweeties',
#  'life',
#  'miss',
#  'bp',
#  'nan',
#  'year',
#  'nan',
#  'Lisailove',
#  'yuo',
#  'Jisoo',
#  'jisoo',
#  'voice',
#  'jisoos',
#  'Alguém',
#  'want',
#  'dog',
#  'Dalgom',
#  'dog',
#  'Jennie',
#  'name',
#  'dog',
#  'jennie',
#  'Lisa',
#  'Rose',
#  'Rosè',
#  'patootie',
#  'Jisoo',
#  'Lisa',
#  'nan',
#  'nan',
#  'Jennie',
#  'jisoo',
#  'voices',
#  'Spick',
#  'Jennie',
#  'Dua',
#  'Lipa',
#  'rules',
#  'Jisoo',
#  'cute',
#  'Jisoo',
#  'voice',
#  'heart',
#  'blinks',
#  '사람',
#  'Jisoo',
#  'jump',
#  'scare',
#  'toast',
#  'love',
#  'Extraño',
#  'estos',
#  'momentos',
#  'Alguém',
#  'em',
#  'aqui',
#  'Anyone',
#  'love',
#  'Blinks',
#  'Alguien',
#  'del',
#  'feliz',
#  'cumpleaños',
#  'jisoo',
#  'birthday',
#  'jisoo',
#  'Iiliflim',
#  'Eww',
#  'kidss',
#  'birthday',
#  'love',
#  'Birthday',
#  'Birthday',
#  'Anyone',
#  '여러분',
#  '새해',
#  '많이',
#  '받으세요',
#  '블랙핑크를',
#  '좋아해요',
#  'مرحبا',
#  'Love',
#  'Rose',
#  'love',
#  'හන',
#  'foddie',
#  '셰프랍시고',
#  '겨우',
#  '샌드위치',
#  '하나를',
#  '각잡고',
#  '가르칠',
#  '있을',
#  '때가',
#  '좋았지',
#  '요즘은',
#  '감히',
#  '셰프',
#  '따위가',
#  '어딜',
#  '한남동',
#  '근처에라도',
#  '가까이',
#  '수가',
#  '있나',
#  'jisoo',
#  'voice',
#  'Kangen',
#  'mereka',
#  'diera',
#  'ini',
#  '마디로',
#  'voice',
#  'LOVE',
#  'JISOO',
#  'PONYTAIL',
#  'SHE',
#  'LOOKING',
#  'AS',
#  'BABY',
#  '너무',
#  '귀엽다',
#  'jisoo',
#  'HAPPY',
#  'TO',
#  'SEE',
#  'THEM',
#  'SMILING',
#  'living',
#  'withcam',
#  'BLCK',
#  'PINK',
#  'MISS',
#  'BPHOUSE',
#  'SM',
#  'jisoo',
#  'lisa',
#  'jennie',
#  'أكبر',
#  'معجبا',
#  'بكم',
#  'أحبكم',
#  'يا',
#  'بلاك',
#  'بينك',
#  '크리스마스여서',
#  '와봤엉요',
#  '있는',
#  '사람',
#  '많아',
#  'احبك',
#  'yisoo',
#  'cute',
#  'บท',
#  'กเป',
#  'นภาพท',
#  'ความส',
#  'ขก',
#  'นมาก',
#  'าร',
#  'กท',
#  'กคน',
#  'Jisoo',
#  'cute',
#  'Bridget',
#  'Bridget',
#  'Brown',
#  'hair',
#  'rosé',
#  'iloveeeeuuuuu',
#  'girlssss',
#  'Türkümmmm']

# %%
comment_nouns = [x.lower() for x in comment_nouns]

# %%
comment_nouns = list(map(lambda x : x.lower(), comment_nouns))

# %%
from matplotlib import font_manager, rc
font_fname = 'c:/windows/fonts/gulim.ttc'
font_name = font_manager.FontProperties(fname=font_fname).get_name()
rc('font', family=font_name)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))

from nltk import Text
comment_text = Text(comment_nouns)
comment_text.plot(50)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
# 뉴스 기사 수집
# JTBC의 뉴스 속보를 수집해서 단어와 빈수를 그래프로 표시하세요.
# https://fs.jtbc.joins.com/RSS/newsflash.xml
