# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import nltk

# %%
# nltk.download(download_dir="C:/nltk_data")

# %%
nltk.download("treebank", download_dir="C:\\nltk_data")
# Out:
# [nltk_data] Downloading package treebank to C:\nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# True

# %%
from nltk.corpus import treebank

# %%
print(treebank.fileids())
# Out:
# ['wsj_0001.mrg', 'wsj_0002.mrg', 'wsj_0003.mrg', 'wsj_0004.mrg', 'wsj_0005.mrg', 'wsj_0006.mrg', 'wsj_0007.mrg', 'wsj_0008.mrg', 'wsj_0009.mrg', 'wsj_0010.mrg', 'wsj_0011.mrg', 'wsj_0012.mrg', 'wsj_0013.mrg', 'wsj_0014.mrg', 'wsj_0015.mrg', 'wsj_0016.mrg', 'wsj_0017.mrg', 'wsj_0018.mrg', 'wsj_0019.mrg', 'wsj_0020.mrg', 'wsj_0021.mrg', 'wsj_0022.mrg', 'wsj_0023.mrg', 'wsj_0024.mrg', 'wsj_0025.mrg', 'wsj_0026.mrg', 'wsj_0027.mrg', 'wsj_0028.mrg', 'wsj_0029.mrg', 'wsj_0030.mrg', 'wsj_0031.mrg', 'wsj_0032.mrg', 'wsj_0033.mrg', 'wsj_0034.mrg', 'wsj_0035.mrg', 'wsj_0036.mrg', 'wsj_0037.mrg', 'wsj_0038.mrg', 'wsj_0039.mrg', 'wsj_0040.mrg', 'wsj_0041.mrg', 'wsj_0042.mrg', 'wsj_0043.mrg', 'wsj_0044.mrg', 'wsj_0045.mrg', 'wsj_0046.mrg', 'wsj_0047.mrg', 'wsj_0048.mrg', 'wsj_0049.mrg', 'wsj_0050.mrg', 'wsj_0051.mrg', 'wsj_0052.mrg', 'wsj_0053.mrg', 'wsj_0054.mrg', 'wsj_0055.mrg', 'wsj_0056.mrg', 'wsj_0057.mrg', 'wsj_0058.mrg', 'wsj_0059.mrg', 'wsj_0060.mrg', 'wsj_0061.mrg', 'wsj_0062.mrg', 'wsj_
# ...

# %%
treebank.sents("wsj_0001.mrg")
# Out:
# [['Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', 'Nov.', '29', '.'], ['Mr.', 'Vinken', 'is', 'chairman', 'of', 'Elsevier', 'N.V.', ',', 'the', 'Dutch', 'publishing', 'group', '.']]

# %%
wsj_0001 = treebank.sents("wsj_0001.mrg")
for line in wsj_0001:
    print(' '.join(line))
# Out:
# Pierre Vinken , 61 years old , will join the board as a nonexecutive director Nov. 29 .
# Mr. Vinken is chairman of Elsevier N.V. , the Dutch publishing group .

# %%
treebank.tagged_words("wsj_0001.mrg")
# Out:
# [('Pierre', 'NNP'), ('Vinken', 'NNP'), (',', ','), ...]

# %%
print(treebank.parsed_sents("wsj_0001.mrg")[0])
# Out:
# (S
#   (NP-SBJ
#     (NP (NNP Pierre) (NNP Vinken))
#     (, ,)
#     (ADJP (NP (CD 61) (NNS years)) (JJ old))
#     (, ,))
#   (VP
#     (MD will)
#     (VP
#       (VB join)
#       (NP (DT the) (NN board))
#       (PP-CLR (IN as) (NP (DT a) (JJ nonexecutive) (NN director)))
#       (NP-TMP (NNP Nov.) (CD 29))))
#   (. .))

# %%
nltk.download("book", download_dir="C:/nltk_data", quiet=True)
# Out:
# True

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
type(text1)
# Out:
# nltk.text.Text

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
emma = nltk.corpus.gutenberg.raw("austen-emma.txt")

# %%
print(emma[:200])
# Out:
# [Emma by Jane Austen 1816]
#
# VOLUME I
#
# CHAPTER I
#
#
# Emma Woodhouse, handsome, clever, and rich, with a comfortable home
# and happy disposition, seemed to unite some of the best blessings
# of existence; an

# %%
from nltk.tokenize import sent_tokenize

# %%
print(sent_tokenize(emma[:1000])[3])
# Out:
# Sixteen years had Miss Taylor been in Mr. Woodhouse's family,
# less as a governess than a friend, very fond of both daughters,
# but particularly of Emma.

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(emma[50:100])
# Out:
# ['Emma',
#  'Woodhouse',
#  ',',
#  'handsome',
#  ',',
#  'clever',
#  ',',
#  'and',
#  'rich',
#  ',',
#  'with',
#  'a']

# %%
from nltk.tokenize import RegexpTokenizer

# %%
ret = RegexpTokenizer("[\w]+")

# %%
ret.tokenize(emma[50:100])
# Out:
# ['Emma', 'Woodhouse', 'handsome', 'clever', 'and', 'rich', 'with', 'a']

# %%
words = ["sending", "cooking", "flies", "lives", 
         "crying", "dying"]

# %%
from nltk.stem import PorterStemmer

# %%
pst = PorterStemmer()

# %%
pst.stem(words[0])
# Out:
# 'send'

# %%
[pst.stem(w) for w in words]
# Out:
# ['send', 'cook', 'fli', 'live', 'cri', 'die']

# %%
from nltk.stem import LancasterStemmer

# %%
lst = LancasterStemmer()

# %%
[lst.stem(w) for w in words]
# Out:
# ['send', 'cook', 'fli', 'liv', 'cry', 'dying']

# %%
from nltk.stem.regexp import RegexpStemmer

# %%
rest = RegexpStemmer('ing')

# %%
[rest.stem(w) for w in words]
# Out:
# ['send', 'cook', 'flies', 'lives', 'cry', 'dy']

# %%
words2 = ['enviar', 'cocina', 'moscas', 'vidas', 
          'llorar', 'morir']

# %%
from nltk.stem.snowball import SnowballStemmer

# %%
sbst = SnowballStemmer('spanish')

# %%
[sbst.stem(w) for w in words2]
# Out:
# ['envi', 'cocin', 'mosc', 'vid', 'llor', 'mor']

# %%
words3 = ["cooking", "believes"]

# %%
from nltk.stem.wordnet import WordNetLemmatizer

# %%
wl = WordNetLemmatizer()

# %%
[wl.lemmatize(w) for w in words3]
# Out:
# ['cooking', 'belief']

# %%
[wl.lemmatize(w, pos='v') for w in words3]
# Out:
# ['cook', 'believe']

# %%
nltk.help.upenn_tagset('NNP')
# Out:
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...

# %%
nltk.help.upenn_tagset()
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
# ...

# %%
sentense = emma[50:289]

# %%
print(sentense)
# Out:
# Emma Woodhouse, handsome, clever, and rich, with a comfortable home
# and happy disposition, seemed to unite some of the best blessings
# of existence; and had lived nearly twenty-one years in the world
# with very little to distress or vex her.

# %%
from nltk.tag import pos_tag

# %%
tagged_list = pos_tag(word_tokenize(sentense))

# %%
print(tagged_list)
# Out:
# [('Emma', 'NNP'), ('Woodhouse', 'NNP'), (',', ','), ('handsome', 'NN'), (',', ','), ('clever', 'NN'), (',', ','), ('and', 'CC'), ('rich', 'JJ'), (',', ','), ('with', 'IN'), ('a', 'DT'), ('comfortable', 'JJ'), ('home', 'NN'), ('and', 'CC'), ('happy', 'JJ'), ('disposition', 'NN'), (',', ','), ('seemed', 'VBD'), ('to', 'TO'), ('unite', 'VB'), ('some', 'DT'), ('of', 'IN'), ('the', 'DT'), ('best', 'JJS'), ('blessings', 'NNS'), ('of', 'IN'), ('existence', 'NN'), (';', ':'), ('and', 'CC'), ('had', 'VBD'), ('lived', 'VBN'), ('nearly', 'RB'), ('twenty-one', 'CD'), ('years', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('world', 'NN'), ('with', 'IN'), ('very', 'RB'), ('little', 'JJ'), ('to', 'TO'), ('distress', 'VB'), ('or', 'CC'), ('vex', 'VB'), ('her', 'PRP'), ('.', '.')]

# %%
nouns_list = [ t[0] for t in tagged_list if t[1]=="NN"]

# %%
nouns_list
# Out:
# ['handsome', 'clever', 'home', 'disposition', 'existence', 'world']

# %%
import re

# %%
pattern = re.compile('NN?')

# %%
nouns_list = [t[0] for t in tagged_list 
              if pattern.match(t[1])]

# %%
nouns_list
# Out:
# ['Emma',
#  'Woodhouse',
#  'handsome',
#  'clever',
#  'home',
#  'disposition',
#  'blessings',
#  'existence',
#  'years',
#  'world']

# %%
tagged_list
# Out:
# [('Emma', 'NNP'),
#  ('Woodhouse', 'NNP'),
#  (',', ','),
#  ('handsome', 'NN'),
#  (',', ','),
#  ('clever', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('rich', 'JJ'),
#  (',', ','),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('comfortable', 'JJ'),
#  ('home', 'NN'),
#  ('and', 'CC'),
#  ('happy', 'JJ'),
#  ('disposition', 'NN'),
#  (',', ','),
#  ('seemed', 'VBD'),
#  ('to', 'TO'),
#  ('unite', 'VB'),
#  ('some', 'DT'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('best', 'JJS'),
#  ('blessings', 'NNS'),
#  ('of', 'IN'),
#  ('existence', 'NN'),
#  (';', ':'),
#  ('and', 'CC'),
#  ('had', 'VBD'),
#  ('lived', 'VBN'),
#  ('nearly', 'RB'),
#  ('twenty-one', 'CD'),
#  ('years', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('world', 'NN'),
#  ('with', 'IN'),
#  ('very', 'RB'),
#  ('little', 'JJ'),
#  ('to', 'TO'),
#  ('distress', 'VB'),
#  ('or', 'CC'),
#  ('vex', 'VB'),
#  ('her', 'PRP'),
#  ('.', '.')]

# %%
from nltk.tag import untag

# %%
untag(tagged_list)
# Out:
# ['Emma',
#  'Woodhouse',
#  ',',
#  'handsome',
#  ',',
#  'clever',
#  ',',
#  'and',
#  'rich',
#  ',',
#  'with',
#  'a',
#  'comfortable',
#  'home',
#  'and',
#  'happy',
#  'disposition',
#  ',',
#  'seemed',
#  'to',
#  'unite',
#  'some',
#  'of',
#  'the',
#  'best',
#  'blessings',
#  'of',
#  'existence',
#  ';',
#  'and',
#  'had',
#  'lived',
#  'nearly',
#  'twenty-one',
#  'years',
#  'in',
#  'the',
#  'world',
#  'with',
#  'very',
#  'little',
#  'to',
#  'distress',
#  'or',
#  'vex',
#  'her',
#  '.']

# %%
["/".join(p) for p in tagged_list]
# Out:
# ['Emma/NNP',
#  'Woodhouse/NNP',
#  ',/,',
#  'handsome/NN',
#  ',/,',
#  'clever/NN',
#  ',/,',
#  'and/CC',
#  'rich/JJ',
#  ',/,',
#  'with/IN',
#  'a/DT',
#  'comfortable/JJ',
#  'home/NN',
#  'and/CC',
#  'happy/JJ',
#  'disposition/NN',
#  ',/,',
#  'seemed/VBD',
#  'to/TO',
#  'unite/VB',
#  'some/DT',
#  'of/IN',
#  'the/DT',
#  'best/JJS',
#  'blessings/NNS',
#  'of/IN',
#  'existence/NN',
#  ';/:',
#  'and/CC',
#  'had/VBD',
#  'lived/VBN',
#  'nearly/RB',
#  'twenty-one/CD',
#  'years/NNS',
#  'in/IN',
#  'the/DT',
#  'world/NN',
#  'with/IN',
#  'very/RB',
#  'little/JJ',
#  'to/TO',
#  'distress/VB',
#  'or/CC',
#  'vex/VB',
#  'her/PRP',
#  './.']

# %%
ret = RegexpTokenizer("[\w]{2,}")

# %%
from nltk import Text

# %%
emma_text = Text(ret.tokenize(emma))

# %%
emma_text.plot(20)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
emma_text.concordance('Emma', lines=5)
# Out:
# Displaying 5 of 865 matches:
#  Emma by Jane Austen 1816 VOLUME CHAPTER E
# a by Jane Austen 1816 VOLUME CHAPTER Emma Woodhouse handsome clever and rich w
# f both daughters but particularly of Emma Between _them_ it was more the intim
# nd friend very mutually attached and Emma doing just what she liked highly est
#  by her own The real evils indeed of Emma situation were the power of having r

# %%
emma_text.similar("general")
# Out:
# love short it london time fact her which highbury and his own well him
# my hurry return vain person despair

# %%
emma_text.similar("general", 10)
# Out:
# love short it london time fact her which highbury and

# %%
emma_text.common_contexts(["general", "strong"])
# Out:
# was_expectation

# %%
emma_text.dispersion_plot(["Emma", "Knightley", "Frank",
                           "Jane", "Harriet", "Robert"])

# %%
len(emma_text)
# Out:
# 154664

# %%
len(set(emma_text))
# Out:
# 7703

# %%
len(set(emma_text)) / len(emma_text)
# Out:
# 0.04980473801272436

# %%
emma_fd = emma_text.vocab()

# %%
type(emma_fd)
# Out:
# nltk.probability.FreqDist

# %%
from nltk import FreqDist

# %%
stopwords = ["Mr.", "Mrs.", "Miss", "Mr", "Mrs", "Dear"]

# %%
emma_tokens = pos_tag(emma_text)

# %%
names_list = [t[0] for t in emma_tokens
              if t[1]=="NNP" and t[0] not in stopwords]

# %%
emma_fd_names = FreqDist(names_list)

# %%
emma_fd_names
# Out:
# FreqDist({'Emma': 833, 'Harriet': 489, 'Weston': 439, 'Knightley': 389, 'Elton': 385, 'Woodhouse': 305, 'Jane': 298, 'Fairfax': 241, 'Churchill': 223, 'Frank': 208, ...})

# %%
emma_fd_names.most_common(5)
# Out:
# [('Emma', 833),
#  ('Harriet', 489),
#  ('Weston', 439),
#  ('Knightley', 389),
#  ('Elton', 385)]

# %% [markdown]
# ## 유튜브 댓글 분석하기

# %%
import pandas as pd
# 4장에서 수집한 유튜브 댓글 데이터 파일이 있어야 합니다.
comment_df = pd.read_csv("comment.csv", encoding="utf-8-sig")
comment_df.head()
# Out:
#                         user  \
# 0            @Peachi_Panther
# 1  @estibalizblinkpareja7144
# 2           @user-xe2xs2ul5l
# 3            @myblinkies_ofc
# 4           @user-un6zc3kj7z
#
#                                              comment
# 0  5:05 Jisoo My Bias. :))))) BP Please make a se...
# 1                          Happy crishtmas Blackpink
# 2                                                Ll-
# 3                                  2024 anyone guys?
# 4                                         5:00 jisoo

# %%
from nltk.tokenize import RegexpTokenizer
ret = RegexpTokenizer(r"[\w]{2,}")
comment_df["comment"] = comment_df["comment"].map(str)
comment_tokens = comment_df["comment"].map(ret.tokenize)

# %%
comment_tokens.head()
# Out:
# 0    [05, Jisoo, My, Bias, BP, Please, make, second...
# 1                        [Happy, crishtmas, Blackpink]
# 2                                                 [Ll]
# 3                                 [2024, anyone, guys]
# 4                                          [00, jisoo]
# Name: comment, dtype: object

# %%
from nltk.tag import pos_tag
comment_tags = comment_tokens.map(pos_tag)

# %%
comment_tags.head()
# Out:
# 0    [(05, CD), (Jisoo, NNP), (My, NNP), (Bias, NNP...
# 1     [(Happy, JJ), (crishtmas, NN), (Blackpink, NNP)]
# 2                                           [(Ll, NN)]
# 3              [(2024, CD), (anyone, NN), (guys, NNS)]
# 4                              [(00, CD), (jisoo, NN)]
# Name: comment, dtype: object

# %%
comment_list = comment_tags.values.tolist()

# %%
comment_list
# Out:
# [[('05', 'CD'),
#   ('Jisoo', 'NNP'),
#   ('My', 'NNP'),
#   ('Bias', 'NNP'),
#   ('BP', 'NNP'),
#   ('Please', 'NNP'),
#   ('make', 'VB'),
#   ('second', 'JJ'),
#   ('BP', 'NNP'),
#   ('House', 'NNP'),
#   ('show', 'NN')],
#  [('Happy', 'JJ'), ('crishtmas', 'NN'), ('Blackpink', 'NNP')],
#  [('Ll', 'NN')],
#  [('2024', 'CD'), ('anyone', 'NN'), ('guys', 'NNS')],
#  [('00', 'CD'), ('jisoo', 'NN')],
#  [('so', 'RB'), ('cutejisoo', 'JJ')],
#  [('是我要求親堂姐曉蘭噴香水', 'NN')],
#  [('Aku', 'NNP'), ('merindukan', 'NN'), ('kalian', 'NN')],
#  [('Aku', 'NNP'), ('merindukan', 'NN'), ('kalian', 'NN')],
#  [('Rose', 'NNP'), ('Jennie', 'NNP'), ('Are', 'NNP'), ('Cute', 'NNP')],
#  [('안녕하세요', 'JJ'),
#   ('블랙핑크', 'NNP'),
#   ('제발', 'NNP'),
#   ('하다', 'NNP'),
#   ('콘서트', 'NNP'),
#   ('인도', 'NN')],
#  [('لیسا', 'NN'), ('خۆشمەوێی', 'NN')],
#  [('لیسا', 'NN'), ('خۆشمەوێی', 'NN')],
#  [('لیسا', 'NN'), ('خۆشمەوێی', 'NN')],
#  [('love', 'NN'), ('you', 'PRP'), ('lesa', 'VBP')],
#  [('Lisa', 'NNP'),
# ...

# %%
from itertools import chain
comment_list = list(chain.from_iterable(comment_list))

# %%
comment_list
# Out:
# [('05', 'CD'),
#  ('Jisoo', 'NNP'),
#  ('My', 'NNP'),
#  ('Bias', 'NNP'),
#  ('BP', 'NNP'),
#  ('Please', 'NNP'),
#  ('make', 'VB'),
#  ('second', 'JJ'),
#  ('BP', 'NNP'),
#  ('House', 'NNP'),
#  ('show', 'NN'),
#  ('Happy', 'JJ'),
#  ('crishtmas', 'NN'),
#  ('Blackpink', 'NNP'),
#  ('Ll', 'NN'),
#  ('2024', 'CD'),
#  ('anyone', 'NN'),
#  ('guys', 'NNS'),
#  ('00', 'CD'),
#  ('jisoo', 'NN'),
#  ('so', 'RB'),
#  ('cutejisoo', 'JJ'),
#  ('是我要求親堂姐曉蘭噴香水', 'NN'),
#  ('Aku', 'NNP'),
#  ('merindukan', 'NN'),
#  ('kalian', 'NN'),
#  ('Aku', 'NNP'),
#  ('merindukan', 'NN'),
#  ('kalian', 'NN'),
#  ('Rose', 'NNP'),
#  ('Jennie', 'NNP'),
#  ('Are', 'NNP'),
#  ('Cute', 'NNP'),
#  ('안녕하세요', 'JJ'),
#  ('블랙핑크', 'NNP'),
#  ('제발', 'NNP'),
#  ('하다', 'NNP'),
#  ('콘서트', 'NNP'),
#  ('인도', 'NN'),
#  ('لیسا', 'NN'),
#  ('خۆشمەوێی', 'NN'),
#  ('لیسا', 'NN'),
#  ('خۆشمەوێی', 'NN'),
#  ('لیسا', 'NN'),
#  ('خۆشمەوێی', 'NN'),
#  ('love', 'NN'),
#  ('you', 'PRP'),
#  ('lesa', 'VBP'),
#  ('Lisa', 'NNP'),
# ...

# %%
import re
pattern = re.compile("NN?")
comment_nouns = [ t[0] for t in comment_list if pattern.match(t[1]) ]

# %%
comment_nouns
# Out:
# ['Jisoo',
#  'My',
#  'Bias',
#  'BP',
#  'Please',
#  'BP',
#  'House',
#  'show',
#  'crishtmas',
#  'Blackpink',
#  'Ll',
#  'anyone',
#  'guys',
#  'jisoo',
#  '是我要求親堂姐曉蘭噴香水',
#  'Aku',
#  'merindukan',
#  'kalian',
#  'Aku',
#  'merindukan',
#  'kalian',
#  'Rose',
#  'Jennie',
#  'Are',
#  'Cute',
#  '블랙핑크',
#  '제발',
#  '하다',
#  '콘서트',
#  '인도',
#  'لیسا',
#  'خۆشمەوێی',
#  'لیسا',
#  'خۆشمەوێی',
#  'لیسا',
#  'خۆشمەوێی',
#  'love',
#  'Lisa',
#  'jisoo',
#  'Lisa',
#  'ROSÉ',
#  'SPOILER',
#  'QUEEN',
#  'THE',
#  'SPOT',
#  'LOL',
#  'Jennie',
#  'jisoo',
#  '그날이',
#  '크리스마스였나요',
#  'Jisoo',
#  'voice',
#  'helium',
#  'thingy',
#  'didn',
#  'Jisoo',
#  'solo',
#  '아름다운',
#  '언니들',
#  '돌아와서',
#  '즐거운',
#  '시간을',
#  '보냈으면',
#  '좋겠어요',
#  '블랙핑크',
#  '콘서트는',
#  '가본',
#  '없는데도',
#  '저는',
#  '블랙핑크를',
#  '정말',
#  '좋아해요',
#  'Jisoo',
#  'sayin',
#  'Finally',
#  'something',
#  'heart',
#  'Jisooni',
#  'efforts',
#  'CuteJisoo',
#  'Jennie',
#  'kind',
#  'people',
#  'Lisa',
# ...

# %%
comment_nouns = [x.lower() for x in comment_nouns]

# %%
comment_nouns = list(map(lambda x : x.lower(), comment_nouns))

# %%
from matplotlib import font_manager, rc
font_fname = 'c:/windows/fonts/gulim.ttc'
font_name = font_manager.FontProperties(fname=font_fname).get_name()
rc('font', family=font_name)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))

from nltk import Text
comment_text = Text(comment_nouns)
comment_text.plot(50)
# Out:
# C:\Users\KOSA\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 1604 (\N{ARABIC LETTER LAM}) missing from font(s) Gulim.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KOSA\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Matplotlib currently does not support Arabic natively.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KOSA\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 1740 (\N{ARABIC LETTER FARSI YEH}) missing from font(s) Gulim.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KOSA\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 1587 (\N{ARABIC LETTER SEEN}) missing from font(s) Gulim.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\KOSA\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 1575 (\N{ARABIC LETTER ALEF}) missing from font(s) Gulim.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# 뉴스 기사 수집
# JTBC의 뉴스 속보를 수집해서 단어와 빈수를 그래프로 표시하세요.
# https://fs.jtbc.joins.com/RSS/newsflash.xml
