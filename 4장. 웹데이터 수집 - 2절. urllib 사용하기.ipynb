# %%
import urllib.request as req
URL = "https://tomcat.apache.org"
header = {"User-Agent": "Mozilla/5.0 (iPhone)"}
request = req.Request(URL, headers=header) # request 객체를 생성함
print(request)
response = req.urlopen(URL) # 요청한 결과를 이용해서 response 객체를 생성함
print(response)
byte_data = response.read(100) # 00 바이트를 읽음, 기본값은 모든 데이터 읽음
print(byte_data)
# Out:
# <urllib.request.Request object at 0x000001CDF722CAD0>
# <http.client.HTTPResponse object at 0x000001CDF5ED4370>
# b'<!DOCTYPE html SYSTEM "about:legacy-compat">\n<html lang="en"><head><META http-equiv="Content-Type" c'

# %%
img_src = "https://tomcat.apache.org/res/images/tomcat.png"
req.urlretrieve(img_src, "tomcat.png")
# Out:
# ('tomcat.png', <http.client.HTTPMessage at 0x1cdf71ba3f0>)

# %%
import urllib
parsed_url = urllib.parse.urlparse("https://tomcat.apache.org/?a=1&b=2&name=Kildong")
print(parsed_url)
# Out:
# ParseResult(scheme='https', netloc='tomcat.apache.org', path='/', params='', query='a=1&b=2&name=Kildong', fragment='')

# %%
unparsed = urllib.parse.urlunparse(list(parsed_url))
print(unparsed)
# Out:
# https://tomcat.apache.org/?a=1&b=2&name=Kildong

# %%
query_list = ["파이썬", "빅데이터", "인공지능"]
URL = "https://search.naver.com/search.naver?query="

# %%
for query in query_list:
    new_URL = URL + urllib.parse.quote(query)
#     print(new_URL)
    data = req.urlopen(new_URL).read()
    print(data.decode())
# Out:
# <!doctype html> <html lang="ko"><head> <meta charset="utf-8"> <meta name="referrer" content="strict-origin-when-cross-origin">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta property="og:title" content="파이썬 : 네이버 검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="'파이썬'의 네이버 검색 결과입니다."> <meta name="description" lang="ko" content="'파이썬'의 네이버 검색 결과입니다."> <title>파이썬 : 네이버 검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_32x32_240820.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_260423.css?o=search"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_260305.css?o=search"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_260205.css?o=search"><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; </script><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); function nx_add_event_handler (event, func) { document.addEventListener(event, func); } function bt(id, after) { document.getElementById(id).src = after; } function document_write (s) { document.write(s) ; } </script><script> var nx_au_cookie_domain = ".search.naver.com" ; var g_site = "" ; function nx_defer_eval (id) { var codeElement = document.getElementById(id), code = codeElement.innerHTML; eval(code.replace(/\/\*/, '').replace(/\*\//, '')); } function trim_crlf (q) { var crlf = /[\r|\n]/ ; q = q.replace(crlf, "") ; return q ; } function include_script (type, defer, src, charset) { var script = document.createElement("script") ; script.type = type, script.defer = defer ; script.src = src ; if (charset) script.charset = charset ; else script.charset = 'utf-8' ; document.getElementsByTagName('head')[0].appendChild(script) ; return script ; } function include_style (src, charset) { var h = document.getElementsByTagName("head")[0] ; var l = document.createElement('link') ; l.type = 'text/css' ; l.rel = 'stylesheet' ; if (charset) l.charset = charset ; else l.charset = 'utf-8' ; l.media = 'screen' ; l.href = src ; h.appendChild(l) ; } function rank_val (rank, name, sign, number, ad_onair) { this.rank = rank ; this.name = name ; this.sign = sign ; this.number = number ; this.ad_onair = ad_onair ; } function rr_hotquery_val (titleImg, totalLink, ad_onair) { this.titleImg = titleImg ; this.totalLink = totalLink ; this.ad_onair = ad_onair ; } function rr_append () { for (var i=0; i<rr_list.length; i++) if (rr_list[i].qname==hotqry_Name && rr_list[i].dir==hotqry_Dir) return 0 ; var o = { order:hotqry_Order, contid:hotqry_ContID, qname:hotqry_Name, dir:hotqry_Dir, toprank:hotqry_TopRank, rankdown:hotqry_RankDown, clicklog:hotqry_ClickLog, toprank_idx:toprank_idx, lowrank_idx:lowrank_idx, topranklist:toprank, lowranklist:lowrank_idx>=0?lowrank:null } ; rr_list = rr_list.concat(o) ; return 1 ; } var msg_hidden_idle=null; function msg (id) { if(msg_hidden_idle) clearInterval(msg_hidden_idle); if(id) { var mid=document.getElementById(id); mid.style.display=''; mid.style.visibility='visible'; } } function msg_hidden (id, f) { if(f) hidden(id); else msg_hidden_idle=setInterval("hidden('"+id+"')",100); } function hidden (id) { var mid=document.getElementById(id); mid.style.display='none'; mid.style.visibility='hidden'; } function nx_check_bas ...
# <div id="fdr-155263d070914a05be660828e28d3ac3" data-fender-root="true" data-block-id="ai-briefing/prs_template_aib_answer_desk.ts" data-meta-area="abL_baX" data-meta-nscs="" data-meta-ssc="tab.nx.all" data-meta-ssuid="ex_csa" data-meta-ssuid-extra="fender_renderer-ai_briefing" class="sc_new _slog_visible" data-slog-container="abL_baX" data-heatmap-area="abL_baX"><div class="KKheV6VbwLkLLMhovxGJ desktop_mode api_subject_bx fds-root-overflow-reset"><div class="sds-comps-base-layout sds-comps-full-layout" data-aib-color="blue"><div class="sds-comps-vertical-layout sds-comps-full-layout E35AGeS4amOM3otqbNGm" data-slog-overflow="true" style="height:600px" aria-expanded="false" data-aib-version="2"><div class="sds-comps-vertical-layout sds-comps-full-layout fds-aib-expandable-container"><div class="sds-comps-base-layout sds-comps-full-layout" style="--animation-duration:300ms;--animation-delay:0ms"><div class="sds-comps-base-layout sds-comps-full-layout Ho7BufTHBEV_bupPRW8E"><div class="sds-comps-vertical-layout sds-comps-full-layout fender-ui_97eaf6e5 fds-aib-header-container"><div class="sds-comps-base-layout sds-comps-full-layout fender-ui_9705a473 fds-aib-header-container-gradient-wrapper"><div class="sds-comps-base-layout sds-comps-inline-layout fender-ui_5980f2b2 fds-aib-header-container-gradient fds-aib-header-color-gradient-99"></div></div><div class="sds-comps-vertical-layout sds-comps-full-layout sds-comps-header type-basic undefined fender-ui_72862fc9 fds-aib-header" data-sds-comp="Header"><div class="sds-comps-horizontal-layout sds-comps-full-layout sds-comps-header-title"><div class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-header-left"><div class="sds-comps-horizontal-layout sds-comps-full-layout fender-ui_26847ec0"><div class="fender-ui_8ae3082c"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0
g":"%7B%22bid%22%3A%22PWC-0000000000038930%22%2C%22docRank%22%3A1%7D","i":"PWC-0000000000038930.nad-a001-03-000000483721462","r":1,"source":"*o"},"image":{"element":".writer","g":"%7B%22bid%22%3A%22PWC-0000000000038930%22%2C%22docRank%22%3A1%7D","i":"PWC-0000000000038930.nad-a001-03-000000483721462","r":1,"source":"*o"},"title":{"element":".writer","g":"%7B%22bid%22%3A%22PWC-0000000000038930%22%2C%22docRank%22%3A1%7D","i":"PWC-0000000000038930.nad-a001-03-000000483721462","r":1,"source":"*o"}},"createdDate":"2026.02.25.","imageHref":"https://ader.naver.com/v1/rl4rUgsSeBQDxDg4wDYtTUjZbnirNbr_2NAH6KL1RKnyC7206FmUAg85XeDizFHfGKf-6ZSnlQ7Y1acmoRkObJhOjgcorLCgLTp7_eb0wiUORnT9GrK41JygeYzS7cCpfzZ41awbdACtXGlT1q4_9mYgm8DHBPL-Sky6e_BM0CwU--WmwiNgXMp_zsV1hsUGZUm0ZSlYS-XCkBpZquZYFEA6uInSJMiJ-kxqoykN4wHaSybg_8ydY7AqsGzr1-oI?c=naver.search.pc.pwc_itb&t=0","imageSrc":"https://search.pstatic.net/common/?src=http%3A%2F%2Fblogpfthumb-phinf.pstatic.net%2FMjAyNTEwMjFfMjk5%2FMDAxNzYxMDMwNzcwNzg4.JGlm_Twbno0rRk88UGT5mJWSKjnoE_U4RWfrlxWO9v8g.EbRoWEqNHBS0t8ykdVYIEaPtBn3mGWcxDR008tgZqTQg.PNG%2F2025-10-21_16_11_22.png%2F2025-10-21%2B16%2B11%2B22.png&type=f48_48","isAdType":true,"title":"메가스터디컴퓨터아카데미","titleHref":"https://ader.naver.com/v1/rl4rUgsSeBQDxDg4wDYtTUjZbnirNbr_2NAH6KL1RK ...
#
#       }});
#     });
#   };
#
#   if (window.naver && window.naver.common && typeof window.naver.common.load_js === "function") {
#     var isDomLoading = document.readyState === "loading";
#
#     naver.common.load_js(null, startApplication, isDomLoading, 150, !isDomLoading);
#   } else {
#     setTimeout(startApplication, 150);
#   }
# })();
# </script><div class="_scrollLog" data-slog-id="ugB_adR*o" style="visibility:hidden;height:0px;margin:0 28px"></div><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_fsolid_251218.css">
#
#
# <div class="spw_fsolid  type_head _fsolid_head  _slog_visible"
# 	data-slog-container="urB_coR"
# 	data-collection="urB_coR"
# 	>
#
# 		<div id="fdr-ee37dd372c9b4bceba66061a29475419" data-fender-root="true" data-block-id="web/prs_template_v2_web_basic_desk.ts" data-meta-area="urB_coR" data-meta-nscs="" data-meta-ssc="tab.nx.all" data-meta-ssuid="web" data-meta-ssuid-extra="fender_renderer-web" class="sc_new _slog_visible"><div class="KKheV6VbwLkLLMhovxGJ desktop_mode api_subject_bx fds-root-overflow-reset"><div class="sds-comps-vertical-layout sds-comps-full-layout fds-web-root" data-template-id="layout" data-template-type="vertical"><div class="sds-comps-vertical-layout sds-comps-full-layout fds-web-list-root fds-web-list-vert-padding" data-template-id="layout" data-template-type="vertical"><div class="sds-comps-vertical-layout sds-comps-full-layout fds-web-doc-root bH6OrZzEJkvRXJV7uV9m fds-web-normal-doc-root"><div class="sds-comps-vertical-layout sds-comps-full-layout TafDtz7UQAydfzSPMah1"><div class="sds-comps-horizontal-layout sds-comps-full-layout yb2KVsCwXz18iwtLVGye"><a nocr="1" href="https://www.python.org/" class="fender-ui_228e3bd1 VvrpcXKSy9qRYQTTCHlR" target="_blank" data-heatmap-target=".link"><div class="sds-comps-horizontal-layout sds-comps-full-layout sds-comps-profile type-web size-lg title-color-g10" data-sds-comp="Profile"><div class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-profile-source"><div class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-profile-source-thumb"><div class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-profile-thumbnail type-web size-lg" data-sds-comp="ProfileThumbnail"><div class="sds-comps-base-layout sds-comps-inline-layout sds-comps-image sds-comps-image-circle fit-cover is-loading" style="width:16px;height:16px;aspect-ratio:1/1" data-sds-comp="RectangleImage" data-dimmed="none"><img width="16" height="16" alt="" loading="lazy" src="https://search.pstatic.net/sunny?src=https%3A%2F%2Fwww.python.org%2Fstatic%2Ffavicon.ico&amp;type=f30_30_png_expire24"/><div class="sds-comps-image-dimmed"></div></div></div></div><div class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-profile-info-title"><span class="sds-comps-text sds-comps-text-ellipsis sds-comps-text-ellipsis-1 sds-comps-text-type-body2 sds-comps-text-weight-sm sds-comps-profile-info-title-text">Python</span></div><div class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-profile-info-subtexts"><span class="sds-comps-base-layout sds-comps-full-layout sds-comps-divider sds-comps-divider-dot" data-sds-comp="DotDivider"></span><span class="sds-comps-text sds-comps-text-type-body2 sds-comps-text-weight-sm sds-comps-profile-info-subtext"><div class="sds-comps-horizontal-layout sds-comps-inline-layout fender-ui_3433cb3b"><span class="sds-comps-text sds-comps-text-type-body2 sds-comps-text-weight-sm">www.python.org</span></div></span></div></div></div></a><div class="sds-comps-base-layout sds-comps-inline-layout fender-ui_22887c0d _keep_wrap QpdYzf1M3e6wwAJmRfw5"><button type="button" class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-button sds-comps-icon-button fender-ui_e68fe790 _keep_trigger" data-url="https://www.python.org/" data-cr-on="a=urB_coR*w.kep" data-cr-off="a=urB_coR*w.kep" aria-label="옵션 메뉴 열기" data-sds-comp="IconSingleButton"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 3 16" class="sds-comps-svg sds-comps-icon sds-comps-icon-size-md1 fender-ui_0e40b61b sds-comps-option-icon" width="3" height="16" fill="none" aria-hidden="true" stroke="none" aria-label="OptionIcon"><circle class="sds-comps-option-icon-element0" cx="1.5" cy="3" r="1.5"></circle><circle class="sds-comps-option-icon-element1" cx="1.5" cy="8" r="1.5"></circle><circle class="sds-comps-option-icon-element2" cx="1.5" cy="13" r="1.5"></circle></svg></button><div class="sds-comps-vertical-layout sds-comps-inline-layout fender-ui_fca27e9a api_ly_save _keep_save_layer" keepTriggerOnClickLog="a=urB_coR*w.kep" keepTriggerOffClickLog="a=urB_coR*w.kep" style="display:none"><a href="#" targe ...
# (function () {
#
#   var startApplication = function () {
#     var require = window.require.config({
#       "context": "fender_renderer_2f4b6a6889f5f7e1c1bb",
#       "paths": {
#         "fender_2f4b6a6889f5f7e1c1bb": "https://ssl.pstatic.net/sstatic/fe/fender/client/2f4b6a6889f5f7e1c1bb/index.js".replace(/\.js$/, ""),
#       }
#     });
#     require(["fender_2f4b6a6889f5f7e1c1bb"], function (entry) {
#       entry.bootstrap(document.getElementById("fdr-ee37dd372c9b4bceba66061a29475419"), {"appElementAttrs":{"className":"sc_new _slog_visible"},"meta":{"area":"urB_coR","nscs":"","query":"파이썬","ssc":"tab.nx.all","ssuid":"web","ssuidExtra":"fender_renderer-web","xQuerySource":""},"refs":{"blockId":"web/prs_template_v2_web_basic_desk.ts"},"rootElementAttrs":{"className":"api_subject_bx fds-root-overflow-reset"},"body":{"props":{"children":[{"props":{"children":[{"props":{"aggregation":{"contents":[{"bodyText":"Looking for Python with a different OS? Python for Windows, Linux/Unix, macOS, Android, other Want to help test development versions of Python 3.15? Pre-releases, Docker images","clickLog":{"image":{"element":".img","g":"","i":"a00000fa_6bd7e4a1b937bdf1c5f65d13^fabl","r":2,"source":"*w"},"title":{"element":".link","g":"","i":"a00000fa_6bd7e4a1b937bdf1c5f65d13^fabl","r":2,"source":"*w"}},"href":"https://www.python.org/downloads/","imageHref":"https://www.python.org/downloads/","imageSrc":"https://search.pstatic.net/sunny?src=https%3A%2F%2Fdevguide.python.org%2F_static%2Frelease-cycle.svg&type=fff174_174","title":"Download Python"}],"more":{"clickLog":{"more":{"element":".sramore","g":"","i":"a00000fa_6bd7e4a1b937bdf1c5f65d13^fabl","r":1,"source":"*w"}},"href":"?page=2&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC+site%3Awww.python.org&qvt=0&ssc=tab.ur.all","text":"관련문서 더보기"}},"bodyText":"The official home of the Python Programming Language","bodyVariants":"3line","card":{},"clickLog":{"title":{"element":".link","g":"","i":"a00000fa_6bd7e4a1b937bdf1c5f65d13^fabl","r":1,"source":"*w"}},"deviceType":"desk","href":"https://www.python.org/","keyValue":{},"list":{},"notice":{},"paragraph":{},"profile":{"badge":"","clickLog":{"profile":{"element":".link","g":"","i":"a00000fa_6bd7e4a1b937bdf1c5f65d13^fabl","r":1,"source":"*w"}},"favicon":"https://search.pstatic.net/sunny?src=https%3A%2F%2Fwww.python.org%2Fstatic%2Ffavicon.ico&type=f30_30_png_expire24","href":"https://www.python.org/","keep":{"clickLog":{"keepLink":{"element":".kephome","g":"","i":"a00000fa_6bd7e4a1b937bdf1c5f65d13^fabl","r":1,"source":""}},"keepOffClickLog":"a=urB_coR*w.kepoff","keepOnClickLog":"a=urB_coR*w.keepon","keepTriggerOffClickLog":"a=urB_coR*w.kep","keepTriggerOnClickLog":"a=urB_coR*w.kep","keepTriggerUrl":"https://www.python.org/","keepURL":"https://keep.naver.com/","type":"basic","use":["keep","mykeep"],"version":"2"},"subTexts":[{"text":"www.python.org"}],"title":"Python"},"review":{},"rootClassName":"fds-web-normal-doc-root","sourceInfo":{},"subLinks":[{"clickLog":{"linkText":{"element":".sublink","g":"","i":"a00000fa_6bd7e4a1b937bdf1c5f65d13^fabl","r":1,"source":"*w"}},"href":"https://www.python.org/doc/","text":"Documentation"},{"clickLog":{"linkText":{"element":".sublink","g":"","i":"a00000fa_6bd7e4a1b937bdf1c5f65d13^fabl","r":1,"source":"*w"}},"href":"https://www.python.org/downloads/","text":"Downloads"},{"clickLog":{"linkText":{"element":".sublink","g":"","i":"a00000fa_6bd7e4a1b937bdf1c5f65d13^fabl","r":1,"source":"*w"}},"href":"https://www.python.org/psf/","text":"PSF"},{"clickLog":{"linkText":{"element":".sublink","g":"","i":"a00000fa_6bd7e4a1b937bdf1c5f65d13^fabl","r":1,"source":"*w"}},"href":"https://www.python.org/downloads/windows/","text":"Windows"},{"clickLog":{"linkText":{"element":".sublink","g":"","i":"a00000fa_6bd7e4a1b937bdf1c5f65d13^fabl","r":1,"source":"*w"}},"href":"https://www.python.org/about/gettingstarted/","text":"Getting Started"},{"clickLog":{"linkText":{"element":".sublink","g":"","i":"a00000fa_6bd7e4a1b937bdf1c5f65d13^fabl","r":1,"source":"*w"}},"href":"https://www.python.org/downloads/macos/","text":"macOS"}],"table":{},"title":"Welcome to Python.org","titleVariant":"1line","topstorys":{},"type":"basic"},"templateId":"webItem"}],"className":"fds-web-list-root fds-web-list-vert-padding","divider":{"props":{"color":"g90","size":"sm"},"templateId":"sdsHorzDivider"},"type":"vertical"},"templateId":"layout"}],"className":"fds-web-root","t ...
#
#       }});
#     });
#   };
#
#   if (window.naver && window.naver.common && typeof window.naver.common.load_js === "function") {
#     var isDomLoading = document.readyState === "loading";
#
#     naver.common.load_js(null, startApplication, isDomLoading, 150, !isDomLoading);
#   } else {
#     setTimeout(startApplication, 150);
#   }
# })();
# </script><div id="fdr-fe47c78fffa34a19806fa8e3f04edfa2" data-fender-root="true" data-block-id="web/prs_template_v2_web_basic_desk.ts" data-meta-area="urB_coR" data-meta-nscs="" data-meta-ssc="tab.nx.all" data-meta-ssuid="web" data-meta-ssuid-extra="fender_renderer-web" class="sc_new _slog_visible"><div class="KKheV6VbwLkLLMhovxGJ desktop_mode api_subject_bx fds-root-overflow-reset"><div class="sds-comps-vertical-layout sds-comps-full-layout fds-web-root" data-template-id="layout" data-template-type="vertical"><div class="sds-comps-vertical-layout sds-comps-full-layout fds-web-list-root fds-web-list-vert-padding" data-template-id="layout" data-template-type="vertical"><div class="sds-comps-vertical-layout sds-comps-full-layout fds-web-doc-root bH6OrZzEJkvRXJV7uV9m fds-web-normal-doc-root"><div class="sds-comps-vertical-layout sds-comps-full-layout TafDtz7UQAydfzSPMah1"><div class="sds-comps-horizontal-layout sds-comps-full-layout yb2KVsCwXz18iwtLVGye"><a nocr="1" href="https://namu.wiki/w/Python" class="fender-ui_228e3bd1 VvrpcXKSy9qRYQTTCHlR" target="_blank" data-heatmap-target=".link"><div class="sds-comps-horizontal-layout sds-comps-full-layout sds-comps-profile type-web size-lg title-color-g10" data-sds-comp="Profile"><div class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-profile-source"><div class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-profile-source-thumb"><div class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-profile-thumbnail type-web size-lg" data-sds-comp="ProfileThumbnail"><div class="sds-comps-base-layout sds-comps-inline-layout sds-comps-image sds-comps-image-circle fit-cover is-loading" style="width:16px;height:16px;aspect-ratio:1/1" data-sds-comp="RectangleImage" data-dimmed="none"><img width="16" height="16" alt="" loading="lazy" src="https://search.pstatic.net/sunny?src=https%3A%2F%2Fnamu.wiki%2Ffavicon.ico&amp;type=f30_30_png_expire24"/><div class="sds-comps-image-dimmed"></div></div></div></div><div class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-profile-info-title"><span class="sds-comps-text sds-comps-text-ellipsis sds-comps-text-ellipsis-1 sds-comps-text-type-body2 sds-comps-text-weight-sm sds-comps-profile-info-title-text">나무위키</span></div><div class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-profile-info-subtexts"><span class="sds-comps-base-layout sds-comps-full-layout sds-comps-divider sds-comps-divider-dot" data-sds-comp="DotDivider"></span><span class="sds-comps-text sds-comps-text-type-body2 sds-comps-text-weight-sm sds-comps-profile-info-subtext"><div class="sds-comps-horizontal-layout sds-comps-inline-layout fender-ui_3433cb3b"><span class="sds-comps-text sds-comps-text-type-body2 sds-comps-text-weight-sm">namu.wiki</span><span class="sds-comps-text fender-ui_0aeefe40">›</span><span class="sds-comps-text sds-comps-text-type-body2 sds-comps-text-weight-sm">Python</span></div></span></div></div></div></a><div class="sds-comps-base-layout sds-comps-inline-layout fender-ui_22887c0d _keep_wrap QpdYzf1M3e6wwAJmRfw5"><button type="button" class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-button sds-comps-icon-button fender-ui_e68fe790 _keep_trigger" data-url="https://namu.wiki/w/Python" data-cr-on="a=urB_coR*w.kep" data-cr-off="a=urB_coR*w.kep" aria-label="옵션 메뉴 열기" data-sds-comp="IconSingleButton"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 3 16" class="sds-comps-svg sds-comps-icon sds-comps-icon-size-md1 fender-ui_0e40b61b sds-comps-option-icon" width="3" height="16" fill="none" aria-hidden="true" stroke="none" aria-label="OptionIcon"><circle class="sds-comps-option-icon-element0" cx="1.5" cy="3" r="1.5"></circle><circle class="sds-comps-option-icon-element1" cx="1.5" cy="8" r="1.5"></circle><circle class="sds-comps-option-icon-element2" cx="1.5" cy="13" r="1.5"></circle></svg></button><div class="sds-comps-vertical-layout sds-comps-inline-layout fender-ui_fca27e9a api_ly_s ...
# (function () {
#
#   var startApplication = function () {
#     var require = window.require.config({
#       "context": "fender_renderer_2f4b6a6889f5f7e1c1bb",
#       "paths": {
#         "fender_2f4b6a6889f5f7e1c1bb": "https://ssl.pstatic.net/sstatic/fe/fender/client/2f4b6a6889f5f7e1c1bb/index.js".replace(/\.js$/, ""),
#       }
#     });
#     require(["fender_2f4b6a6889f5f7e1c1bb"], function (entry) {
#       entry.bootstrap(document.getElementById("fdr-fe47c78fffa34a19806fa8e3f04edfa2"), {"appElementAttrs":{"className":"sc_new _slog_visible"},"meta":{"area":"urB_coR","nscs":"","query":"파이썬","ssc":"tab.nx.all","ssuid":"web","ssuidExtra":"fender_renderer-web","xQuerySource":""},"refs":{"blockId":"web/prs_template_v2_web_basic_desk.ts"},"rootElementAttrs":{"className":"api_subject_bx fds-root-overflow-reset"},"body":{"props":{"children":[{"props":{"children":[{"props":{"aggregation":{},"bodyText":"네덜란드의 프로그래머 귀도 반 로섬이 1991년도에 개발하고 1994년에 정식 출시한 인터프리터형 프로그래밍 언어.","bodyVariants":"3line","card":{},"clickLog":{"title":{"element":".link","g":"","i":"a00000fa_f26c3ab04ba64ef798bebab8^faVc","r":3,"source":"*w"}},"deviceType":"desk","href":"https://namu.wiki/w/Python","images":[{"clickLog":{"image":{"element":".image","g":"","i":"a00000fa_f26c3ab04ba64ef798bebab8^faVc","r":3,"source":"*w"}},"imageHref":"https://namu.wiki/w/Python","imageSrc":"https://search.pstatic.net/sunny?src=https%3A%2F%2Fi.ytimg.com%2Fvi%2Fx7X9w_GIm1s%2Fmaxresdefault.jpg&type=fff208_208_ar","type":"image"}],"keyValue":{"clickLog":{"keyValue":{"element":".infob","g":"","i":"a00000fa_f26c3ab04ba64ef798bebab8^faVc","r":3,"source":"*w"}},"contents":[{"key":"개발자","valueData":{"text":"귀도 반 로섬","type":"basic"}}]},"linkBtns":[{"clickLog":{"link":{"element":".relink","g":"","i":"a00000fa_f26c3ab04ba64ef798bebab8^faVc","r":3,"source":"*w"}},"href":"https://namu.wiki/w/Python#s-1","text":"개요"},{"clickLog":{"link":{"element":".relink","g":"","i":"a00000fa_f26c3ab04ba64ef798bebab8^faVc","r":3,"source":"*w"}},"href":"https://namu.wiki/w/Python#s-2","text":"디자인"},{"clickLog":{"link":{"element":".relink","g":"","i":"a00000fa_f26c3ab04ba64ef798bebab8^faVc","r":3,"source":"*w"}},"href":"https://namu.wiki/w/Python#s-3","text":"장점"},{"clickLog":{"link":{"element":".relink","g":"","i":"a00000fa_f26c3ab04ba64ef798bebab8^faVc","r":3,"source":"*w"}},"href":"https://namu.wiki/w/Python#s-4","text":"단점"},{"clickLog":{"link":{"element":".relink","g":"","i":"a00000fa_f26c3ab04ba64ef798bebab8^faVc","r":3,"source":"*w"}},"href":"https://namu.wiki/w/Python#s-5","text":"구현체 목록"},{"clickLog":{"link":{"element":".relink","g":"","i":"a00000fa_f26c3ab04ba64ef798bebab8^faVc","r":3,"source":"*w"}},"href":"https://namu.wiki/w/Python#s-6","text":"개발 환경"},{"clickLog":{"link":{"element":".relink","g":"","i":"a00000fa_f26c3ab04ba64ef798bebab8^faVc","r":3,"source":"*w"}},"href":"https://namu.wiki/w/Python#s-7","text":"패키지 및 가상 환경 관리"},{"clickLog":{"link":{"element":".relink","g":"","i":"a00000fa_f26c3ab04ba64ef798bebab8^faVc","r":3,"source":"*w"}},"href":"https://namu.wiki/w/Python#s-8","text":"주요 패키지"},{"clickLog":{"link":{"element":".relink","g":"","i":"a00000fa_f26c3ab04ba64ef798bebab8^faVc","r":3,"source":"*w"}},"href":"https://namu.wiki/w/Python#s-9","text":"문법"},{"clickLog":{"link":{"element":".relink","g":"","i":"a00000fa_f26c3ab04ba64ef798bebab8^faVc","r":3,"source":"*w"}},"href":"https://namu.wiki/w/Python#s-10","text":"설치"}],"list":{},"notice":{},"paragraph":{},"profile":{"badge":"","clickLog":{"profile":{"element":".link","g":"","i":"a00000fa_f26c3ab04ba64ef798bebab8^faVc","r":3,"source":"*w"}},"favicon":"https://search.pstatic.net/sunny?src=https%3A%2F%2Fnamu.wiki%2Ffavicon.ico&type=f30_30_png_expire24","href":"https://namu.wiki/w/Python","keep":{"clickLog":{"keepLink":{"element":".kephome","g":"","i":"a00000fa_f26c3ab04ba64ef798bebab8^faVc","r":3,"source":""}},"keepOffClickLog":"a=urB_coR*w.kepoff","keepOnClickLog":"a=urB_coR*w.keepon","keepTriggerOffClickLog":"a=urB_coR*w.kep","keepTriggerOnClickLog":"a=urB_coR*w.kep","keepTriggerUrl":"https://namu.wiki/w/Python","keepURL":"https://keep.naver.com/","type":"basic","use":["keep","mykeep"],"version":"2"},"subTexts":[{"text":"namu.wiki"},{"text":"Python"}],"title":"나무위키"},"review":{},"rootClassName":"fds-web-normal-doc-root","sourceInfo":{},"table":{},"title":"Python - 나무위키","titleVariant":"1line","topstorys":{},"type":"basic"},"templateId":"webIte ...
#
#       }});
#     });
#   };
#
#   if (window.naver && window.naver.common && typeof window.naver.common.load_js === "function") {
#     var isDomLoading = document.readyState === "loading";
#
#     naver.common.load_js(null, startApplication, isDomLoading, 150, !isDomLoading);
#   } else {
#     setTimeout(startApplication, 150);
#   }
# })();
# </script><div id="fdr-9f2946edc4914683a11d1ea051e46e09" data-fender-root="true" data-block-id="web/prs_template_v2_web_basic_desk.ts" data-meta-area="urB_coR" data-meta-nscs="" data-meta-ssc="tab.nx.all" data-meta-ssuid="web" data-meta-ssuid-extra="fender_renderer-web" class="sc_new _slog_visible"><div class="KKheV6VbwLkLLMhovxGJ desktop_mode api_subject_bx fds-root-overflow-reset"><div class="sds-comps-vertical-layout sds-comps-full-layout fds-web-root" data-template-id="layout" data-template-type="vertical"><div class="sds-comps-vertical-layout sds-comps-full-layout fds-web-list-root fds-web-list-vert-padding" data-template-id="layout" data-template-type="vertical"><div class="sds-comps-vertical-layout sds-comps-full-layout fds-web-doc-root bH6OrZzEJkvRXJV7uV9m fds-web-normal-doc-root"><div class="sds-comps-vertical-layout sds-comps-full-layout TafDtz7UQAydfzSPMah1"><div class="sds-comps-horizontal-layout sds-comps-full-layout yb2KVsCwXz18iwtLVGye"><a nocr="1" href="https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC" class="fender-ui_228e3bd1 VvrpcXKSy9qRYQTTCHlR" target="_blank" data-heatmap-target=".link"><div class="sds-comps-horizontal-layout sds-comps-full-layout sds-comps-profile type-web size-lg title-color-g10" data-sds-comp="Profile"><div class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-profile-source"><div class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-profile-source-thumb"><div class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-profile-thumbnail type-web size-lg" data-sds-comp="ProfileThumbnail"><div class="sds-comps-base-layout sds-comps-inline-layout sds-comps-image sds-comps-image-circle fit-cover is-loading" style="width:16px;height:16px;aspect-ratio:1/1" data-sds-comp="RectangleImage" data-dimmed="none"><img width="16" height="16" alt="" loading="lazy" src="https://search.pstatic.net/sunny?src=https%3A%2F%2Fko.wikipedia.org%2Ffavicon.ico&amp;type=f30_30_png_expire24"/><div class="sds-comps-image-dimmed"></div></div></div></div><div class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-profile-info-title"><span class="sds-comps-text sds-comps-text-ellipsis sds-comps-text-ellipsis-1 sds-comps-text-type-body2 sds-comps-text-weight-sm sds-comps-profile-info-title-text">위키백과 한국어</span></div><div class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-profile-info-subtexts"><span class="sds-comps-base-layout sds-comps-full-layout sds-comps-divider sds-comps-divider-dot" data-sds-comp="DotDivider"></span><span class="sds-comps-text sds-comps-text-type-body2 sds-comps-text-weight-sm sds-comps-profile-info-subtext"><div class="sds-comps-horizontal-layout sds-comps-inline-layout fender-ui_3433cb3b"><span class="sds-comps-text sds-comps-text-type-body2 sds-comps-text-weight-sm">ko.wikipedia.org</span><span class="sds-comps-text fender-ui_0aeefe40">›</span><span class="sds-comps-text sds-comps-text-type-body2 sds-comps-text-weight-sm">파이썬</span></div></span></div></div></div></a><div class="sds-comps-base-layout sds-comps-inline-layout fender-ui_22887c0d _keep_wrap QpdYzf1M3e6wwAJmRfw5"><button type="button" class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-button sds-comps-icon-button fender-ui_e68fe790 _keep_trigger" data-url="https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC" data-cr-on="a=urB_coR*w.kep" data-cr-off="a=urB_coR*w.kep" aria-label="옵션 메뉴 열기" data-sds-comp="IconSingleButton"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 3 16" class="sds-comps-svg sds-comps-icon sds-comps-icon-size-md1 fender-ui_0e40b61b sds-comps-option-icon" width="3" height="16" fill="none" aria-hidden="true" stroke="none" aria-label="OptionIcon"><circle class="sds-comps-option-icon-element0" cx="1.5" cy="3" r="1.5"></circle><circle class="sds-comps-option-icon-element1" cx="1.5" cy="8" r="1.5"></circle><circle class="sds-comps-option-icon-element2" cx="1.5" cy="13" r="1.5"></circle></svg></button><div class=" ...
# (function () {
#
#   var startApplication = function () {
#     var require = window.require.config({
#       "context": "fender_renderer_2f4b6a6889f5f7e1c1bb",
#       "paths": {
#         "fender_2f4b6a6889f5f7e1c1bb": "https://ssl.pstatic.net/sstatic/fe/fender/client/2f4b6a6889f5f7e1c1bb/index.js".replace(/\.js$/, ""),
#       }
#     });
#     require(["fender_2f4b6a6889f5f7e1c1bb"], function (entry) {
#       entry.bootstrap(document.getElementById("fdr-9f2946edc4914683a11d1ea051e46e09"), {"appElementAttrs":{"className":"sc_new _slog_visible"},"meta":{"area":"urB_coR","nscs":"","query":"파이썬","ssc":"tab.nx.all","ssuid":"web","ssuidExtra":"fender_renderer-web","xQuerySource":""},"refs":{"blockId":"web/prs_template_v2_web_basic_desk.ts"},"rootElementAttrs":{"className":"api_subject_bx fds-root-overflow-reset"},"body":{"props":{"children":[{"props":{"children":[{"props":{"aggregation":{"contents":[{"bodyText":"<mark>파이썬</mark> ( 영어: Python )은 1991년 네덜란드계 소프트웨어 엔지니어인 귀도 반 로섬이 발표한 고급 프로그래밍 언어로, '인터프리터를 사용하는 객체지향 언어'이자 플랫폼에 독립적인, 동적 타이핑(dynamically typed) 대화형 언어다. <mark>파이썬</mark>이라는 이름은 귀도가 좋아하는 코미디인〈Monty Python's Flying Circus〉에서 따온 것이다. 이름에서 고대신화에 나오는 커다란 뱀을 연상하겠지만 이와는 무관하다. 다만 로고에는 뱀 두마리가 형상화되어 있다. 간결하고 읽기 쉬운 문법이 특징인 프로그래밍 언어로 데이터 분석, 웹 개발, 인공지능 등 다양한 분야에서 활용된다. <mark>파이썬</mark>은 비영리 <mark>파이썬</mark> 소프트웨어 재단이 관리하는 개방형, 공동체 기반 개발 모델이 있다. 가독성이 높고 표현력이 풍...","clickLog":{"title":{"element":".link","g":"","i":"a00000fa_5a2bd8e76c2907579103e03b^falc","r":5,"source":"*w"}},"href":"https://ko.wikipedia.org/wiki/ko:%ED%8C%8C%EC%9D%B4%EC%8D%AC","title":"<mark>파이썬</mark> - 위키백과 한국어"}],"more":{"clickLog":{"more":{"element":".sramore","g":"","i":"a00000fa_5a2bd8e76c2907579103e03b^falc","r":4,"source":"*w"}},"href":"?page=2&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC+site%3Ako.wikipedia.org&qvt=0&ssc=tab.ur.all","text":"관련문서 더보기"}},"bodyText":"<mark>파이썬</mark> ( 영어: Python )은 1991년 네덜란드계 소프트웨어 엔지니어인 귀도 반 로섬이 발표한 고급 프로그래밍 언어로, '인터프리터를 사용하는 객체지향 언어'이자 플랫폼에 독립적인, 동적 타이핑(dynamically typed) 대화형 언어다. <mark>파이썬</mark>이라는 이름은 귀도가 좋아하는 코미디인〈Monty Python's Flying Circus〉에서 따온 것이다. 이름에서 고대신화에 나오는 커다란 뱀을 연상하겠지만 이와는 무관하다. 다만 로고에는 뱀 두마리가 형상화되어 있다. 간결하고 읽기 쉬운 문법이 특징인 프로그래밍 언어로 데이터 분석, 웹 개발, 인공지능 등 다양한 분야에서 활용된다. <mark>파이썬</mark>은 비영리 <mark>파이썬</mark> 소프트웨어 재단이 관리하는 개방형, 공동체 기반 개발 모델이 있다. 가독성이 높고 표현력이 풍...","bodyVariants":"3line","card":{},"clickLog":{"title":{"element":".link","g":"","i":"a00000fa_5a2bd8e76c2907579103e03b^falc","r":4,"source":"*w"}},"deviceType":"desk","href":"https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC","keyValue":{"clickLog":{"keyValue":{"element":".infob","g":"","i":"a00000fa_5a2bd8e76c2907579103e03b^falc","r":4,"source":"*w"}},"contents":[{"key":"파일 확장자","valueData":{"text":".py, .pyc, .pyd, .pyo","type":"basic"}},{"key":"패러다임","valueData":{"text":"프로그래밍 패러다임 객체 지향 프로그래밍, 명령형 프로그래밍, 함수형 프로그래밍, 절차적 프로그래밍, 반영","type":"basic"}},{"key":"최근 버전","valueData":{"text":"3.14.4","type":"basic"}},{"key":"최근 버전 출시일","valueData":{"text":"2026년 4월 7일 (14일 전)","type":"basic"}}]},"linkBtns":[{"clickLog":{"link":{"element":".relink","g":"","i":"a00000fa_5a2bd8e76c2907579103e03b^falc","r":4,"source":"*w"}},"href":"https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC#%EA%B0%9C%EC%9A%94","text":"개요"},{"clickLog":{"link":{"element":".relink","g":"","i":"a00000fa_5a2bd8e76c2907579103e03b^falc","r":4,"source":"*w"}},"href":"https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC#%EC%97%AD%EC%82%AC","text":"역사"},{"clickLog":{"link":{"element":".relink","g":"","i":"a00000fa_5a2bd8e76c2907579103e03b^falc","r":4,"source":"*w"}},"href":"https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC#%EA%B8%B0%EB%8A%A5%EA%B3%BC_%EC%B2%A0%ED%95%99","text":"기능과 철학"},{"clickLog":{"link":{"element":".relink","g":"","i":"a00000fa_5a2bd8e76c2907579103e03b^falc","r":4,"source":"*w"}},"href":"https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC#%EB%AC%B8%EB%B2%95","text":"문법"},{"clickLog":{"link":{"element":".relink","g":"","i":"a00000fa_5a2bd8e76c2907579103e03b^falc","r":4,"source":"*w"}},"href":"https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC#%EC%9E%90%EB%A3%8C%ED%98%95","text":"자료형"},{"clickLog":{"link":{"element":".relink","g":"","i":"a00000fa_5a2bd8e76c2907579103e03b^falc","r":4,"source":"*w"}},"href":"https://ko.wikipedia.org/wiki/%ED%8C%8C%EC%9D%B4%EC%8D%AC#%EB%8F%99%EC%9E%91%ED%95%98%EB%8A%94_%ED%94%8C%EB%9E%AB%ED%8F%BC","text":"동작하는 플랫폼"},{"cl ...
#
#       }});
#     });
#   };
#
#   if (window.naver && window.naver.common && typeof window.naver.common.load_js === "function") {
#     var isDomLoading = document.readyState === "loading";
#
# ...
# 		<div class="sc_page_inner">
#
#
#
#
#
#
#
#
#
#
# 			<a
# 				href="?nso=&amp;query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;sm=tab_pge&amp;ssc=tab.nx.all"
# 				onClick="goOtherCR(this,'a=pag.pag&r=1&i=&u='+urlencode(this.href))"
# 				role="button" class="btn" aria-pressed="true">1</a>
#
#
#
#
#
#
#
# 			<a
# 				href="?nso=&amp;page=2&amp;query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;sm=tab_pge&amp;ssc=tab.ur.all&amp;start=1"
# 				onClick="goOtherCR(this,'a=pag.pag&r=2&i=&u='+urlencode(this.href))"
# 				role="button" class="btn" aria-pressed="false">2</a>
#
#
#
#
#
#
#
#
# 			<a
# 				href="?nso=&amp;page=3&amp;query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;sm=tab_pge&amp;ssc=tab.ur.all&amp;start=16"
# 				onClick="goOtherCR(this,'a=pag.pag&r=3&i=&u='+urlencode(this.href))"
# 				role="button" class="btn" aria-pressed="false">3</a>
#
#
#
#
#
#
#
#
# 			<a
# 				href="?nso=&amp;page=4&amp;query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;sm=tab_pge&amp;ssc=tab.ur.all&amp;start=31"
# 				onClick="goOtherCR(this,'a=pag.pag&r=4&i=&u='+urlencode(this.href))"
# 				role="button" class="btn" aria-pressed="false">4</a>
#
#
#
#
#
#
#
#
# 			<a
# 				href="?nso=&amp;page=5&amp;query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;sm=tab_pge&amp;ssc=tab.ur.all&amp;start=46"
# 				onClick="goOtherCR(this,'a=pag.pag&r=5&i=&u='+urlencode(this.href))"
# 				role="button" class="btn" aria-pressed="false">5</a>
#
#
#
#
#
#
#
#
# 			<a
# 				href="?nso=&amp;page=6&amp;query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;sm=tab_pge&amp;ssc=tab.ur.all&amp;start=61"
# 				onClick="goOtherCR(this,'a=pag.pag&r=6&i=&u='+urlencode(this.href))"
# 				role="button" class="btn" aria-pressed="false">6</a>
#
#
#
#
#
#
#
#
# 			<a
# 				href="?nso=&amp;page=7&amp;query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;sm=tab_pge&amp;ssc=tab.ur.all&amp;start=76"
# 				onClick="goOtherCR(this,'a=pag.pag&r=7&i=&u='+urlencode(this.href))"
# 				role="button" class="btn" aria-pressed="false">7</a>
#
#
#
#
#
#
#
#
# 			<a
# 				href="?nso=&amp;page=8&amp;query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;sm=tab_pge&amp;ssc=tab.ur.all&amp;start=91"
# 				onClick="goOtherCR(this,'a=pag.pag&r=8&i=&u='+urlencode(this.href))"
# 				role="button" class="btn" aria-pressed="false">8</a>
#
#
#
#
#
#
#
#
# 			<a
# 				href="?nso=&amp;page=9&amp;query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;sm=tab_pge&amp;ssc=tab.ur.all&amp;start=106"
# 				onClick="goOtherCR(this,'a=pag.pag&r=9&i=&u='+urlencode(this.href))"
# 				role="button" class="btn" aria-pressed="false">9</a>
#
#
#
#
#
#
#
#
# 			<a
# 				href="?nso=&amp;page=10&amp;query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;sm=tab_pge&amp;ssc=tab.ur.all&amp;start=121"
# 				onClick="goOtherCR(this,'a=pag.pag&r=10&i=&u='+urlencode(this.href))"
# 				role="button" class="btn" aria-pressed="false">10</a>
#
#
#
#
#
#
#
#
#
#
# 		</div>
# 		<a
# 			href="?nso=&amp;page=2&amp;query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&amp;sm=tab_pge&amp;ssc=tab.ur.all&amp;start=1"
# 			onClick="goOtherCR(this,'a=pag.pag&r=2&i=&u='+urlencode(this.href))"
# 			role="button" class="btn_next" aria-disabled="false"><i class="spnew api_ico_pg_arr">다음</i></a>
#
#
#
# 	</div>
# </div>
#
#
#
#
#
# <div class="ct_feed_wrap"></div><div class="_scrollLogEndline" style="visibility:hidden;height:0px"></div></div><div id="sub_pack" class="sub_pack"><div id="fdr-441c7dac22b446ed8bf3657f005a5156" data-fender-root="true" data-block-id="shortents/prs_template_feed_search_shortents_compact_sub_desk.ts" data-meta-area="stX_cpT" data-meta-nscs="" data-meta-ssc="tab.nx.all" data-meta-ssuid="shortents" data-meta-ssuid-extra="fender_renderer-shortents" class="sc_new" data-heatmap-area="stX_cpT"><div class="KKheV6VbwLkLLMhovxGJ desktop_mode api_subject_bx"><div class="sds-comps-vertical-layout sds-comps-full-layout fds-shortents-compact-block" data-template-id="layout" data-template-type="vertical"><div class="sds-comps-vertical-layout sds-comps-full-layout sds-comps-header type-basic fender-ui_fb538804" data-template-id="sdsFeedSearchHeader" data-template-type="basic" data-sds-comp="Header"><div class="sds-comps-horizontal-layout sds-comps-full-layout sds-comps-header-title"><div class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-header-left"><h2 class="sds-comps-horizontal-layout sds-comps-full-layout fender-ui_7af62893 fds-header-title-shortents"><div class="sds-comps-horizontal-layout sds-comps-full-layout fender-ui_10e25d56 fds-header-title-shortents-text-wrap"><span class="sds-comps-text sds-comps-text-type-headline3 sds-comps-text-weight-lg fender-ui_0fc0e67f fds-header-title-shortents-text">함께 보는</span><span class="sds-comps-text sds-comps-text-type-headline3 sds-comps-text-weight-lg fender-ui_be0ff25c type-navy fds-header-title-shortents-text">카테크 종합</span><span class="sds-comps-text sds-comps-text-type-headline3 sds-comps-text-weight-lg fender-ui_4eb379d7 fds-header-title-shortents-text">숏텐츠</span></div></h2><button type="button" class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-button sds-comps-icon-button fds-information-popover-button" data-sds-comp="IconSingleButton"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 16 16" class="sds-comps-svg sds-comps-icon sds-comps-icon-size-md1 fds-information-popover-icon sds-comps-mark-information-icon" width="16" height="16" fill="none" aria-hidden="true" stroke="none" aria-label="MarkInformationIcon"><path class="sds-comps-mark-information-icon-element0" fill-rule="evenodd" clip-rule="evenodd" d="M8 15.5C12.1421 15.5 15.5 12.1421 15.5 8C15.5 3.85786 12.1421 0.5 8 0.5C3.85786 0.5 0.5 3.85786 0.5 8C0.5 12.1421 3.85786 15.5 8 15.5ZM8 14.5C11.5899 14.5 14.5 11.5898 14.5 7.99999C14.5 4.41014 11.5899 1.49999 8 1.49999C4.41015 1.49999 1.5 4.41014 1.5 7.99999C1.5 11.5898 4.41015 14.5 8 14.5Z"></path><path class="sds-comps-mark-information-icon-element1" d="M8 3.80001C7.6134 3.80001 7.3 4.11341 7.3 4.50001C7.3 4.8866 7.6134 5.20001 8 5.20001C8.3866 5.20001 8.7 4.8866 8.7 4.50001C8.7 4.11341 8.3866 3.80001 8 3.80001Z"></path><path class="sds-comps-mark-information-icon-element2" d="M8.50057 6.5H7.50057V12.5H8.50057V6.5Z"></path></svg></button><span class="sds-comps-information-popover-wrapper"><div class="sds-comps-base-popover-wrapper" style="position:absolute;left:0;top:0"><div tabindex="-1" role="dialog" class="sds-comps-base-popover sds-comps-information-popover fender-ui_0e50cedf fds-information-popover" data-sds-comp="InformationPopover" data-template-id="sdsIconInformationPopover" data-template-type="basic"><div class="sds-comps-base-layout sds-comps-full-layout sds-comps-information-popover-inner"><div class="sds-comps-vertical-layout sds-comps-full-layout sds-comps-information-popover-content"><span class="sds-comps-text">생성형AI를 통해 주제별로 인기 있는 콘텐츠를 자동 추출하여 요약된 정보를 보여줍니다. 일부 콘텐츠의 경우 주제와 일치하지 않는 정보가 노출될 수 있습니다.</span></div><button type="button" class="sds-comps-horizontal-layout sds-comps-inline-layout sds-comps-button sds-comps-icon-button sds-comps-information-popover-close-btn" aria-label="정보확인 레이어 닫기" data-sds-comp="IconSingleButton"><svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 20 20" class="sds-comps-svg sds-comps-icon sds-comps-icon ...
# (function () {
#
#   var startApplication = function () {
#     var require = window.require.config({
#       "context": "fender_renderer_2f4b6a6889f5f7e1c1bb",
#       "paths": {
#         "fender_2f4b6a6889f5f7e1c1bb": "https://ssl.pstatic.net/sstatic/fe/fender/client/2f4b6a6889f5f7e1c1bb/index.js".replace(/\.js$/, ""),
#       }
#     });
#     require(["fender_2f4b6a6889f5f7e1c1bb"], function (entry) {
#       entry.bootstrap(document.getElementById("fdr-441c7dac22b446ed8bf3657f005a5156"), {"appElementAttrs":{"className":"sc_new","data-heatmap-area":"stX_cpT"},"meta":{"area":"stX_cpT","query":"인공지능","ssc":"tab.nx.all","ssuid":"shortents","ssuidExtra":"fender_renderer-shortents"},"refs":{"blockId":"shortents/prs_template_feed_search_shortents_compact_sub_desk.ts"},"rootElementAttrs":{"className":"api_subject_bx"},"body":{"props":{"children":[{"props":{"subIcon":{"props":{"clickLog":{"close":{"element":".ttclose","g":"","i":"","r":0,"source":"*b"},"open":{"element":".tooltip","g":"","i":"","r":0,"source":"*b"}},"content":"생성형AI를 통해 주제별로 인기 있는 콘텐츠를 자동 추출하여 요약된 정보를 보여줍니다. 일부 콘텐츠의 경우 주제와 일치하지 않는 정보가 노출될 수 있습니다.","full":true,"type":"basic"},"templateId":"sdsIconInformationPopover"},"titleTemplate":{"props":{"color":"navy","highlight":"카테크 종합","prefix":"함께 보는","showIcon":false,"subType":"desk","suffix":"숏텐츠","type":"shortents_nx"},"templateId":"headerTitle"},"type":"basic"},"templateId":"sdsFeedSearchHeader"},{"props":{"category":"카테크 종합","color":"navy","contents":[{"category":"카테크 종합","clickLog":{"keyword":{"element":".kwd","g":"","i":"90000003_000000000000003436D82E3F","nlog":{"airs_prid":"starfeed_naver","nlogEvt":{"airs":{"airs_session_id":"UTUMy3aMTpqduxZphh0EQA","bucket":"V0","click_shortcat":"카테크 종합","click_shortdoc":["90000003_000000000000003436D82E3F"],"click_shortkey":["테슬라 모델Y 주니퍼 전비 분석"],"service_code":"SEARCH","session_id":"oByZP1HrZxh7p4/4v/JjHwEq","session_starttime":"1776931865","template_code":"shortents_compact"}}},"r":1,"source":"*b"},"unfold":{"element":".unfold","g":"","i":"90000003_000000000000003436D82E3F","nlog":{"airs_prid":"starfeed_naver","nlogEvt":{"airs":{"airs_session_id":"UTUMy3aMTpqduxZphh0EQA","bucket":"V0","click_shortcat":"카테크 종합","click_shortdoc":["90000003_000000000000003436D82E3F"],"click_shortkey":["테슬라 모델Y 주니퍼 전비 분석"],"service_code":"SEARCH","session_id":"oByZP1HrZxh7p4/4v/JjHwEq","session_starttime":"1776931865","template_code":"shortents_compact"}}},"r":1,"source":"*b"}},"data-gdid":"90000003_000000000000003436D82E3F","date":"3일 전","imageSrc":"https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyNjA0MTlfOTUg%2FMDAxNzc2NTgyNzczNDQ5.QQ_tplRgbsUrZcukSp2f3swPYHoV_sJ3L_nSYa70ldog.12ct_vt4oLOz4cVzdP3ifeV9GaQqjOewPykiRTlwakcg.JPEG%2Foutput%25EF%25BC%25BF107818209.jpg&type=fc140_140_q75","isNew":false,"keyword":"테슬라 모델Y 주니퍼 전비 분석","keywordHref":"?mra=QkRS%5EU2JUX0NQbQ%3D%3D%5EU2xUX1NBeA%3D%3D%5ETk9DX1hJVQ%3D%3D%5EU3hUX0NQdA%3D%3D&mra2=U0RC%5EU3hUX0NQdA%3D%3D&query=%ED%85%8C%EC%8A%AC%EB%9D%BC+%EB%AA%A8%EB%8D%B8Y+%EC%A3%BC%EB%8B%88%ED%8D%BC+%EC%A0%84%EB%B9%84+%EB%B6%84%EC%84%9D&qvt=0&sm=tab_sht.best&where=nexearch&x_cue=%7B%22act%22%3A%22resrch%22%2C%22from%22%3A%22shortents%22%7D&x_shortents=%7B%22category%22%3A%22%EC%B9%B4%ED%85%8C%ED%81%AC+%EC%A2%85%ED%95%A9%22%2C%22gdid%22%3A%2290000003_000000000000003436D82E3F%22%7D","title":"테슬라모델y 주니퍼 rwd 봄철 장거리주행 전비"},{"category":"카테크 종합","clickLog":{"keyword":{"element":".kwd","g":"","i":"880000F2_000000000000000003518211","nlog":{"airs_prid":"starfeed_naver","nlogEvt":{"airs":{"airs_session_id":"UTUMy3aMTpqduxZphh0EQA","bucket":"V0","click_shortcat":"카테크 종합","click_shortdoc":["880000F2_000000000000000003518211"],"click_shortkey":["스페이스X, 우주 데이터센터 불확실"],"service_code":"SEARCH","session_id":"oByZP1HrZxh7p4/4v/JjHwEq","session_starttime":"1776931865","template_code":"shortents_compact"}}},"r":2,"source":"*b"},"unfold":{"element":".unfold","g":"","i":"880000F2_000000000000000003518211","nlog":{"airs_prid":"starfeed_naver","nlogEvt":{"airs":{"airs_session_id":"UTUMy3aMTpqduxZphh0EQA","bucket":"V0","click_shortcat":"카테크 종합","click_shortdoc":["880000F2_000000000000000003518211"],"click_shortkey":["스페이스X, 우주 데이터센터 불확실"],"service_code":"SEARCH","session_id":"oByZP1HrZxh7p4/4v/JjHwEq","session_starttime":"1776931865","template_code":"shortents_compact"}}},"r":2,"source":"*b"}},"data-gdid":"880000F2_000000000000000003518211","date":"17시간 전","ima ...
#
#       }});
#     });
#   };
#
#   if (window.naver && window.naver.common && typeof window.naver.common.load_js === "function") {
#     var isDomLoading = document.readyState === "loading";
#
#     naver.common.load_js(null, startApplication, isDomLoading, 150, !isDomLoading);
#   } else {
#     setTimeout(startApplication, 150);
#   }
# })();
# </script><script>(function(){var a="https://ssl.pstatic.net/sstatic/fe/sfe/shortents/app-1.2.0.js",b=function(){var b=window.require.config({context:"shortents",paths:{shortents:a.replace(/\.js$/,"")}});define("jquery",[],function(){return jQuery}),b(["jquery","shortents"],function(e,f){var c=e('[data-fender-root][data-block-id^="shortents/prs_template_feed_search_shortents_compact"]:not(data-handled-for-log)').attr("data-handled-for-log",""),a=new Map,b={};function g(d,b){var e=[{},{},{},{},{},{},{},{},{},{},{},{},{},{},{},{},{},{},{},{}],c=d*b,f=c+b,g=e.slice(c,f),a="";return jQuery.each(g,function(c,b){a?a+=" ":a="[",a+=JSON.stringify(b)}),a?a+"]":""}function d(h,e){var a=h.querySelector('[data-event-area="component"]'),i=a.dataset.eventExtraCategory,c=JSON.parse(a.dataset.eventExtraKeywordList),j=JSON.parse(a.dataset.eventExtraGdidList),d={event:"shortentsCompactImpTrigger",nlogEvt:{imp_nsc:"tab.m.all",imp_area:"pc_second_notch",airs:{service_code:"SEARCH",session_id:"oByZP1HrZxh7p4/4v/JjHwEq",session_starttime:"1776931865",imp_shortcat:i,imp_shortkey:c,imp_shortdoc:j,template_code:"shortents_compact",airs_session_id:"UTUMy3aMTpqduxZphh0EQA",bucket:"V0",area_code:"pc_second_notch"}}},f;e&&(d.nlogEvt.load_type=e),f=c.join(","),b[f]||(b[f]=!0,d.nlogEvt.airs.bypass=g(Object.keys(b).length-1,c.length),window.ntm.push(d))}c.each(function(c,b){f.logExposure({el:b,callback:function(b){a[b.el]=b.intersect,a[b.el]&&d(b.el)}})}),c.on("fender-event",function(b){var c=b.detail.type,e=b.detail.eventName;c==="impressLog"&&e==="update_keyword"&&a[b.target]&&d(b.target,"reload")})})};naver.common.load_js(null,b)})()</script><section class="sc_new"> <div class="api_subject_bx"> <div class="api_common_banner"> <a nocr onclick="return goOtherCR(this, 'a=bnr.link1&r=1&i=&u=' + urlencode(this.href));" href="https://mkt.naver.com/p1/atrb?channel_id=naver_pcsearchmktbanner&campaign_id=2603-naverclip-001&target=https%3A%2F%2Fclipcreators.naver.com%2Fpromotion%2Ftoday%3Fdtm_source%3Dnaver_pcsearchmktbanner%26dtm_medium%3Dmktatrb_etc%26dtm_campaign%3D2603-naverclip-001" class="spnew_bf item" target="_blank"> <div class="ico_area"><img src="https://csearch-phinf.pstatic.net/20260402_96/17750899533084BXWL_JPEG/760_31963112_marketing_banner_pc_icon_0_1775089953303.jpg" width="36" height="36" alt="" class="ico"></div> <div class="dsc_area"> <strong class="elss tit">오늘은 어떤 취향을 남겨볼까요?</strong> <p class="elss dsc">오늘 클립 챌린지</p> </div> </a> <a nocr onclick="return goOtherCR(this, 'a=bnr.link2&r=2&i=&u=' + urlencode(this.href));" href="https://mkt.naver.com/p1/atrb?channel_id=naver_pcsearchmktbanner&campaign_id=2604-shopping-004&target=https%3A%2F%2Fshopping.naver.com%2Ffesta%2Fgift%2F69b749a21598d745dca2155c%3FlayerId%3DL_260324103322314%26dtm_source%3Dnaver_pcsearchmktbanner%26dtm_medium%3Dmktatrb_etc%26dtm_campaign%3D2604-shopping-004" class="spnew_bf item" target="_blank"> <div class="ico_area"><img src="https://csearch-phinf.pstatic.net/20260420_168/1776645093386F6Ua0_PNG/760_31963112_marketing_banner_pc_icon_1_1776645093379.png" width="36" height="36" alt="" class="ico"></div> <div class="dsc_area"> <strong class="elss tit">가정의달+세일</strong> <p class="elss dsc">선물에 진심, 혜택에 진심 N+스토어</p> </div> </a> <a nocr onclick="return goOtherCR(this, 'a=bnr.link3&r=3&i=&u=' + urlencode(this.href));" href="https://mkt.naver.com/p1/atrb?channel_id=naver_pcsearchmktbanner&campaign_id=2509-shopping-007&target=https%3A%2F%2Fshopping.naver.com%2Fns%2Fhome%2Fkurlynmart%3Fdtm_source%3Dnaver_pcsearchmktbanner%26dtm_medium%3Dmktatrb_etc%26dtm_campaign%3D2509-shopping-007" class="spnew_bf item" target="_blank"> <div class="ico_area"><img src="https://csearch-phinf.pstatic.net/20260107_198/1767771129397w9Fx5_JPEG/760_31963112_marketing_banner_pc_icon_2_1767771129391.jpg" width="36" height="36" alt="" class="ico"></div> <div class="dsc_area"> <strong class="elss tit">네이버에서 컬리를</strong> <p class="elss dsc">멤버십 2만원 이상 무료배송</p> </div> </a> <a nocr onclick="return goOtherCR(this, 'a ...
